# %%
import torch
import matplotlib.pyplot as plt
import numpy as np 
import argparse
import pickle 
import os
from torch.autograd import Variable 
from torchvision import transforms 
from data_loader import build_vocab 
from model import EncoderCNN, DecoderRNN
from model import ResNet, ResidualBlock
from PIL import Image
from attn_model import ResidualBlock, AttnEncoder, AttnDecoderRnn


embed_size = 128
hidden_size = 256 
num_layers = 1 
feature_size = 128 

#decoder_path = './models/2object_color/decoder-10-150.pkl'
#encoder_path = './models/2object_color/encoder-10-150.pkl'
decoder_path = './models/attn/nobject/decoder-15-500.pkl'
encoder_path = './models/attn/nobject/encoder-15-500.pkl'

def to_var(x, volatile=False):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x, volatile=volatile)

def load_image(image_path, transform=None):
    image = Image.open(image_path).convert('RGB')
    image = image.resize([64, 64], Image.LANCZOS)
    
    if transform is not None:
        image = transform(image).unsqueeze(0)
    
    return image

transform = transforms.Compose([ 
    transforms.ToTensor(), 
    transforms.Normalize((0.033, 0.032, 0.033), 
                         (0.027, 0.027, 0.027))])



#vocab_path = './data/vocab_2object_color.pkl'
vocab_path = './data/attn/vocabn.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
len_vocab = vocab.idx

# Build Models
#encoder = ResNet(ResidualBlock, [3, 3, 3], len_vocab)
#encoder.eval()  # evaluation mode (BN uses moving mean/variance)
#decoder = DecoderRNN(len_vocab, hidden_size, len(vocab), num_layers)

encoder = AttnEncoder(ResidualBlock, [3, 3, 3])
encoder.eval()  # evaluation mode (BN uses moving mean/variance)
decoder = AttnDecoderRnn(feature_size, hidden_size, 
                     len(vocab), num_layers)



# Load the trained model parameters
encoder.load_state_dict(torch.load(encoder_path))
decoder.load_state_dict(torch.load(decoder_path))

# If use gpu
if torch.cuda.is_available():
    encoder.cuda()
    decoder.cuda()

# %%
test_dir = 'data/nobject_test/bitmap/'
cap_dir = 'data/nobject_test/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

shape_match = 0
location_match = 0
location_match_rect= 0 
radius_match = 0 
rect_x_match = 0 
rect_y_match = 0 
color_match = 0

location_err = [] 
location_err_rect = [] 

rect_x_err = []
rect_y_err = []
radius_err = [] 


for fname in test_list: 
    #cnt+=1 
    if cnt>2:
        break;
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))
    print(fname)

    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    in_caption = sampled_caption[1:-1]
    print(in_caption)
    
    #read target caption
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    trg_caption = [] 
    with open(cap_path, 'r') as f:
        target = f.readline().split()
        for word in target:
            trg_caption.append(word)
    print(trg_caption)
    print('------------------------------------')
# Out:
# 748.png
# ['circle', '3', '8', '120', 'red', 'circle', '6', '3', '100', 'red', 'circle', '2', '10', '80', 'red', 'rect', '9', '10', '100', '30', 'red', 'rect', '9', '7', '40', '60', 'red', 'rect', '5', '3', '40', '80', 'red', 'rect', '7', '6', '30', '30', 'red', 'rect', '1', '4', '120', '70', 'red', 'rect', '3', '6', '110', '50', 'red', 'rect', '4', '6', '50', '50', 'red']
# ['circle', '3', '8', '120', 'yellow', 'circle', '1', '10', '80', 'purple', 'circle', '6', '3', '100', 'skyblue', 'rect', '3', '6', '100', '50', 'orange', 'rect', '2', '6', '60', '110', 'yellow', 'rect', '1', '5', '120', '70', 'red', 'rect', '5', '3', '30', '80', 'spring_green', 'rect', '7', '6', '30', '30', 'red', 'rect', '9', '7', '40', '60', 'red', 'rect', '9', '10', '120', '80', 'blue']
# ------------------------------------
# 606.png
# ['circle', '1', '9', '80', 'red', 'rect', '7', '5', '100', '110', 'red', 'rect', '9', '2', '110', '50', 'red', 'rect', '9', '7', '60', '90', 'red', 'rect', '7', '2', '100', '80', 'red', 'rect', '1', '7', '80', '90', 'red', 'rect', '8', '5', '100', '110', 'red']
# ['circle', '1', '9', '80', 'blue', 'rect', '8', '5', '100', '110', 'purple', 'rect', '9', '7', '60', '90', 'red', 'rect', '9', '2', '100', '50', 'green', 'rect', '9', '5', '30', '30', 'pink', 'rect', '7', '2', '100', '80', 'yellow', 'rect', '1', '7', '80', '90', 'cyan']
# ------------------------------------
# 468.png
# ['rect', '9', '7', '100', '90', 'red', 'rect', '2', '7', '30', '110', 'red', 'rect', '9', '8', '40', '30', 'red', 'rect', '1', '2', '80', '20', 'red', 'rect', '10', '4', '30', '60', 'red', 'rect', '7', '6', '120', '120', 'red', 'rect', '5', '4', '60', '30', 'red', 'rect', '2', '4', '30', '100', 'red', 'rect', '3', '10', '30', '90', 'red', 'rect', '9', '8', '40', '30', 'red']
# ['rect', '2', '4', '40', '100', 'purple', 'rect', '9', '7', '50', '50', 'skyblue', 'rect', '10', '4', '30', '60', 'lime', 'rect', '9', '7', '80', '100', 'red', 'rect', '3', '10', '30', '30', 'red', 'rect', '7', '6', '120', '120', 'yellow', 'rect', '5', '4', '60', '30', 'pink', 'rect', '9', '8', '40', '30', 'spring_green', 'rect', '2', '7', '30', '110', 'red', 'rect', '1', '2', '80', '20', 'spring_green']
# ------------------------------------
# 596.png
# ['rect', '6', '6', '110', '80', 'red', 'rect', '5', '6', '50', '60', 'red', 'rect', '6', '2', '110', '100', 'red', 'rect', '3', '4', '30', '80', 'red', 'rect', '9', '10', '40', '90', 'red', 'rect', '6', '9', '50', '110', 'red', 'rect', '4', '3', '90', '110', 'red']
# ['rect', '9', '10', '40', '90', 'blue', 'rect', '5', '6', '50', '60', 'pink', 'rect', '3', '5', '30', '80', 'yellow', 'rect', '6', '2', '120', '100', 'pink', 'rect', '4', '3', '90', '110', 'yellow', 'rect', '7', '6', '30', '80', 'spring_green', 'rect', '6', '9', '50', '90', 'deep_pink']
# ------------------------------------
# 489.png
# ['circle', '5', '5', '60', 'red', 'circle', '3', '2', '40', 'red', 'rect', '2', '7', '70', '80', 'red', 'rect', '2', '9', '30', '20', 'red', 'rect', '10', '8', '110', '100', 'red', 'rect', '7', '5', '50', '60', 'red', 'rect', '2', '5', '80', '80', 'red']
# ['circle', '5', '5', '60', 'deep_pink', 'circle', '3', '2', '40', 'spring_green', 'rect', '7', '5', '50', '60', 'skyblue', 'rect', '2', '9', '30', '20', 'cyan', 'rect', '2', '7', '70', '80', 'lime', 'rect', '10', '8', '60', '100', 'spring_green', 'rect', '2', '5', '80', '80', 'blue']
# ------------------------------------
# 754.png
# ['rect', '8', '9', '50', '40', 'red', 'rect', '3', '10', '70', '90', 'red', 'rect', '4', '9', '40', '30', 'red', 'rect', '5', '9', '30', '30', 'red']
# ['rect', '4', '9', '40', '30', 'green', 'rect', '8', '9', '50', '40', 'purple', 'rect', '3', '10', '70', '100', 'lime', 'rect', '10', '10', '80', '60', 'red']
# ------------------------------------
# 746.png
# ['circle', '1', '8', '20', 'red', 'circle', '8', '7', '20', 'red', 'rect', '4', '5', '30', '100', 'red', 'rect', '5', '9', '100', '50', 'red', 'rect', '8', '1', '60', '120', 'red', 'rect', '4', '1', '40', '60', 'red', 'rect', '1', '6', '50', '90', 'red']
# ['circle', '8', '7', '20', 'green', 'circle', '1', '8', '20', 'deep_pink', 'rect', '1', '6', '50', '90', 'spring_green', 'rect', '4', '1', '40', '60', 'pink', 'rect', '8', '1', '60', '120', 'deep_pink', 'rect', '4', '5', '20', '100', 'red', 'rect', '5', '9', '100', '50', 'lime']
# ------------------------------------
# 714.png
# ['rect', '5', '10', '110', '90', 'red', 'rect', '1', '3', '90', '80', 'red', 'rect', '4', '2', '30', '40', 'red', 'rect', '1', '3', '90', '80', 'red', 'rect', '5', '1', '70', '30', 'red', 'rect', '3', '8', '40', '60', 'red', 'rect', '6', '10', '80', '110', 'red', 'rect', '4', '1', '70', '30', 'red', 'rect', '5', '3', '110', '50', 'red', 'rect', '3', '8', '40', '60', 'red']
# ['rect', '3', '8', '40', '60', 'blue', 'rect', '5', '3', '110', '50', 'red', 'rect', '1', '8', '90', '30', 'lime', 'rect', '3', '10', '70', '80', 'pink', 'rect', '5', '10', '120', '30', 'cyan', 'rect', '4', '1', '70', '30', 'lime', 'rect', '7', '10', '70', '30', 'deep_pink', 'rect', '4', '2', '20', '40', 'lime', 'rect', '1', '4', '90', '80', 'blue', 'rect', '2', '2', '100', '30', 'purple']
# ------------------------------------
# 723.png
# ['circle', '8', '8', '60', 'red', 'circle', '6', '4', '50', 'red', 'circle', '8', '8', '60', 'red', 'circle', '7', '8', '80', 'red', 'rect', '7', '10', '70', '80', 'red', 'rect', '4', '9', '90', '100', 'red', 'rect', '7', '9', '70', '70', 'red']
# ['circle', '5', '10', '30', 'deep_pink', 'circle', '8', '7', '60', 'blue', 'circle', '8', '9', '70', 'green', 'circle', '6', '4', '50', 'purple', 'circle', '7', '8', '80', 'spring_green', 'rect', '7', '10', '70', '80', 'red', 'rect', '4', '9', '90', '110', 'pink']
# ------------------------------------
# 833.png
# ['circle', '9', '5', '90', 'red', 'circle', '2', '2', '70', 'red', 'circle', '8', '1', '110', 'red', 'circle', '9', '5', '40', 'red', 'circle', '4', '2', '120', 'red', 'circle', '9', '5', '40', 'red', 'circle', '8', '7', '100', 'red', 'rect', '2', '6', '40', '40', 'red', 'rect', '10', '1', '80', '90', 'red', 'rect', '9', '1', '90', '90', 'red']
# ['circle', '4', '2', '80', 'spring_green', 'circle', '6', '1', '50', 'red', 'circle', '8', '1', '110', 'skyblue', 'circle', '9', '5', '90', 'cyan', 'circle', '9', '5', '40', 'red', 'circle', '8', '7', '100', 'deep_pink', 'circle', '3', '2', '70', 'deep_pink', 'circle', '4', '2', '120', 'yellow', 'rect', '10', '1', '80', '90', 'skyblue', 'rect', '2', '6', '40', '40', 'deep_pink']
# ------------------------------------
# 987.png
# ['circle', '4', '6', '30', 'red', 'circle', '10', '6', '60', 'red', 'circle', '7', '9', '20', 'red', 'circle', '5', '4', '80', 'red', 'circle', '4', '10', '70', 'red', 'rect', '1', '10', '40', '110', 'red', 'rect', '1', '3', '90', '80', 'red', 'rect', '4', '3', '50', '80', 'red', 'rect', '3', '1', '30', '50', 'red', 'rect', '1', '5', '90', '100', 'red']
# ['circle', '7', '9', '20', 'red', 'circle', '4', '10', '70', 'lime', 'circle', '5', '4', '70', 'deep_pink', 'circle', '3', '6', '30', 'green', 'circle', '10', '6', '60', 'spring_green', 'rect', '1', '10', '40', '70', 'orange', 'rect', '1', '3', '90', '80', 'lime', 'rect', '1', '5', '90', '100', 'yellow', 'rect', '4', '3', '50', '80', 'yellow', 'rect', '3', '1', '30', '50', 'lime']
# ------------------------------------
# 698.png
# ['circle', '1', '3', '80', 'red', 'circle', '1', '8', '70', 'red', 'circle', '2', '3', '80', 'red', 'circle', '9', '4', '50', 'red', 'circle', '8', '1', '110', 'red', 'rect', '6', '2', '90', '100', 'red', 'rect', '6', '9', '40', '50', 'red', 'rect', '10', '9', '70', '30', 'red', 'rect', '7', '3', '110', '60', 'red', 'rect', '10', '9', '70', '30', 'red']
# ['circle', '1', '4', '70', 'red', 'circle', '1', '3', '110', 'lime', 'circle', '1', '8', '70', 'red', 'circle', '9', '4', '50', 'red', 'circle', '2', '2', '80', 'blue', 'circle', '8', '1', '110', 'lime', 'rect', '6', '2', '50', '100', 'deep_pink', 'rect', '7', '3', '110', '60', 'blue', 'rect', '6', '9', '40', '50', 'lime', 'rect', '10', '9', '80', '30', 'lime']
# ------------------------------------
# 178.png
# ['circle', '6', '7', '100', 'red', 'circle', '3', '7', '20', 'red', 'rect', '2', '4', '40', '50', 'red', 'rect', '4', '1', '30', '90', 'red']
# ['circle', '6', '7', '100', 'red', 'circle', '3', '7', '20', 'pink', 'rect', '2', '4', '40', '50', 'skyblue', 'rect', '4', '1', '30', '90', 'pink']
# ------------------------------------
# 203.png
# ['circle', '6', '9', '60', 'red', 'circle', '8', '2', '60', 'red', 'circle', '9', '7', '70', 'red', 'circle', '4', '3', '70', 'red', 'rect', '6', '4', '90', '100', 'red', 'rect', '1', '2', '70', '60', 'red', 'rect', '2', '6', '70', '90', 'red']
# ['circle', '6', '9', '60', 'spring_green', 'circle', '9', '7', '70', 'purple', 'circle', '4', '3', '70', 'yellow', 'circle', '8', '2', '60', 'lime', 'rect', '2', '6', '70', '90', 'yellow', 'rect', '6', '4', '90', '100', 'pink', 'rect', '1', '2', '70', '60', 'yellow']
# ------------------------------------
# 400.png
# ['circle', '7', '6', '60', 'red', 'circle', '6', '5', '20', 'red', 'rect', '7', '5', '40', '70', 'red', 'rect', '5', '6', '30', '20', 'red']
# ['circle', '7', '6', '60', 'yellow', 'circle', '6', '5', '20', 'deep_pink', 'rect', '7', '5', '40', '70', 'skyblue', 'rect', '5', '6', '50', '20', 'skyblue']
# ------------------------------------
# 192.png
# ['circle', '6', '9', '100', 'red', 'circle', '5', '9', '50', 'red', 'rect', '9', '1', '100', '110', 'red', 'rect', '3', '3', '30', '70', 'red', 'rect', '3', '2', '100', '90', 'red', 'rect', '8', '3', '30', '90', 'red', 'rect', '9', '3', '70', '80', 'red']
# ['circle', '6', '9', '100', 'spring_green', 'circle', '5', '9', '50', 'blue', 'rect', '9', '3', '70', '80', 'pink', 'rect', '9', '1', '100', '110', 'red', 'rect', '3', '2', '40', '90', 'green', 'rect', '8', '3', '30', '90', 'purple', 'rect', '3', '1', '100', '90', 'blue']
# ------------------------------------
# 2.png
# ['circle', '8', '2', '80', 'red', 'circle', '5', '5', '90', 'red', 'circle', '8', '1', '100', 'red', 'rect', '3', '7', '110', '80', 'red']
# ['circle', '5', '5', '90', 'lime', 'circle', '8', '2', '80', 'lime', 'circle', '8', '1', '100', 'orange', 'rect', '3', '7', '110', '80', 'lime']
# ------------------------------------
# 126.png
# ['circle', '8', '10', '30', 'red', 'rect', '10', '10', '70', '90', 'red', 'rect', '8', '1', '20', '70', 'red', 'rect', '2', '6', '120', '120', 'red']
# ['circle', '8', '10', '30', 'spring_green', 'rect', '8', '1', '20', '70', 'red', 'rect', '2', '6', '120', '120', 'deep_pink', 'rect', '10', '10', '50', '110', 'lime']
# ------------------------------------
# 711.png
# ['circle', '1', '3', '80', 'red', 'circle', '5', '2', '60', 'red', 'circle', '10', '8', '70', 'red', 'circle', '3', '5', '110', 'red', 'circle', '9', '2', '110', 'red', 'circle', '3', '5', '30', 'red', 'rect', '10', '2', '70', '80', 'red']
# ['circle', '2', '4', '40', 'pink', 'circle', '10', '8', '70', 'red', 'circle', '10', '1', '50', 'deep_pink', 'circle', '1', '3', '80', 'lime', 'circle', '5', '2', '60', 'pink', 'circle', '9', '2', '110', 'spring_green', 'circle', '3', '5', '110', 'blue']
# ------------------------------------
# 752.png
# ['circle', '10', '5', '80', 'red', 'circle', '4', '6', '30', 'red', 'circle', '10', '2', '100', 'red', 'circle', '7', '10', '50', 'red', 'circle', '3', '4', '110', 'red', 'circle', '5', '2', '90', 'red', 'circle', '9', '3', '30', 'red', 'circle', '8', '8', '50', 'red', 'rect', '8', '8', '50', '50', 'red', 'rect', '10', '2', '80', '50', 'red']
# ['circle', '10', '1', '110', 'orange', 'circle', '4', '6', '30', 'red', 'circle', '10', '5', '80', 'blue', 'circle', '9', '3', '30', 'skyblue', 'circle', '7', '10', '50', 'orange', 'circle', '3', '4', '110', 'pink', 'circle', '4', '3', '70', 'pink', 'circle', '5', '2', '90', 'cyan', 'rect', '10', '1', '40', '110', 'lime', 'rect', '8', '8', '50', '50', 'lime']
# ------------------------------------
# 910.png
# ['circle', '7', '4', '100', 'red', 'circle', '4', '1', '110', 'red', 'circle', '10', '3', '110', 'red', 'circle', '1', '4', '100', 'red', 'circle', '4', '1', '100', 'red', 'circle', '7', '7', '110', 'red', 'circle', '1', '4', '100', 'red', 'rect', '2', '6', '100', '100', 'red', 'rect', '7', '7', '100', '30', 'red', 'rect', '10', '3', '80', '50', 'red']
# ['circle', '2', '4', '40', 'red', 'circle', '1', '4', '100', 'red', 'circle', '4', '1', '110', 'deep_pink', 'circle', '4', '1', '90', 'pink', 'circle', '4', '1', '60', 'pink', 'circle', '7', '4', '100', 'blue', 'circle', '10', '3', '100', 'blue', 'circle', '7', '7', '110', 'spring_green', 'rect', '7', '7', '100', '30', 'red', 'rect', '2', '6', '100', '100', 'pink']
# ------------------------------------
# 67.png
# ['circle', '1', '8', '80', 'red', 'circle', '2', '2', '90', 'red', 'circle', '1', '10', '90', 'red', 'circle', '2', '10', '80', 'red', 'circle', '8', '3', '20', 'red', 'circle', '10', '1', '70', 'red', 'circle', '5', '8', '50', 'red', 'rect', '8', '1', '30', '40', 'red', 'rect', '8', '10', '70', '90', 'red', 'rect', '3', '10', '110', '30', 'red']
# ['circle', '1', '9', '80', 'pink', 'circle', '5', '8', '50', 'orange', 'circle', '2', '10', '80', 'deep_pink', 'circle', '2', '2', '90', 'lime', 'circle', '8', '3', '20', 'red', 'circle', '10', '1', '70', 'spring_green', 'circle', '1', '2', '90', 'orange', 'rect', '8', '10', '70', '70', 'orange', 'rect', '8', '1', '30', '50', 'red', 'rect', '3', '10', '110', '30', 'red']
# ------------------------------------
# 925.png
# ['circle', '2', '5', '30', 'red', 'circle', '2', '9', '70', 'red', 'circle', '7', '9', '110', 'red', 'circle', '6', '3', '100', 'red', 'circle', '10', '8', '60', 'red', 'circle', '8', '4', '50', 'red', 'circle', '4', '4', '110', 'red', 'circle', '1', '10', '80', 'red', 'circle', '8', '4', '50', 'red', 'rect', '10', '8', '90', '60', 'red']
# ['circle', '6', '8', '60', 'pink', 'circle', '2', '9', '70', 'skyblue', 'circle', '6', '3', '100', 'spring_green', 'circle', '8', '10', '20', 'lime', 'circle', '8', '4', '50', 'blue', 'circle', '2', '5', '30', 'green', 'circle', '1', '10', '80', 'green', 'circle', '10', '8', '60', 'spring_green', 'circle', '4', '4', '110', 'spring_green', 'circle', '7', '9', '120', 'spring_green']
# ------------------------------------
# 355.png
# ['rect', '9', '8', '40', '40', 'red', 'rect', '6', '2', '60', '80', 'red', 'rect', '5', '4', '80', '60', 'red', 'rect', '8', '5', '100', '60', 'red', 'rect', '3', '5', '60', '30', 'red', 'rect', '8', '10', '80', '110', 'red', 'rect', '1', '1', '110', '20', 'red', 'rect', '5', '4', '80', '30', 'red', 'rect', '2', '4', '20', '110', 'red', 'rect', '9', '1', '70', '80', 'red']
# ['rect', '5', '4', '80', '60', 'red', 'rect', '5', '5', '80', '30', 'spring_green', 'rect', '6', '2', '60', '80', 'purple', 'rect', '8', '10', '80', '110', 'pink', 'rect', '9', '1', '70', '80', 'green', 'rect', '8', '5', '100', '60', 'orange', 'rect', '1', '1', '110', '20', 'purple', 'rect', '2', '4', '20', '110', 'cyan', 'rect', '9', '8', '40', '40', 'deep_pink', 'rect', '3', '6', '60', '120', 'red']
# ------------------------------------
# 687.png
# ['circle', '7', '9', '80', 'red', 'circle', '1', '4', '120', 'red', 'circle', '1', '8', '20', 'red', 'circle', '7', '8', '90', 'red']
# ['circle', '7', '9', '70', 'deep_pink', 'circle', '1', '8', '20', 'cyan', 'circle', '7', '8', '90', 'yellow', 'circle', '1', '4', '120', 'red']
# ------------------------------------
# 340.png
# ['circle', '8', '4', '40', 'red', 'circle', '5', '1', '110', 'red', 'circle', '4', '7', '60', 'red', 'circle', '5', '1', '100', 'red', 'circle', '1', '9', '70', 'red', 'circle', '4', '8', '80', 'red', 'circle', '4', '6', '90', 'red', 'rect', '7', '6', '40', '50', 'red', 'rect', '4', '1', '30', '100', 'red', 'rect', '8', '2', '60', '120', 'red']
# ['circle', '5', '7', '90', 'deep_pink', 'circle', '8', '4', '40', 'orange', 'circle', '6', '1', '60', 'lime', 'circle', '4', '6', '90', 'purple', 'circle', '5', '1', '110', 'yellow', 'circle', '4', '8', '60', 'purple', 'circle', '1', '9', '70', 'skyblue', 'rect', '7', '6', '40', '50', 'orange', 'rect', '8', '2', '60', '120', 'cyan', 'rect', '4', '1', '30', '100', 'blue']
# ------------------------------------
# 70.png
# ['circle', '10', '1', '40', 'red', 'rect', '7', '1', '30', '80', 'red', 'rect', '10', '6', '70', '60', 'red', 'rect', '1', '7', '30', '80', 'red', 'rect', '8', '1', '40', '70', 'red', 'rect', '2', '2', '80', '100', 'red', 'rect', '4', '8', '90', '80', 'red']
# ['circle', '10', '1', '40', 'orange', 'rect', '8', '1', '40', '70', 'deep_pink', 'rect', '10', '6', '70', '60', 'blue', 'rect', '1', '7', '30', '80', 'green', 'rect', '2', '2', '80', '100', 'lime', 'rect', '7', '1', '30', '80', 'green', 'rect', '4', '8', '90', '80', 'red']
# ------------------------------------
# 738.png
# ['circle', '6', '6', '60', 'red', 'circle', '9', '7', '60', 'red', 'circle', '1', '8', '40', 'red', 'circle', '5', '6', '20', 'red', 'circle', '7', '5', '80', 'red', 'circle', '4', '2', '40', 'red', 'rect', '3', '10', '60', '90', 'red']
# ['circle', '6', '5', '60', 'spring_green', 'circle', '9', '7', '60', 'purple', 'circle', '4', '2', '40', 'green', 'circle', '7', '5', '80', 'yellow', 'circle', '1', '8', '40', 'purple', 'circle', '5', '6', '20', 'orange', 'rect', '3', '10', '60', '100', 'red']
# ------------------------------------
# 647.png
# ['circle', '4', '7', '40', 'red', 'circle', '2', '5', '100', 'red', 'circle', '3', '10', '90', 'red', 'circle', '10', '1', '60', 'red', 'circle', '4', '9', '30', 'red', 'circle', '3', '9', '20', 'red', 'rect', '3', '9', '30', '20', 'red']
# ['circle', '4', '8', '40', 'yellow', 'circle', '2', '5', '100', 'green', 'circle', '4', '10', '80', 'skyblue', 'circle', '3', '9', '20', 'spring_green', 'circle', '4', '7', '20', 'green', 'circle', '10', '1', '60', 'red', 'rect', '3', '10', '40', '20', 'cyan']
# ------------------------------------
# 630.png
# ['circle', '8', '3', '80', 'red', 'circle', '2', '2', '100', 'red', 'circle', '8', '5', '90', 'red', 'circle', '4', '4', '60', 'red', 'circle', '8', '4', '50', 'red', 'circle', '1', '4', '60', 'red', 'circle', '2', '1', '30', 'red', 'circle', '8', '5', '40', 'red', 'circle', '1', '4', '60', 'red', 'rect', '2', '4', '70', '80', 'red']
# ['circle', '8', '6', '90', 'green', 'circle', '3', '2', '50', 'cyan', 'circle', '8', '3', '70', 'spring_green', 'circle', '2', '3', '110', 'skyblue', 'circle', '8', '4', '50', 'purple', 'circle', '1', '4', '60', 'spring_green', 'circle', '2', '1', '40', 'green', 'circle', '4', '4', '60', 'green', 'circle', '8', '5', '40', 'pink', 'rect', '2', '3', '70', '80', 'lime']
# ------------------------------------
# 524.png
# ['circle', '6', '3', '80', 'red', 'circle', '4', '3', '80', 'red', 'circle', '1', '7', '60', 'red', 'circle', '5', '10', '40', 'red', 'rect', '9', '10', '100', '90', 'red', 'rect', '4', '7', '110', '90', 'red', 'rect', '10', '10', '80', '80', 'red']
# ['circle', '6', '3', '80', 'deep_pink', 'circle', '1', '7', '60', 'purple', 'circle', '4', '3', '80', 'skyblue', 'circle', '6', '10', '50', 'blue', 'rect', '9', '10', '50', '70', 'purple', 'rect', '4', '7', '110', '90', 'cyan', 'rect', '9', '10', '100', '100', 'spring_green']
# ------------------------------------
# 204.png
# ['rect', '10', '10', '80', '90', 'red', 'rect', '6', '1', '100', '90', 'red', 'rect', '2', '10', '120', '90', 'red', 'rect', '6', '2', '80', '90', 'red']
# ['rect', '6', '1', '90', '90', 'spring_green', 'rect', '2', '10', '120', '90', 'red', 'rect', '6', '2', '80', '80', 'yellow', 'rect', '10', '10', '90', '110', 'green']
# ------------------------------------
# 528.png
# ['circle', '3', '3', '70', 'red', 'circle', '2', '10', '80', 'red', 'circle', '6', '8', '100', 'red', 'circle', '5', '1', '70', 'red']
# ['circle', '6', '8', '100', 'red', 'circle', '3', '3', '70', 'lime', 'circle', '2', '10', '80', 'yellow', 'circle', '5', '1', '70', 'yellow']
# ------------------------------------
# 834.png
# ['circle', '2', '6', '20', 'red', 'rect', '1', '2', '60', '20', 'red', 'rect', '3', '4', '80', '60', 'red', 'rect', '6', '10', '70', '80', 'red', 'rect', '1', '2', '60', '20', 'red', 'rect', '6', '6', '120', '20', 'red', 'rect', '2', '4', '100', '50', 'red', 'rect', '6', '10', '70', '90', 'red', 'rect', '1', '2', '60', '20', 'red', 'rect', '4', '5', '120', '110', 'red']
# ['circle', '2', '6', '30', 'blue', 'rect', '1', '2', '60', '20', 'red', 'rect', '2', '4', '100', '60', 'pink', 'rect', '2', '10', '90', '90', 'blue', 'rect', '4', '2', '120', '40', 'skyblue', 'rect', '3', '5', '80', '110', 'spring_green', 'rect', '1', '4', '30', '60', 'pink', 'rect', '1', '3', '110', '100', 'spring_green', 'rect', '6', '10', '70', '90', 'deep_pink', 'rect', '6', '5', '120', '20', 'yellow']
# ------------------------------------
# 85.png
# ['circle', '7', '8', '50', 'red', 'rect', '7', '8', '80', '90', 'red', 'rect', '2', '9', '110', '30', 'red', 'rect', '9', '7', '50', '80', 'red', 'rect', '6', '4', '110', '70', 'red', 'rect', '2', '6', '100', '50', 'red', 'rect', '6', '5', '20', '70', 'red']
# ['circle', '7', '8', '50', 'pink', 'rect', '7', '5', '100', '110', 'cyan', 'rect', '2', '9', '110', '30', 'red', 'rect', '7', '8', '70', '90', 'pink', 'rect', '2', '6', '100', '50', 'yellow', 'rect', '6', '4', '20', '70', 'red', 'rect', '9', '7', '50', '80', 'orange']
# ------------------------------------
# 776.png
# ['circle', '10', '4', '100', 'red', 'circle', '10', '10', '60', 'red', 'circle', '6', '3', '110', 'red', 'circle', '8', '5', '80', 'red', 'circle', '1', '10', '40', 'red', 'circle', '9', '6', '40', 'red', 'circle', '10', '1', '80', 'red', 'circle', '2', '6', '110', 'red', 'circle', '9', '5', '30', 'red', 'rect', '3', '5', '70', '120', 'red']
# ['circle', '1', '10', '40', 'green', 'circle', '10', '3', '50', 'cyan', 'circle', '10', '4', '110', 'cyan', 'circle', '10', '1', '80', 'red', 'circle', '6', '3', '110', 'pink', 'circle', '2', '6', '110', 'lime', 'circle', '8', '5', '80', 'red', 'circle', '9', '6', '40', 'spring_green', 'circle', '10', '10', '60', 'purple', 'rect', '3', '5', '70', '120', 'orange']
# ------------------------------------
# 78.png
# ['circle', '5', '8', '120', 'red', 'circle', '2', '2', '70', 'red', 'rect', '2', '7', '70', '30', 'red', 'rect', '5', '2', '50', '110', 'red', 'rect', '9', '7', '100', '100', 'red', 'rect', '8', '5', '60', '20', 'red', 'rect', '3', '3', '20', '80', 'red']
# ['circle', '5', '8', '120', 'purple', 'circle', '2', '2', '70', 'lime', 'rect', '5', '2', '50', '110', 'orange', 'rect', '2', '7', '70', '30', 'purple', 'rect', '3', '3', '20', '80', 'purple', 'rect', '8', '5', '60', '20', 'spring_green', 'rect', '9', '7', '90', '100', 'red']
# ------------------------------------
# 365.png
# ['circle', '2', '6', '60', 'red', 'circle', '10', '8', '120', 'red', 'circle', '3', '8', '20', 'red', 'circle', '5', '9', '30', 'red', 'rect', '10', '7', '70', '60', 'red', 'rect', '4', '10', '90', '70', 'red', 'rect', '6', '7', '110', '100', 'red', 'rect', '1', '5', '90', '70', 'red', 'rect', '3', '1', '70', '100', 'red', 'rect', '10', '7', '80', '60', 'red']
# ['circle', '10', '7', '120', 'blue', 'circle', '5', '9', '30', 'orange', 'circle', '3', '8', '20', 'yellow', 'circle', '2', '6', '60', 'orange', 'circle', '2', '6', '50', 'lime', 'rect', '3', '1', '70', '100', 'pink', 'rect', '10', '7', '70', '60', 'lime', 'rect', '6', '7', '110', '100', 'lime', 'rect', '1', '5', '90', '70', 'skyblue', 'rect', '4', '10', '90', '120', 'green']
# ------------------------------------
# 737.png
# ['circle', '7', '3', '100', 'red', 'rect', '9', '3', '110', '80', 'red', 'rect', '8', '6', '120', '110', 'red', 'rect', '4', '3', '90', '20', 'red', 'rect', '9', '2', '100', '90', 'red', 'rect', '2', '10', '70', '70', 'red', 'rect', '4', '6', '100', '100', 'red', 'rect', '9', '2', '30', '90', 'red', 'rect', '3', '3', '110', '60', 'red', 'rect', '6', '3', '90', '70', 'red']
# ['circle', '7', '3', '100', 'red', 'rect', '4', '3', '90', '60', 'lime', 'rect', '8', '6', '120', '110', 'purple', 'rect', '2', '10', '70', '90', 'lime', 'rect', '9', '4', '80', '30', 'green', 'rect', '9', '1', '100', '120', 'yellow', 'rect', '4', '6', '100', '100', 'orange', 'rect', '6', '3', '90', '70', 'pink', 'rect', '3', '3', '110', '60', 'spring_green', 'rect', '9', '2', '30', '80', 'red']
# ------------------------------------
# 486.png
# ['rect', '5', '4', '70', '60', 'red', 'rect', '2', '8', '20', '30', 'red', 'rect', '4', '1', '50', '110', 'red', 'rect', '3', '4', '70', '70', 'red']
# ['rect', '3', '4', '70', '70', 'blue', 'rect', '5', '4', '70', '60', 'yellow', 'rect', '4', '1', '50', '120', 'skyblue', 'rect', '2', '8', '20', '30', 'deep_pink']
# ------------------------------------
# 168.png
# ['rect', '10', '3', '70', '50', 'red', 'rect', '10', '10', '70', '110', 'red', 'rect', '2', '1', '90', '30', 'red', 'rect', '6', '10', '100', '90', 'red']
# ['rect', '6', '10', '100', '50', 'deep_pink', 'rect', '2', '1', '90', '30', 'pink', 'rect', '10', '10', '40', '100', 'lime', 'rect', '10', '3', '100', '50', 'red']
# ------------------------------------
# 15.png
# ['circle', '10', '8', '70', 'red', 'circle', '4', '10', '120', 'red', 'circle', '5', '2', '60', 'red', 'circle', '6', '7', '110', 'red', 'circle', '5', '4', '100', 'red', 'circle', '8', '9', '40', 'red', 'circle', '10', '5', '100', 'red', 'circle', '5', '7', '100', 'red', 'circle', '5', '4', '100', 'red', 'circle', '5', '7', '90', 'red']
# ['circle', '10', '8', '70', 'green', 'circle', '10', '5', '100', 'green', 'circle', '4', '10', '110', 'yellow', 'circle', '4', '5', '60', 'orange', 'circle', '5', '3', '60', 'yellow', 'circle', '6', '7', '110', 'yellow', 'circle', '10', '1', '100', 'purple', 'circle', '5', '4', '100', 'cyan', 'circle', '5', '7', '90', 'lime', 'circle', '8', '9', '40', 'deep_pink']
# ------------------------------------
# 177.png
# ['circle', '4', '2', '100', 'red', 'circle', '3', '8', '30', 'red', 'rect', '7', '4', '100', '70', 'red', 'rect', '1', '1', '110', '30', 'red']
# ['circle', '3', '8', '30', 'green', 'circle', '4', '2', '100', 'spring_green', 'rect', '7', '4', '100', '70', 'spring_green', 'rect', '1', '1', '110', '30', 'yellow']
# ------------------------------------
# 543.png
# ['circle', '7', '3', '40', 'red', 'circle', '6', '8', '40', 'red', 'circle', '9', '4', '100', 'red', 'rect', '9', '8', '70', '70', 'red']
# ['circle', '7', '3', '40', 'red', 'circle', '6', '8', '40', 'spring_green', 'circle', '9', '4', '100', 'pink', 'rect', '9', '8', '70', '70', 'cyan']
# ------------------------------------
# 582.png
# ['circle', '5', '2', '60', 'red', 'circle', '8', '1', '80', 'red', 'rect', '10', '10', '20', '30', 'red', 'rect', '3', '3', '30', '100', 'red']
# ['circle', '5', '2', '60', 'lime', 'circle', '8', '1', '80', 'lime', 'rect', '10', '10', '20', '80', 'yellow', 'rect', '3', '3', '30', '100', 'spring_green']
# ------------------------------------
# 214.png
# ['circle', '2', '7', '20', 'red', 'circle', '8', '6', '90', 'red', 'rect', '6', '6', '110', '40', 'red', 'rect', '1', '10', '40', '30', 'red', 'rect', '6', '4', '60', '60', 'red', 'rect', '1', '2', '30', '80', 'red', 'rect', '6', '6', '110', '40', 'red', 'rect', '6', '4', '60', '60', 'red', 'rect', '1', '10', '40', '90', 'red', 'rect', '8', '2', '110', '50', 'red']
# ['circle', '8', '6', '90', 'cyan', 'circle', '2', '7', '20', 'skyblue', 'rect', '5', '10', '110', '90', 'skyblue', 'rect', '1', '4', '20', '50', 'purple', 'rect', '1', '1', '70', '50', 'blue', 'rect', '6', '4', '60', '60', 'purple', 'rect', '1', '10', '40', '100', 'pink', 'rect', '6', '6', '110', '50', 'blue', 'rect', '6', '6', '60', '40', 'pink', 'rect', '8', '2', '110', '50', 'blue']
# ------------------------------------
# 593.png
# ['circle', '6', '4', '30', 'red', 'circle', '6', '1', '60', 'red', 'rect', '2', '6', '80', '90', 'red', 'rect', '9', '2', '90', '100', 'red']
# ['circle', '6', '4', '30', 'green', 'circle', '6', '1', '60', 'cyan', 'rect', '9', '2', '90', '100', 'deep_pink', 'rect', '2', '6', '80', '90', 'purple']
# ------------------------------------
# 402.png
# ['circle', '5', '10', '30', 'red', 'circle', '5', '6', '60', 'red', 'circle', '1', '8', '80', 'red', 'circle', '2', '1', '80', 'red', 'rect', '6', '2', '50', '50', 'red', 'rect', '3', '6', '70', '70', 'red', 'rect', '7', '4', '40', '60', 'red', 'rect', '5', '7', '70', '70', 'red', 'rect', '6', '1', '50', '60', 'red', 'rect', '2', '2', '80', '40', 'red']
# ['circle', '2', '1', '80', 'red', 'circle', '4', '10', '80', 'deep_pink', 'circle', '1', '8', '80', 'skyblue', 'circle', '5', '6', '60', 'skyblue', 'rect', '2', '2', '80', '40', 'pink', 'rect', '7', '4', '50', '60', 'red', 'rect', '3', '6', '70', '70', 'blue', 'rect', '6', '2', '50', '50', 'lime', 'rect', '5', '7', '70', '70', 'purple', 'rect', '6', '1', '50', '60', 'deep_pink']
# ------------------------------------
# 646.png
# ['circle', '4', '2', '20', 'red', 'circle', '1', '10', '60', 'red', 'circle', '10', '6', '50', 'red', 'circle', '2', '9', '50', 'red', 'circle', '4', '9', '120', 'red', 'rect', '5', '2', '30', '40', 'red', 'rect', '3', '10', '100', '90', 'red']
# ['circle', '4', '2', '20', 'blue', 'circle', '4', '9', '120', 'blue', 'circle', '2', '9', '50', 'pink', 'circle', '1', '10', '60', 'pink', 'circle', '10', '6', '50', 'green', 'rect', '3', '10', '100', '30', 'cyan', 'rect', '5', '2', '30', '40', 'orange']
# ------------------------------------
# 503.png
# ['circle', '10', '2', '50', 'red', 'circle', '10', '8', '30', 'red', 'circle', '3', '9', '50', 'red', 'circle', '8', '6', '50', 'red', 'circle', '3', '7', '50', 'red', 'rect', '6', '7', '30', '40', 'red', 'rect', '2', '10', '110', '90', 'red', 'rect', '10', '2', '110', '100', 'red', 'rect', '6', '3', '100', '70', 'red', 'rect', '8', '1', '70', '90', 'red']
# ['circle', '10', '8', '30', 'skyblue', 'circle', '3', '9', '50', 'orange', 'circle', '8', '6', '50', 'lime', 'circle', '3', '7', '50', 'red', 'circle', '9', '2', '60', 'lime', 'rect', '10', '3', '120', '100', 'pink', 'rect', '2', '10', '110', '60', 'deep_pink', 'rect', '8', '1', '70', '90', 'spring_green', 'rect', '6', '3', '100', '70', 'red', 'rect', '6', '7', '20', '40', 'pink']
# ------------------------------------
# 939.png
# ['circle', '1', '9', '100', 'red', 'circle', '3', '2', '40', 'red', 'circle', '2', '3', '90', 'red', 'rect', '3', '9', '30', '30', 'red', 'rect', '7', '7', '90', '100', 'red', 'rect', '7', '9', '80', '70', 'red', 'rect', '8', '4', '50', '50', 'red', 'rect', '5', '2', '50', '30', 'red', 'rect', '3', '7', '20', '110', 'red', 'rect', '3', '9', '60', '20', 'red']
# ['circle', '1', '9', '90', 'purple', 'circle', '3', '2', '40', 'spring_green', 'circle', '2', '3', '90', 'yellow', 'rect', '3', '9', '50', '50', 'green', 'rect', '3', '7', '20', '110', 'cyan', 'rect', '5', '2', '50', '30', 'pink', 'rect', '3', '9', '50', '20', 'deep_pink', 'rect', '8', '4', '50', '50', 'lime', 'rect', '7', '9', '80', '70', 'blue', 'rect', '7', '7', '100', '100', 'deep_pink']
# ------------------------------------
# 274.png
# ['circle', '10', '6', '90', 'red', 'circle', '6', '6', '40', 'red', 'rect', '4', '8', '50', '100', 'red', 'rect', '7', '8', '30', '50', 'red', 'rect', '6', '5', '110', '120', 'red', 'rect', '1', '6', '50', '90', 'red', 'rect', '4', '7', '90', '110', 'red']
# ['circle', '10', '6', '90', 'red', 'circle', '7', '6', '50', 'lime', 'rect', '1', '6', '50', '90', 'pink', 'rect', '6', '5', '110', '120', 'purple', 'rect', '7', '8', '30', '50', 'blue', 'rect', '4', '7', '90', '110', 'purple', 'rect', '4', '9', '50', '50', 'purple']
# ------------------------------------
# 466.png
# ['circle', '1', '3', '120', 'red', 'circle', '6', '5', '90', 'red', 'circle', '8', '2', '90', 'red', 'circle', '10', '9', '90', 'red', 'circle', '4', '7', '60', 'red', 'circle', '6', '1', '100', 'red', 'rect', '5', '3', '30', '30', 'red']
# ['circle', '6', '5', '90', 'red', 'circle', '10', '9', '30', 'red', 'circle', '10', '9', '90', 'red', 'circle', '4', '7', '60', 'skyblue', 'circle', '1', '3', '120', 'orange', 'circle', '8', '2', '90', 'deep_pink', 'circle', '5', '1', '100', 'green']
# ------------------------------------
# 347.png
# ['rect', '4', '2', '30', '60', 'red', 'rect', '10', '4', '70', '80', 'red', 'rect', '7', '9', '40', '40', 'red', 'rect', '1', '5', '100', '50', 'red', 'rect', '10', '9', '30', '60', 'red', 'rect', '7', '2', '90', '30', 'red', 'rect', '4', '4', '50', '20', 'red']
# ['rect', '7', '9', '40', '40', 'red', 'rect', '10', '9', '20', '60', 'cyan', 'rect', '7', '2', '90', '30', 'cyan', 'rect', '1', '5', '100', '50', 'green', 'rect', '10', '4', '30', '80', 'cyan', 'rect', '4', '2', '30', '60', 'spring_green', 'rect', '4', '4', '50', '20', 'purple']
# ------------------------------------
# 34.png
# ['circle', '9', '8', '60', 'red', 'circle', '4', '4', '50', 'red', 'circle', '3', '5', '90', 'red', 'circle', '10', '3', '40', 'red']
# ['circle', '4', '4', '50', 'blue', 'circle', '10', '3', '40', 'deep_pink', 'circle', '9', '8', '60', 'red', 'circle', '3', '5', '90', 'purple']
# ------------------------------------
# 604.png
# ['rect', '5', '10', '40', '90', 'red', 'rect', '5', '8', '40', '90', 'red', 'rect', '5', '5', '70', '110', 'red', 'rect', '5', '10', '30', '90', 'red', 'rect', '5', '5', '70', '110', 'red', 'rect', '5', '7', '80', '70', 'red', 'rect', '9', '9', '110', '110', 'red', 'rect', '4', '1', '30', '70', 'red', 'rect', '10', '5', '60', '110', 'red', 'rect', '7', '9', '90', '90', 'red']
# ['rect', '6', '5', '120', '110', 'orange', 'rect', '10', '5', '100', '110', 'cyan', 'rect', '1', '9', '50', '30', 'deep_pink', 'rect', '5', '10', '40', '110', 'yellow', 'rect', '9', '9', '90', '80', 'cyan', 'rect', '5', '8', '40', '90', 'lime', 'rect', '5', '7', '70', '70', 'cyan', 'rect', '5', '5', '90', '60', 'lime', 'rect', '7', '10', '90', '20', 'purple', 'rect', '4', '1', '40', '70', 'spring_green']
# ------------------------------------
# 491.png
# ['circle', '1', '8', '30', 'red', 'circle', '6', '3', '120', 'red', 'circle', '1', '9', '90', 'red', 'circle', '5', '1', '80', 'red']
# ['circle', '6', '3', '120', 'deep_pink', 'circle', '1', '8', '20', 'purple', 'circle', '5', '1', '80', 'deep_pink', 'circle', '1', '9', '90', 'red']
# ------------------------------------
# 145.png
# ['circle', '8', '4', '80', 'red', 'circle', '1', '1', '60', 'red', 'circle', '9', '4', '20', 'red', 'rect', '4', '7', '50', '30', 'red']
# ['circle', '8', '4', '80', 'red', 'circle', '1', '1', '60', 'deep_pink', 'circle', '9', '4', '20', 'lime', 'rect', '4', '7', '60', '30', 'red']
# ------------------------------------
# 84.png
# ['rect', '6', '7', '100', '60', 'red', 'rect', '6', '7', '90', '60', 'red', 'rect', '4', '2', '20', '50', 'red', 'rect', '2', '9', '80', '40', 'red', 'rect', '6', '10', '40', '30', 'red', 'rect', '6', '9', '70', '30', 'red', 'rect', '8', '10', '90', '60', 'red', 'rect', '7', '4', '70', '50', 'red', 'rect', '1', '9', '50', '40', 'red', 'rect', '8', '10', '90', '60', 'red']
# ['rect', '6', '7', '100', '60', 'green', 'rect', '2', '10', '80', '50', 'skyblue', 'rect', '6', '8', '70', '110', 'spring_green', 'rect', '8', '10', '90', '80', 'deep_pink', 'rect', '1', '9', '50', '40', 'green', 'rect', '6', '9', '50', '30', 'lime', 'rect', '7', '4', '70', '50', 'skyblue', 'rect', '6', '9', '30', '70', 'lime', 'rect', '6', '10', '30', '110', 'cyan', 'rect', '4', '2', '20', '50', 'blue']
# ------------------------------------
# 712.png
# ['circle', '9', '8', '90', 'red', 'circle', '10', '4', '40', 'red', 'circle', '10', '8', '40', 'red', 'circle', '3', '6', '90', 'red', 'circle', '2', '8', '40', 'red', 'circle', '2', '1', '50', 'red', 'circle', '6', '9', '100', 'red', 'circle', '4', '10', '120', 'red', 'circle', '2', '8', '40', 'red', 'rect', '3', '10', '40', '80', 'red']
# ['circle', '2', '8', '40', 'orange', 'circle', '10', '4', '40', 'cyan', 'circle', '3', '6', '80', 'red', 'circle', '9', '8', '90', 'skyblue', 'circle', '10', '9', '40', 'orange', 'circle', '6', '9', '100', 'yellow', 'circle', '5', '10', '70', 'lime', 'circle', '4', '10', '110', 'skyblue', 'circle', '3', '8', '40', 'skyblue', 'circle', '2', '1', '50', 'skyblue']
# ------------------------------------
# 719.png
# ['circle', '5', '5', '50', 'red', 'circle', '7', '3', '50', 'red', 'rect', '2', '6', '70', '60', 'red', 'rect', '2', '1', '30', '90', 'red', 'rect', '6', '4', '60', '80', 'red', 'rect', '9', '1', '110', '80', 'red', 'rect', '3', '6', '50', '70', 'red']
# ['circle', '7', '3', '50', 'pink', 'circle', '5', '5', '50', 'red', 'rect', '2', '1', '30', '90', 'green', 'rect', '6', '4', '60', '80', 'pink', 'rect', '3', '6', '50', '70', 'green', 'rect', '2', '6', '40', '60', 'skyblue', 'rect', '9', '1', '100', '80', 'lime']
# ------------------------------------
# 432.png
# ['circle', '6', '1', '90', 'red', 'circle', '1', '4', '50', 'red', 'circle', '5', '5', '80', 'red', 'circle', '7', '5', '40', 'red', 'rect', '6', '3', '80', '80', 'red', 'rect', '2', '8', '40', '40', 'red', 'rect', '7', '4', '110', '100', 'red', 'rect', '7', '5', '110', '110', 'red', 'rect', '1', '1', '80', '110', 'red', 'rect', '7', '1', '70', '100', 'red']
# ['circle', '7', '5', '50', 'green', 'circle', '5', '5', '80', 'red', 'circle', '6', '1', '90', 'spring_green', 'circle', '1', '4', '50', 'purple', 'rect', '6', '3', '80', '80', 'purple', 'rect', '7', '1', '70', '100', 'lime', 'rect', '7', '5', '110', '110', 'red', 'rect', '1', '1', '80', '110', 'lime', 'rect', '2', '8', '40', '40', 'red', 'rect', '8', '4', '100', '80', 'pink']
# ------------------------------------
# 252.png
# ['circle', '4', '1', '120', 'red', 'circle', '5', '9', '60', 'red', 'circle', '9', '10', '80', 'red', 'circle', '8', '6', '80', 'red', 'circle', '1', '10', '90', 'red', 'circle', '4', '1', '60', 'red', 'circle', '3', '1', '40', 'red']
# ['circle', '5', '9', '60', 'green', 'circle', '3', '10', '50', 'red', 'circle', '8', '6', '80', 'spring_green', 'circle', '4', '1', '120', 'yellow', 'circle', '9', '10', '80', 'lime', 'circle', '1', '9', '80', 'deep_pink', 'circle', '4', '1', '60', 'pink']
# ------------------------------------
# 166.png
# ['circle', '2', '5', '120', 'red', 'circle', '8', '9', '40', 'red', 'circle', '7', '7', '70', 'red', 'circle', '3', '9', '100', 'red', 'circle', '5', '7', '100', 'red', 'rect', '5', '3', '70', '40', 'red', 'rect', '5', '6', '110', '30', 'red', 'rect', '8', '5', '90', '90', 'red', 'rect', '5', '1', '50', '50', 'red', 'rect', '1', '6', '40', '60', 'red']
# ['circle', '2', '5', '120', 'blue', 'circle', '5', '7', '100', 'skyblue', 'circle', '8', '9', '40', 'spring_green', 'circle', '3', '9', '100', 'lime', 'circle', '7', '7', '70', 'green', 'rect', '5', '6', '100', '30', 'red', 'rect', '1', '6', '40', '60', 'red', 'rect', '5', '3', '70', '40', 'yellow', 'rect', '8', '5', '90', '90', 'pink', 'rect', '5', '1', '50', '50', 'spring_green']
# ------------------------------------
# 552.png
# ['rect', '9', '3', '110', '110', 'red', 'rect', '9', '3', '110', '110', 'red', 'rect', '3', '4', '90', '60', 'red', 'rect', '7', '8', '100', '20', 'red', 'rect', '8', '10', '70', '90', 'red', 'rect', '4', '1', '40', '60', 'red', 'rect', '6', '6', '20', '70', 'red', 'rect', '9', '4', '100', '90', 'red', 'rect', '7', '8', '100', '20', 'red', 'rect', '3', '10', '70', '90', 'red']
# ['rect', '6', '6', '20', '70', 'lime', 'rect', '10', '3', '40', '90', 'purple', 'rect', '9', '6', '60', '90', 'red', 'rect', '3', '10', '70', '80', 'skyblue', 'rect', '7', '8', '100', '20', 'orange', 'rect', '9', '3', '100', '110', 'lime', 'rect', '8', '4', '90', '90', 'cyan', 'rect', '3', '4', '50', '60', 'cyan', 'rect', '8', '10', '70', '100', 'pink', 'rect', '4', '1', '40', '60', 'purple']
# ------------------------------------
# 253.png
# ['circle', '1', '10', '100', 'red', 'circle', '6', '9', '100', 'red', 'circle', '3', '8', '40', 'red', 'rect', '7', '8', '80', '100', 'red', 'rect', '8', '7', '110', '90', 'red', 'rect', '6', '8', '30', '110', 'red', 'rect', '2', '10', '100', '40', 'red']
# ['circle', '3', '8', '40', 'red', 'circle', '6', '9', '100', 'purple', 'circle', '1', '10', '110', 'spring_green', 'rect', '2', '10', '100', '80', 'blue', 'rect', '8', '7', '110', '90', 'skyblue', 'rect', '7', '8', '50', '100', 'purple', 'rect', '6', '8', '30', '110', 'red']
# ------------------------------------
# 768.png
# ['circle', '4', '10', '40', 'red', 'circle', '9', '9', '80', 'red', 'circle', '4', '2', '70', 'red', 'circle', '4', '8', '90', 'red', 'rect', '4', '4', '110', '100', 'red', 'rect', '3', '2', '40', '50', 'red', 'rect', '5', '1', '30', '30', 'red']
# ['circle', '9', '9', '70', 'skyblue', 'circle', '4', '10', '40', 'red', 'circle', '4', '2', '60', 'orange', 'circle', '4', '8', '90', 'cyan', 'rect', '5', '1', '30', '30', 'spring_green', 'rect', '4', '4', '110', '100', 'purple', 'rect', '3', '2', '40', '50', 'deep_pink']
# ------------------------------------
# 272.png
# ['circle', '10', '8', '100', 'red', 'circle', '7', '4', '50', 'red', 'circle', '6', '9', '80', 'red', 'rect', '9', '4', '70', '70', 'red']
# ['circle', '6', '9', '80', 'deep_pink', 'circle', '7', '4', '50', 'red', 'circle', '10', '8', '90', 'blue', 'rect', '9', '4', '70', '70', 'cyan']
# ------------------------------------
# 963.png
# ['circle', '1', '5', '100', 'red', 'circle', '1', '3', '30', 'red', 'circle', '10', '4', '20', 'red', 'circle', '3', '6', '60', 'red', 'circle', '8', '2', '30', 'red', 'rect', '6', '5', '20', '90', 'red', 'rect', '8', '5', '20', '100', 'red']
# ['circle', '1', '5', '100', 'yellow', 'circle', '1', '3', '40', 'blue', 'circle', '3', '6', '60', 'cyan', 'circle', '10', '4', '20', 'spring_green', 'circle', '8', '2', '30', 'yellow', 'rect', '6', '5', '20', '90', 'orange', 'rect', '8', '5', '20', '100', 'deep_pink']
# ------------------------------------
# 200.png
# ['circle', '10', '9', '70', 'red', 'circle', '6', '1', '120', 'red', 'circle', '1', '1', '80', 'red', 'circle', '10', '10', '40', 'red', 'rect', '4', '4', '110', '30', 'red', 'rect', '9', '6', '110', '60', 'red', 'rect', '10', '7', '60', '110', 'red', 'rect', '1', '8', '60', '40', 'red', 'rect', '4', '8', '80', '90', 'red', 'rect', '2', '1', '40', '110', 'red']
# ['circle', '10', '9', '70', 'purple', 'circle', '6', '1', '120', 'pink', 'circle', '1', '1', '70', 'lime', 'circle', '10', '10', '30', 'red', 'rect', '4', '8', '80', '90', 'orange', 'rect', '9', '6', '110', '60', 'red', 'rect', '2', '1', '40', '110', 'green', 'rect', '1', '8', '60', '40', 'spring_green', 'rect', '4', '4', '110', '30', 'spring_green', 'rect', '10', '7', '60', '110', 'deep_pink']
# ------------------------------------
# 284.png
# ['rect', '6', '10', '90', '30', 'red', 'rect', '2', '8', '60', '40', 'red', 'rect', '6', '7', '30', '110', 'red', 'rect', '7', '3', '70', '80', 'red', 'rect', '3', '7', '60', '80', 'red', 'rect', '2', '8', '80', '40', 'red', 'rect', '6', '5', '90', '40', 'red', 'rect', '4', '5', '80', '40', 'red', 'rect', '8', '6', '90', '90', 'red', 'rect', '7', '2', '80', '110', 'red']
# ['rect', '6', '7', '30', '110', 'red', 'rect', '1', '8', '50', '110', 'deep_pink', 'rect', '3', '7', '60', '80', 'red', 'rect', '7', '2', '70', '100', 'purple', 'rect', '2', '8', '80', '40', 'lime', 'rect', '7', '2', '80', '110', 'red', 'rect', '4', '5', '80', '40', 'green', 'rect', '6', '10', '90', '40', 'purple', 'rect', '8', '6', '90', '90', 'deep_pink', 'rect', '2', '9', '60', '120', 'spring_green']
# ------------------------------------
# 32.png
# ['rect', '9', '8', '100', '100', 'red', 'rect', '2', '1', '30', '90', 'red', 'rect', '9', '8', '40', '100', 'red', 'rect', '4', '4', '110', '110', 'red', 'rect', '3', '4', '90', '110', 'red', 'rect', '9', '8', '50', '100', 'red', 'rect', '10', '10', '40', '50', 'red']
# ['rect', '2', '1', '30', '90', 'yellow', 'rect', '3', '4', '90', '110', 'purple', 'rect', '9', '10', '40', '60', 'spring_green', 'rect', '4', '3', '110', '90', 'green', 'rect', '10', '8', '80', '40', 'red', 'rect', '10', '9', '30', '80', 'cyan', 'rect', '9', '8', '80', '100', 'blue']
# ------------------------------------
# 227.png
# ['circle', '10', '7', '30', 'red', 'circle', '2', '8', '120', 'red', 'circle', '4', '3', '100', 'red', 'circle', '9', '2', '30', 'red', 'rect', '10', '1', '80', '40', 'red', 'rect', '3', '5', '100', '30', 'red', 'rect', '4', '9', '70', '50', 'red']
# ['circle', '4', '3', '100', 'lime', 'circle', '10', '7', '30', 'cyan', 'circle', '1', '8', '120', 'lime', 'circle', '9', '2', '30', 'lime', 'rect', '4', '9', '70', '50', 'skyblue', 'rect', '10', '1', '50', '40', 'orange', 'rect', '3', '5', '100', '30', 'spring_green']
# ------------------------------------
# 224.png
# ['circle', '1', '7', '90', 'red', 'circle', '5', '3', '90', 'red', 'circle', '3', '6', '90', 'red', 'circle', '7', '1', '120', 'red', 'circle', '4', '7', '90', 'red', 'rect', '1', '4', '110', '60', 'red', 'rect', '5', '10', '110', '30', 'red']
# ['circle', '5', '3', '90', 'purple', 'circle', '1', '7', '90', 'cyan', 'circle', '3', '7', '90', 'green', 'circle', '4', '6', '90', 'green', 'circle', '7', '1', '120', 'spring_green', 'rect', '1', '4', '110', '60', 'orange', 'rect', '6', '10', '110', '40', 'green']
# ------------------------------------
# 388.png
# ['rect', '10', '6', '70', '80', 'red', 'rect', '3', '8', '70', '40', 'red', 'rect', '5', '5', '20', '30', 'red', 'rect', '1', '5', '100', '60', 'red']
# ['rect', '10', '6', '90', '80', 'spring_green', 'rect', '1', '5', '100', '60', 'yellow', 'rect', '3', '8', '70', '40', 'orange', 'rect', '5', '5', '20', '30', 'yellow']
# ------------------------------------
# 310.png
# ['circle', '9', '6', '60', 'red', 'circle', '5', '9', '100', 'red', 'circle', '2', '3', '110', 'red', 'circle', '4', '10', '20', 'red']
# ['circle', '5', '9', '100', 'lime', 'circle', '9', '6', '60', 'green', 'circle', '2', '3', '110', 'orange', 'circle', '3', '10', '20', 'blue']
# ------------------------------------
# 363.png
# ['rect', '8', '9', '110', '100', 'red', 'rect', '1', '10', '90', '60', 'red', 'rect', '8', '6', '110', '80', 'red', 'rect', '6', '4', '100', '120', 'red', 'rect', '4', '3', '90', '90', 'red', 'rect', '5', '4', '80', '120', 'red', 'rect', '10', '6', '70', '110', 'red', 'rect', '1', '10', '90', '60', 'red', 'rect', '4', '6', '90', '30', 'red', 'rect', '9', '9', '100', '100', 'red']
# ['rect', '8', '6', '110', '80', 'spring_green', 'rect', '1', '4', '110', '50', 'red', 'rect', '1', '9', '80', '100', 'deep_pink', 'rect', '9', '9', '80', '90', 'spring_green', 'rect', '6', '4', '100', '120', 'red', 'rect', '8', '1', '30', '90', 'purple', 'rect', '10', '6', '50', '110', 'orange', 'rect', '5', '3', '80', '90', 'red', 'rect', '4', '10', '100', '90', 'yellow', 'rect', '4', '6', '90', '30', 'blue']
# ------------------------------------
# 13.png
# ['circle', '2', '4', '50', 'red', 'circle', '9', '6', '60', 'red', 'circle', '1', '3', '110', 'red', 'circle', '7', '5', '120', 'red', 'circle', '8', '2', '70', 'red', 'circle', '9', '2', '90', 'red', 'rect', '5', '1', '50', '50', 'red']
# ['circle', '2', '4', '50', 'lime', 'circle', '8', '2', '80', 'deep_pink', 'circle', '9', '6', '60', 'pink', 'circle', '7', '5', '120', 'spring_green', 'circle', '1', '3', '110', 'skyblue', 'circle', '9', '2', '90', 'red', 'rect', '5', '1', '50', '50', 'blue']
# ------------------------------------
# 551.png
# ['circle', '5', '6', '100', 'red', 'circle', '7', '3', '70', 'red', 'circle', '2', '8', '30', 'red', 'rect', '10', '7', '20', '100', 'red', 'rect', '8', '9', '60', '50', 'red', 'rect', '5', '1', '30', '30', 'red', 'rect', '8', '9', '60', '50', 'red', 'rect', '5', '9', '60', '90', 'red', 'rect', '4', '4', '110', '50', 'red', 'rect', '10', '7', '20', '100', 'red']
# ['circle', '7', '3', '70', 'purple', 'circle', '2', '8', '30', 'lime', 'circle', '5', '6', '100', 'purple', 'rect', '5', '1', '30', '30', 'lime', 'rect', '10', '8', '20', '90', 'orange', 'rect', '4', '4', '60', '50', 'purple', 'rect', '5', '9', '60', '90', 'deep_pink', 'rect', '10', '9', '50', '100', 'pink', 'rect', '8', '5', '100', '100', 'blue', 'rect', '8', '9', '60', '50', 'skyblue']
# ------------------------------------
# 615.png
# ['circle', '6', '5', '30', 'red', 'circle', '9', '9', '90', 'red', 'circle', '2', '2', '110', 'red', 'circle', '6', '9', '30', 'red', 'rect', '8', '9', '30', '80', 'red', 'rect', '4', '5', '110', '110', 'red', 'rect', '9', '4', '30', '120', 'red']
# ['circle', '9', '9', '90', 'green', 'circle', '2', '2', '110', 'skyblue', 'circle', '6', '5', '40', 'red', 'circle', '6', '9', '30', 'orange', 'rect', '8', '9', '40', '80', 'skyblue', 'rect', '4', '5', '110', '120', 'red', 'rect', '9', '4', '30', '120', 'blue']
# ------------------------------------
# ...
# ['circle', '4', '3', '90', 'green', 'circle', '7', '2', '20', 'spring_green', 'circle', '6', '4', '70', 'cyan', 'rect', '9', '10', '70', '110', 'deep_pink', 'rect', '4', '10', '110', '50', 'lime', 'rect', '8', '8', '90', '120', 'red', 'rect', '3', '8', '70', '60', 'pink', 'rect', '5', '6', '110', '50', 'blue', 'rect', '2', '7', '40', '110', 'orange', 'rect', '2', '9', '110', '60', 'blue']
# ------------------------------------
# 716.png
# ['circle', '8', '6', '90', 'red', 'circle', '5', '8', '80', 'red', 'circle', '7', '8', '80', 'red', 'rect', '5', '4', '60', '100', 'red', 'rect', '10', '7', '110', '90', 'red', 'rect', '5', '5', '60', '40', 'red', 'rect', '6', '10', '110', '40', 'red']
# ['circle', '8', '6', '90', 'red', 'circle', '5', '8', '70', 'deep_pink', 'circle', '7', '8', '80', 'pink', 'rect', '5', '4', '60', '90', 'red', 'rect', '5', '5', '60', '40', 'green', 'rect', '10', '7', '90', '90', 'lime', 'rect', '6', '10', '110', '100', 'red']
# ------------------------------------
# 758.png
# ['circle', '4', '6', '120', 'red', 'rect', '10', '4', '30', '100', 'red', 'rect', '10', '6', '30', '60', 'red', 'rect', '6', '6', '50', '110', 'red', 'rect', '5', '3', '30', '20', 'red', 'rect', '9', '9', '30', '50', 'red', 'rect', '6', '6', '50', '110', 'red', 'rect', '10', '8', '30', '70', 'red', 'rect', '9', '9', '30', '50', 'red', 'rect', '8', '1', '90', '30', 'red']
# ['circle', '4', '6', '120', 'blue', 'rect', '9', '9', '20', '50', 'purple', 'rect', '10', '6', '30', '80', 'cyan', 'rect', '6', '6', '20', '60', 'deep_pink', 'rect', '10', '4', '80', '100', 'skyblue', 'rect', '8', '1', '90', '30', 'orange', 'rect', '10', '7', '70', '70', 'orange', 'rect', '6', '6', '50', '100', 'blue', 'rect', '9', '9', '30', '50', 'skyblue', 'rect', '5', '3', '30', '20', 'blue']
# ------------------------------------
# 98.png
# ['circle', '10', '7', '100', 'red', 'circle', '6', '5', '60', 'red', 'circle', '8', '5', '100', 'red', 'circle', '7', '7', '30', 'red', 'rect', '9', '8', '40', '20', 'red', 'rect', '9', '2', '110', '120', 'red', 'rect', '6', '8', '50', '110', 'red']
# ['circle', '7', '7', '30', 'spring_green', 'circle', '10', '6', '90', 'green', 'circle', '6', '5', '60', 'blue', 'circle', '8', '5', '100', 'spring_green', 'rect', '9', '8', '40', '20', 'skyblue', 'rect', '9', '2', '100', '120', 'cyan', 'rect', '6', '8', '50', '110', 'yellow']
# ------------------------------------
# 107.png
# ['rect', '5', '3', '70', '110', 'red', 'rect', '6', '9', '90', '30', 'red', 'rect', '8', '3', '80', '110', 'red', 'rect', '4', '8', '80', '30', 'red', 'rect', '6', '9', '80', '30', 'red', 'rect', '10', '5', '110', '90', 'red', 'rect', '8', '5', '30', '100', 'red', 'rect', '7', '1', '80', '20', 'red', 'rect', '3', '3', '70', '90', 'red', 'rect', '5', '5', '90', '30', 'red']
# ['rect', '3', '3', '70', '90', 'red', 'rect', '5', '3', '60', '110', 'orange', 'rect', '4', '8', '70', '30', 'lime', 'rect', '6', '9', '90', '30', 'cyan', 'rect', '8', '3', '80', '110', 'purple', 'rect', '4', '8', '50', '100', 'pink', 'rect', '6', '6', '90', '70', 'skyblue', 'rect', '8', '5', '30', '100', 'red', 'rect', '7', '1', '80', '20', 'red', 'rect', '10', '4', '50', '90', 'orange']
# ------------------------------------
# 975.png
# ['circle', '9', '7', '80', 'red', 'rect', '5', '5', '80', '30', 'red', 'rect', '5', '10', '50', '90', 'red', 'rect', '2', '1', '20', '90', 'red', 'rect', '4', '6', '80', '30', 'red', 'rect', '6', '5', '80', '30', 'red', 'rect', '9', '10', '40', '90', 'red']
# ['circle', '9', '7', '80', 'cyan', 'rect', '9', '10', '40', '70', 'pink', 'rect', '2', '1', '20', '90', 'deep_pink', 'rect', '5', '5', '80', '80', 'cyan', 'rect', '4', '6', '60', '30', 'blue', 'rect', '5', '10', '50', '20', 'pink', 'rect', '6', '5', '80', '30', 'deep_pink']
# ------------------------------------
# 889.png
# ['rect', '8', '4', '60', '110', 'red', 'rect', '3', '9', '30', '90', 'red', 'rect', '2', '6', '30', '60', 'red', 'rect', '7', '7', '60', '30', 'red', 'rect', '5', '6', '30', '50', 'red', 'rect', '9', '8', '90', '40', 'red', 'rect', '3', '10', '30', '90', 'red', 'rect', '8', '4', '80', '110', 'red', 'rect', '1', '4', '80', '50', 'red', 'rect', '7', '7', '60', '30', 'red']
# ['rect', '2', '6', '30', '60', 'purple', 'rect', '3', '9', '30', '60', 'spring_green', 'rect', '8', '4', '60', '120', 'red', 'rect', '7', '7', '60', '30', 'cyan', 'rect', '3', '7', '40', '70', 'cyan', 'rect', '3', '10', '30', '120', 'deep_pink', 'rect', '8', '8', '80', '40', 'red', 'rect', '1', '4', '80', '50', 'red', 'rect', '5', '6', '30', '50', 'skyblue', 'rect', '9', '10', '70', '50', 'orange']
# ------------------------------------
# 480.png
# ['circle', '8', '7', '30', 'red', 'circle', '7', '4', '80', 'red', 'circle', '7', '4', '60', 'red', 'circle', '4', '6', '60', 'red', 'circle', '6', '4', '30', 'red', 'circle', '8', '10', '60', 'red', 'circle', '6', '7', '60', 'red', 'circle', '2', '6', '60', 'red', 'circle', '10', '3', '20', 'red', 'circle', '9', '3', '80', 'red']
# ['circle', '10', '4', '20', 'skyblue', 'circle', '7', '5', '80', 'blue', 'circle', '7', '4', '60', 'deep_pink', 'circle', '4', '6', '60', 'green', 'circle', '6', '4', '20', 'blue', 'circle', '2', '6', '60', 'green', 'circle', '8', '10', '60', 'pink', 'circle', '6', '7', '60', 'cyan', 'circle', '8', '7', '30', 'red', 'circle', '9', '3', '80', 'purple']
# ------------------------------------
# 264.png
# ['circle', '5', '1', '80', 'red', 'circle', '10', '1', '70', 'red', 'rect', '6', '3', '90', '70', 'red', 'rect', '6', '3', '30', '30', 'red']
# ['circle', '5', '1', '80', 'green', 'circle', '10', '1', '70', 'red', 'rect', '6', '3', '30', '30', 'cyan', 'rect', '6', '3', '90', '70', 'red']
# ------------------------------------
# 601.png
# ['circle', '5', '8', '50', 'red', 'circle', '4', '3', '50', 'red', 'circle', '10', '4', '40', 'red', 'circle', '1', '2', '70', 'red', 'circle', '2', '10', '110', 'red', 'circle', '4', '4', '100', 'red', 'circle', '6', '7', '90', 'red']
# ['circle', '4', '3', '60', 'blue', 'circle', '5', '8', '50', 'red', 'circle', '1', '2', '40', 'green', 'circle', '6', '7', '30', 'lime', 'circle', '6', '7', '90', 'blue', 'circle', '10', '4', '40', 'skyblue', 'circle', '1', '2', '70', 'yellow', 'circle', '2', '10', '110', 'red', 'circle', '4', '4', '50', 'blue', 'circle', '4', '2', '90', 'red']
# ------------------------------------
# 493.png
# ['rect', '8', '3', '40', '70', 'red', 'rect', '6', '8', '100', '30', 'red', 'rect', '5', '3', '30', '70', 'red', 'rect', '4', '2', '60', '110', 'red']
# ['rect', '4', '2', '60', '110', 'yellow', 'rect', '5', '3', '30', '70', 'lime', 'rect', '6', '8', '100', '30', 'deep_pink', 'rect', '8', '3', '40', '70', 'deep_pink']
# ------------------------------------
# 850.png
# ['circle', '1', '6', '60', 'red', 'rect', '4', '5', '100', '110', 'red', 'rect', '4', '1', '110', '110', 'red', 'rect', '10', '9', '50', '70', 'red', 'rect', '1', '1', '40', '60', 'red', 'rect', '7', '5', '90', '50', 'red', 'rect', '2', '8', '30', '90', 'red', 'rect', '9', '9', '60', '20', 'red', 'rect', '4', '2', '120', '100', 'red', 'rect', '3', '10', '100', '30', 'red']
# ['circle', '1', '6', '60', 'red', 'rect', '1', '1', '50', '60', 'spring_green', 'rect', '2', '8', '30', '90', 'yellow', 'rect', '7', '5', '90', '50', 'red', 'rect', '4', '1', '110', '110', 'orange', 'rect', '4', '2', '120', '100', 'skyblue', 'rect', '4', '5', '100', '110', 'pink', 'rect', '10', '8', '90', '80', 'blue', 'rect', '3', '10', '100', '100', 'green', 'rect', '9', '9', '60', '20', 'spring_green']
# ------------------------------------
# 632.png
# ['circle', '8', '2', '80', 'red', 'circle', '3', '1', '80', 'red', 'circle', '5', '8', '110', 'red', 'rect', '5', '10', '70', '90', 'red', 'rect', '6', '4', '60', '80', 'red', 'rect', '5', '8', '100', '40', 'red', 'rect', '7', '8', '70', '30', 'red']
# ['circle', '8', '2', '80', 'blue', 'circle', '4', '8', '110', 'lime', 'circle', '3', '1', '80', 'pink', 'rect', '5', '8', '100', '40', 'cyan', 'rect', '5', '10', '70', '90', 'red', 'rect', '7', '8', '80', '30', 'spring_green', 'rect', '6', '4', '60', '80', 'yellow']
# ------------------------------------
# 542.png
# ['rect', '7', '6', '70', '110', 'red', 'rect', '6', '1', '40', '40', 'red', 'rect', '6', '8', '60', '60', 'red', 'rect', '7', '10', '60', '80', 'red', 'rect', '6', '4', '60', '50', 'red', 'rect', '2', '4', '100', '40', 'red', 'rect', '9', '6', '90', '20', 'red']
# ['rect', '7', '6', '60', '110', 'yellow', 'rect', '6', '1', '40', '40', 'orange', 'rect', '6', '4', '50', '50', 'blue', 'rect', '2', '4', '100', '40', 'spring_green', 'rect', '6', '8', '70', '60', 'orange', 'rect', '9', '6', '90', '20', 'deep_pink', 'rect', '7', '10', '60', '100', 'spring_green']
# ------------------------------------
# 238.png
# ['circle', '10', '5', '120', 'red', 'circle', '3', '3', '20', 'red', 'circle', '8', '10', '20', 'red', 'rect', '5', '3', '110', '80', 'red']
# ['circle', '3', '3', '20', 'blue', 'circle', '8', '10', '20', 'lime', 'circle', '10', '5', '120', 'pink', 'rect', '5', '3', '110', '80', 'cyan']
# ------------------------------------
# 598.png
# ['rect', '3', '5', '80', '100', 'red', 'rect', '6', '6', '100', '80', 'red', 'rect', '4', '7', '70', '90', 'red', 'rect', '1', '7', '40', '80', 'red']
# ['rect', '3', '5', '80', '100', 'purple', 'rect', '1', '7', '40', '80', 'purple', 'rect', '6', '6', '100', '80', 'blue', 'rect', '4', '7', '70', '90', 'lime']
# ------------------------------------
# 766.png
# ['circle', '1', '9', '40', 'red', 'circle', '3', '2', '20', 'red', 'rect', '10', '8', '110', '40', 'red', 'rect', '1', '7', '40', '110', 'red']
# ['circle', '1', '9', '40', 'purple', 'circle', '3', '2', '20', 'lime', 'rect', '1', '7', '40', '110', 'purple', 'rect', '10', '8', '90', '40', 'cyan']
# ------------------------------------
# 350.png
# ['rect', '3', '5', '100', '90', 'red', 'rect', '7', '8', '40', '20', 'red', 'rect', '8', '10', '120', '30', 'red', 'rect', '4', '4', '60', '70', 'red']
# ['rect', '3', '5', '100', '90', 'purple', 'rect', '7', '8', '40', '20', 'red', 'rect', '8', '10', '110', '70', 'pink', 'rect', '4', '4', '60', '70', 'red']
# ------------------------------------
# 358.png
# ['circle', '8', '7', '40', 'red', 'circle', '8', '1', '70', 'red', 'circle', '3', '5', '30', 'red', 'circle', '8', '7', '40', 'red', 'circle', '9', '5', '30', 'red', 'rect', '6', '9', '70', '30', 'red', 'rect', '10', '6', '70', '80', 'red']
# ['circle', '3', '5', '30', 'cyan', 'circle', '8', '1', '20', 'yellow', 'circle', '8', '7', '40', 'lime', 'circle', '8', '7', '40', 'cyan', 'circle', '8', '1', '70', 'lime', 'circle', '9', '5', '30', 'blue', 'rect', '6', '9', '70', '30', 'purple']
# ------------------------------------
# 585.png
# ['circle', '4', '6', '30', 'red', 'rect', '6', '6', '60', '40', 'red', 'rect', '6', '9', '90', '80', 'red', 'rect', '3', '7', '110', '120', 'red', 'rect', '10', '7', '30', '30', 'red', 'rect', '6', '10', '90', '90', 'red', 'rect', '7', '3', '100', '90', 'red', 'rect', '1', '2', '30', '40', 'red', 'rect', '5', '6', '100', '50', 'red', 'rect', '7', '6', '100', '40', 'red']
# ['circle', '4', '6', '30', 'red', 'rect', '6', '9', '90', '100', 'lime', 'rect', '6', '10', '20', '110', 'cyan', 'rect', '1', '2', '30', '40', 'red', 'rect', '10', '7', '90', '30', 'skyblue', 'rect', '3', '9', '50', '110', 'deep_pink', 'rect', '5', '6', '100', '50', 'green', 'rect', '7', '6', '100', '40', 'pink', 'rect', '3', '7', '120', '120', 'purple', 'rect', '7', '3', '110', '90', 'red']
# ------------------------------------
# 923.png
# ['rect', '7', '10', '100', '60', 'red', 'rect', '3', '6', '40', '50', 'red', 'rect', '9', '8', '50', '60', 'red', 'rect', '6', '1', '90', '80', 'red']
# ['rect', '7', '10', '100', '60', 'yellow', 'rect', '3', '6', '40', '60', 'spring_green', 'rect', '6', '1', '90', '80', 'yellow', 'rect', '9', '8', '50', '60', 'skyblue']
# ------------------------------------
# 424.png
# ['circle', '10', '10', '40', 'red', 'circle', '2', '3', '50', 'red', 'circle', '7', '1', '90', 'red', 'rect', '8', '5', '80', '50', 'red', 'rect', '5', '8', '100', '50', 'red', 'rect', '5', '8', '60', '110', 'red', 'rect', '8', '1', '120', '110', 'red']
# ['circle', '10', '10', '40', 'lime', 'circle', '2', '3', '50', 'yellow', 'circle', '7', '1', '90', 'green', 'rect', '8', '5', '80', '50', 'yellow', 'rect', '5', '8', '110', '50', 'skyblue', 'rect', '5', '8', '60', '110', 'lime', 'rect', '8', '1', '110', '110', 'blue']
# ------------------------------------
# 441.png
# ['circle', '5', '4', '100', 'red', 'circle', '8', '4', '80', 'red', 'circle', '1', '10', '80', 'red', 'circle', '5', '8', '110', 'red', 'circle', '8', '5', '90', 'red', 'circle', '8', '6', '50', 'red', 'circle', '1', '10', '30', 'red', 'circle', '9', '2', '50', 'red', 'circle', '4', '10', '110', 'red', 'rect', '5', '3', '40', '80', 'red']
# ['circle', '5', '4', '100', 'purple', 'circle', '5', '8', '100', 'cyan', 'circle', '8', '4', '80', 'skyblue', 'circle', '9', '2', '50', 'purple', 'circle', '1', '10', '70', 'green', 'circle', '8', '5', '90', 'purple', 'circle', '8', '6', '50', 'pink', 'circle', '4', '10', '110', 'orange', 'circle', '1', '8', '30', 'blue', 'rect', '5', '3', '40', '80', 'red']
# ------------------------------------
# 787.png
# ['circle', '5', '4', '80', 'red', 'rect', '10', '9', '70', '100', 'red', 'rect', '2', '6', '100', '30', 'red', 'rect', '4', '10', '30', '30', 'red', 'rect', '7', '6', '20', '50', 'red', 'rect', '1', '1', '40', '60', 'red', 'rect', '3', '7', '30', '30', 'red']
# ['circle', '5', '4', '80', 'pink', 'rect', '7', '6', '20', '60', 'spring_green', 'rect', '4', '10', '30', '110', 'red', 'rect', '10', '9', '60', '50', 'red', 'rect', '2', '6', '100', '30', 'blue', 'rect', '1', '1', '40', '60', 'skyblue', 'rect', '3', '7', '20', '30', 'green']
# ------------------------------------
# 416.png
# ['circle', '9', '10', '120', 'red', 'circle', '7', '9', '90', 'red', 'circle', '4', '9', '120', 'red', 'circle', '6', '10', '110', 'red']
# ['circle', '4', '9', '120', 'orange', 'circle', '9', '10', '120', 'green', 'circle', '7', '9', '90', 'red', 'circle', '6', '10', '110', 'blue']
# ------------------------------------
# 966.png
# ['circle', '3', '2', '60', 'red', 'rect', '9', '9', '20', '20', 'red', 'rect', '5', '3', '30', '50', 'red', 'rect', '6', '10', '100', '90', 'red', 'rect', '8', '7', '60', '100', 'red', 'rect', '1', '10', '100', '100', 'red', 'rect', '3', '3', '110', '20', 'red']
# ['circle', '3', '2', '60', 'green', 'rect', '9', '9', '20', '20', 'orange', 'rect', '5', '3', '30', '50', 'red', 'rect', '6', '10', '100', '100', 'yellow', 'rect', '8', '7', '60', '100', 'spring_green', 'rect', '1', '10', '100', '110', 'pink', 'rect', '3', '3', '110', '20', 'green']
# ------------------------------------
# 102.png
# ['circle', '8', '8', '70', 'red', 'rect', '5', '6', '100', '110', 'red', 'rect', '10', '1', '90', '20', 'red', 'rect', '2', '3', '90', '60', 'red', 'rect', '5', '10', '100', '90', 'red', 'rect', '7', '9', '70', '80', 'red', 'rect', '8', '4', '100', '80', 'red']
# ['circle', '8', '8', '70', 'lime', 'rect', '5', '10', '110', '30', 'deep_pink', 'rect', '5', '6', '100', '110', 'cyan', 'rect', '7', '9', '70', '80', 'deep_pink', 'rect', '10', '1', '60', '20', 'red', 'rect', '8', '4', '100', '80', 'orange', 'rect', '2', '3', '90', '70', 'yellow']
# ------------------------------------
# 384.png
# ['circle', '1', '3', '110', 'red', 'circle', '8', '7', '30', 'red', 'circle', '2', '5', '110', 'red', 'circle', '3', '4', '30', 'red', 'circle', '8', '8', '60', 'red', 'circle', '4', '10', '90', 'red', 'circle', '2', '8', '50', 'red']
# ['circle', '1', '4', '120', 'cyan', 'circle', '2', '5', '110', 'skyblue', 'circle', '4', '10', '90', 'lime', 'circle', '3', '4', '30', 'green', 'circle', '8', '9', '60', 'red', 'circle', '8', '7', '30', 'red', 'circle', '2', '8', '50', 'purple']
# ------------------------------------

# %%
        
print('shape match: %.4f, location match: %.4f,location match_rect: %.4f, radius_match: %.4f, rect_x_match: %.4f, rect_y_match: %.4f color_match: %.4f'
     %(shape_match/(len(test_list)*2), location_match/(len(test_list)*2), location_match_rect/(len(test_list)*2),
      radius_match/len(test_list), rect_x_match/len(test_list), rect_y_match/len(test_list), color_match/(len(test_list)*2)))

# %%
x_ = {x:rect_x_err.count(x) for x in rect_x_err}
y_ = {x:rect_y_err.count(x) for x in rect_y_err}
r_ = {x:radius_err.count(x) for x in radius_err}
loc_ ={x:location_err.count(x) for x in location_err}
loc_rect_ = {x:location_err_rect.count(x) for x in location_err_rect}

# %%
loc_

# %%
test_dir = 'data/2object_test/bitmap/'
cap_dir = 'data/2object_test/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

for fname in test_list: 
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))


    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    sentence = ' '.join(sampled_caption)
    print(sentence)
    predict = sentence.split()[1]
    
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    with open(cap_path, 'r') as f:
        target = f.readline()
        print('target: '+ target)
    if predict == target:
        print('corret')
    #    cnt+=1 
        
print(cnt)

# %%
feature.unsqueeze(1)

# %%
cap_path = img_list[0].split('.')[0]+'.svg'

# %%
cap_path
