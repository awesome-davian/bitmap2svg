# %%
import torch
import matplotlib.pyplot as plt
import numpy as np 
import argparse
import pickle 
import os
from torch.autograd import Variable 
from torchvision import transforms 
from data_loader import build_vocab 
from model import EncoderCNN, DecoderRNN
from model import ResNet, ResidualBlock
from PIL import Image
from attn_model import ResidualBlock, AttnEncoder, AttnDecoderRnn


embed_size = 128
hidden_size = 256 
num_layers = 1 
feature_size = 128 

#decoder_path = './models/2object_color/decoder-10-150.pkl'
#encoder_path = './models/2object_color/encoder-10-150.pkl'
decoder_path = './models/attn/2object/decoder-10-150.pkl'
encoder_path = './models/attn/2object/encoder-10-150.pkl'

def to_var(x, volatile=False):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x, volatile=volatile)

def load_image(image_path, transform=None):
    image = Image.open(image_path).convert('RGB')
    image = image.resize([64, 64], Image.LANCZOS)
    
    if transform is not None:
        image = transform(image).unsqueeze(0)
    
    return image

transform = transforms.Compose([ 
    transforms.ToTensor(), 
    transforms.Normalize((0.033, 0.032, 0.033), 
                         (0.027, 0.027, 0.027))])



#vocab_path = './data/vocab_2object_color.pkl'
vocab_path = './data/attn/vocab2.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
len_vocab = vocab.idx

# Build Models
#encoder = ResNet(ResidualBlock, [3, 3, 3], len_vocab)
#encoder.eval()  # evaluation mode (BN uses moving mean/variance)
#decoder = DecoderRNN(len_vocab, hidden_size, len(vocab), num_layers)

encoder = AttnEncoder(ResidualBlock, [3, 3, 3])
encoder.eval()  # evaluation mode (BN uses moving mean/variance)
decoder = AttnDecoderRnn(feature_size, hidden_size, 
                     len(vocab), num_layers)



# Load the trained model parameters
encoder.load_state_dict(torch.load(encoder_path))
decoder.load_state_dict(torch.load(decoder_path))

# If use gpu
if torch.cuda.is_available():
    encoder.cuda()
    decoder.cuda()

# %%
test_dir = 'data/2object_test/bitmap/'
cap_dir = 'data/2object_test/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

shape_match = 0
location_match = 0
location_match_rect= 0 
radius_match = 0 
rect_x_match = 0 
rect_y_match = 0 
color_match = 0

location_err = [] 
location_err_rect = [] 

rect_x_err = []
rect_y_err = []
radius_err = [] 


for fname in test_list: 
    #cnt+=1 
    if cnt>2:
        break;
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))
    print(fname)

    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    in_caption = sampled_caption[1:-1]
    print(in_caption)
    
    #read target caption
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    trg_caption = [] 
    with open(cap_path, 'r') as f:
        target = f.readline().split()
        for word in target:
            trg_caption.append(word)
    print(trg_caption)
    print('------------------------------------')
    
    try:
        if in_caption[0] == trg_caption[0]:
            shape_match+=1 
        if in_caption[5] == trg_caption[5]:
            shape_match+=1
        if in_caption[1] == trg_caption[1]:
            location_match+=1
        else:
            error = int(trg_caption[1]) - int(in_caption[1])
            location_err.append(abs(error))
        if in_caption[2] == trg_caption[2]:
            location_match+=1
        else:
            error = int(trg_caption[2]) - int(in_caption[2])
            location_err.append(abs(error))
        if in_caption[6] == trg_caption[6]:
            location_match_rect+=1
        else:
            error = int(trg_caption[6]) - int(in_caption[6])
            location_err_rect.append(abs(error))
        if in_caption[7] == trg_caption[7]:
            location_match_rect+=1    
        else:
            error = int(trg_caption[7]) - int(in_caption[7])
            location_err_rect.append(abs(error))
        if in_caption[8] == trg_caption[8]:
            rect_x_match+=1
        else:
            error = int(trg_caption[8]) - int(in_caption[8])
            rect_x_err.append(abs(error))
        if in_caption[9] == trg_caption[9]:
            rect_y_match+=1
        else:
            error = int(trg_caption[9]) - int(in_caption[9])
            rect_y_err.append(abs(error))
        if in_caption[3] == trg_caption[3]:
            radius_match+=1       
        else:
            error = int(trg_caption[3]) - int(in_caption[3])
            radius_err.append(abs(error))
        if in_caption[4] == trg_caption[4]:
            color_match+=1   
        if in_caption[10] == trg_caption[10]:
            color_match+=1  
    except:
        continue
# Out:
# 9908.png
# ['circle', '7', '3', '80', 'skyblue', 'rect', '9', '9', '80', '80', 'spring_green']
# ['circle', '6', '3', '80', 'skyblue', 'rect', '9', '9', '80', '80', 'spring_green']
# ------------------------------------
# 9759.png
# ['circle', '4', '8', '20', 'orange', 'rect', '4', '6', '20', '20', 'cyan']
# ['circle', '4', '8', '20', 'orange', 'rect', '4', '6', '20', '20', 'cyan']
# ------------------------------------
# 9903.png
# ['circle', '1', '9', '110', 'yellow', 'rect', '1', '7', '110', '110', 'green']
# ['circle', '1', '8', '110', 'yellow', 'rect', '1', '9', '110', '110', 'blue']
# ------------------------------------
# 9980.png
# ['circle', '8', '7', '50', 'lime', 'rect', '8', '9', '50', '50', 'green']
# ['circle', '8', '7', '50', 'lime', 'rect', '9', '9', '50', '50', 'green']
# ------------------------------------
# 9728.png
# ['circle', '9', '10', '30', 'blue', 'rect', '7', '4', '30', '30', 'pink']
# ['circle', '10', '10', '50', 'blue', 'rect', '7', '3', '50', '50', 'pink']
# ------------------------------------
# 9934.png
# ['circle', '2', '9', '40', 'cyan', 'rect', '9', '4', '40', '40', 'spring_green']
# ['circle', '2', '9', '40', 'cyan', 'rect', '9', '4', '40', '40', 'spring_green']
# ------------------------------------
# 9807.png
# ['circle', '5', '5', '100', 'cyan', 'rect', '7', '8', '100', '100', 'yellow']
# ['circle', '4', '5', '110', 'cyan', 'rect', '8', '8', '110', '110', 'yellow']
# ------------------------------------
# 9828.png
# ['circle', '4', '2', '40', 'blue', 'rect', '4', '7', '40', '40', 'orange']
# ['circle', '4', '1', '40', 'blue', 'rect', '4', '7', '40', '40', 'orange']
# ------------------------------------
# 9995.png
# ['circle', '1', '9', '90', 'spring_green', 'rect', '10', '7', '90', '90', 'red']
# ['circle', '1', '9', '90', 'spring_green', 'rect', '10', '7', '90', '90', 'red']
# ------------------------------------
# 9801.png
# ['circle', '4', '6', '80', 'spring_green', 'rect', '5', '9', '80', '80', 'deep_pink']
# ['circle', '4', '6', '90', 'spring_green', 'rect', '5', '9', '90', '90', 'deep_pink']
# ------------------------------------
# 9775.png
# ['circle', '1', '2', '90', 'cyan', 'rect', '10', '10', '90', '90', 'pink']
# ['circle', '1', '3', '90', 'cyan', 'rect', '10', '10', '90', '90', 'pink']
# ------------------------------------
# 9928.png
# ['circle', '10', '9', '30', 'red', 'rect', '10', '2', '30', '30', 'pink']
# ['circle', '10', '9', '20', 'red', 'rect', '10', '2', '30', '30', 'pink']
# ------------------------------------
# 9977.png
# ['circle', '8', '1', '90', 'yellow', 'rect', '4', '4', '90', '90', 'cyan']
# ['circle', '8', '1', '100', 'yellow', 'rect', '4', '4', '100', '100', 'cyan']
# ------------------------------------
# 9838.png
# ['circle', '4', '1', '50', 'purple', 'rect', '1', '8', '50', '50', 'cyan']
# ['circle', '4', '2', '50', 'purple', 'rect', '1', '8', '50', '50', 'cyan']
# ------------------------------------
# 9925.png
# ['circle', '9', '1', '80', 'blue', 'rect', '6', '4', '80', '80', 'purple']
# ['circle', '9', '1', '80', 'skyblue', 'rect', '6', '4', '80', '80', 'purple']
# ------------------------------------
# 9963.png
# ['circle', '10', '5', '110', 'cyan', 'rect', '4', '5', '110', '110', 'skyblue']
# ['circle', '10', '5', '110', 'cyan', 'rect', '4', '5', '110', '110', 'skyblue']
# ------------------------------------
# 9889.png
# ['circle', '10', '4', '90', 'blue', 'rect', '1', '10', '90', '90', 'yellow']
# ['circle', '10', '4', '90', 'blue', 'rect', '1', '10', '90', '90', 'yellow']
# ------------------------------------
# 9976.png
# ['circle', '1', '6', '30', 'yellow', 'rect', '5', '7', '30', '30', 'purple']
# ['circle', '1', '7', '30', 'yellow', 'rect', '5', '7', '30', '30', 'purple']
# ------------------------------------
# 9986.png
# ['circle', '6', '9', '100', 'orange', 'rect', '9', '4', '100', '100', 'lime']
# ['circle', '6', '9', '100', 'orange', 'rect', '9', '4', '100', '100', 'lime']
# ------------------------------------
# 9773.png
# ['circle', '1', '10', '110', 'red', 'rect', '6', '3', '110', '110', 'lime']
# ['circle', '2', '10', '90', 'red', 'rect', '6', '3', '90', '90', 'lime']
# ------------------------------------
# 9803.png
# ['circle', '5', '2', '30', 'spring_green', 'rect', '5', '9', '30', '30', 'cyan']
# ['circle', '5', '2', '30', 'spring_green', 'rect', '5', '9', '30', '30', 'cyan']
# ------------------------------------
# 9873.png
# ['circle', '7', '2', '60', 'red', 'rect', '1', '6', '60', '60', 'skyblue']
# ['circle', '7', '3', '60', 'red', 'rect', '1', '6', '60', '60', 'skyblue']
# ------------------------------------
# 9831.png
# ['circle', '7', '2', '20', 'spring_green', 'rect', '3', '7', '20', '20', 'yellow']
# ['circle', '7', '2', '20', 'spring_green', 'rect', '3', '7', '20', '20', 'lime']
# ------------------------------------
# 9935.png
# ['circle', '10', '4', '40', 'orange', 'rect', '9', '2', '40', '40', 'blue']
# ['circle', '10', '4', '50', 'orange', 'rect', '9', '1', '50', '50', 'blue']
# ------------------------------------
# 9784.png
# ['circle', '8', '3', '70', 'orange', 'rect', '6', '2', '70', '70', 'blue']
# ['circle', '8', '3', '70', 'orange', 'rect', '6', '2', '70', '70', 'blue']
# ------------------------------------
# 9700.png
# ['circle', '6', '2', '20', 'deep_pink', 'rect', '9', '1', '20', '20', 'deep_pink']
# ['circle', '6', '1', '20', 'deep_pink', 'rect', '7', '1', '30', '30', 'deep_pink']
# ------------------------------------
# 9703.png
# ['circle', '4', '10', '70', 'spring_green', 'rect', '1', '7', '70', '70', 'purple']
# ['circle', '3', '10', '80', 'spring_green', 'rect', '1', '7', '80', '80', 'purple']
# ------------------------------------
# 9920.png
# ['circle', '4', '8', '100', 'yellow', 'rect', '8', '4', '100', '100', 'lime']
# ['circle', '4', '8', '100', 'yellow', 'rect', '8', '4', '100', '100', 'lime']
# ------------------------------------
# 9724.png
# ['circle', '6', '7', '100', 'yellow', 'rect', '6', '7', '100', '100', 'lime']
# ['circle', '6', '7', '100', 'yellow', 'rect', '6', '8', '100', '100', 'pink']
# ------------------------------------
# 9944.png
# ['circle', '6', '5', '30', 'purple', 'rect', '9', '6', '30', '30', 'pink']
# ['circle', '6', '5', '30', 'purple', 'rect', '9', '6', '30', '30', 'pink']
# ------------------------------------
# 9860.png
# ['circle', '6', '5', '60', 'yellow', 'rect', '8', '1', '60', '60', 'green']
# ['circle', '6', '5', '60', 'yellow', 'rect', '9', '1', '60', '60', 'green']
# ------------------------------------
# 9797.png
# ['circle', '5', '8', '60', 'yellow', 'rect', '5', '8', '60', '60', 'green']
# ['circle', '5', '8', '60', 'yellow', 'rect', '5', '7', '70', '70', 'lime']
# ------------------------------------
# 9716.png
# ['circle', '9', '8', '90', 'green', 'rect', '1', '4', '90', '90', 'skyblue']
# ['circle', '8', '8', '90', 'green', 'rect', '1', '4', '90', '90', 'skyblue']
# ------------------------------------
# 9955.png
# ['circle', '3', '1', '60', 'orange', 'rect', '10', '7', '60', '60', 'lime']
# ['circle', '3', '1', '60', 'orange', 'rect', '10', '7', '60', '60', 'green']
# ------------------------------------
# 9809.png
# ['circle', '5', '3', '80', 'green', 'rect', '5', '4', '80', '80', 'lime']
# ['circle', '4', '3', '80', 'green', 'rect', '5', '4', '80', '80', 'green']
# ------------------------------------
# 9859.png
# ['circle', '5', '4', '40', 'spring_green', 'rect', '10', '2', '40', '40', 'skyblue']
# ['circle', '5', '4', '40', 'spring_green', 'rect', '10', '3', '40', '40', 'skyblue']
# ------------------------------------
# 9990.png
# ['circle', '10', '1', '30', 'green', 'rect', '8', '8', '30', '30', 'skyblue']
# ['circle', '10', '1', '30', 'lime', 'rect', '8', '8', '30', '30', 'skyblue']
# ------------------------------------
# 9869.png
# ['circle', '9', '6', '120', 'red', 'rect', '8', '6', '120', '120', 'red']
# ['circle', '8', '6', '110', 'red', 'rect', '9', '6', '110', '110', 'pink']
# ------------------------------------
# 9991.png
# ['circle', '10', '8', '30', 'purple', 'rect', '3', '1', '30', '30', 'pink']
# ['circle', '10', '8', '30', 'purple', 'rect', '3', '2', '30', '30', 'pink']
# ------------------------------------
# 9856.png
# ['circle', '7', '2', '80', 'skyblue', 'rect', '2', '6', '80', '80', 'lime']
# ['circle', '7', '2', '80', 'skyblue', 'rect', '2', '6', '80', '80', 'lime']
# ------------------------------------
# 9778.png
# ['circle', '7', '2', '120', 'lime', 'rect', '5', '10', '120', '120', 'red']
# ['circle', '7', '3', '120', 'lime', 'rect', '6', '10', '120', '120', 'red']
# ------------------------------------
# 9841.png
# ['circle', '9', '10', '90', 'lime', 'rect', '5', '2', '90', '90', 'red']
# ['circle', '9', '10', '110', 'lime', 'rect', '5', '2', '110', '110', 'red']
# ------------------------------------
# 9904.png
# ['circle', '1', '4', '80', 'blue', 'rect', '3', '6', '80', '80', 'purple']
# ['circle', '1', '5', '80', 'blue', 'rect', '3', '5', '80', '80', 'purple']
# ------------------------------------
# 9737.png
# ['circle', '8', '4', '60', 'red', 'rect', '7', '3', '60', '60', 'green']
# ['circle', '7', '4', '60', 'red', 'rect', '7', '4', '60', '60', 'red']
# ------------------------------------
# 9776.png
# ['circle', '2', '2', '90', 'deep_pink', 'rect', '1', '4', '90', '90', 'orange']
# ['circle', '2', '3', '90', 'red', 'rect', '1', '4', '90', '90', 'orange']
# ------------------------------------
# 9984.png
# ['circle', '4', '1', '70', 'red', 'rect', '5', '8', '70', '70', 'pink']
# ['circle', '4', '2', '70', 'red', 'rect', '5', '8', '70', '70', 'pink']
# ------------------------------------
# 9772.png
# ['circle', '1', '9', '90', 'blue', 'rect', '2', '3', '90', '90', 'lime']
# ['circle', '1', '9', '90', 'blue', 'rect', '2', '3', '90', '90', 'lime']
# ------------------------------------
# 9744.png
# ['circle', '4', '1', '60', 'purple', 'rect', '1', '1', '60', '60', 'red']
# ['circle', '4', '1', '60', 'purple', 'rect', '1', '1', '60', '60', 'red']
# ------------------------------------
# 9824.png
# ['circle', '7', '3', '110', 'pink', 'rect', '10', '6', '110', '110', 'skyblue']
# ['circle', '7', '3', '110', 'pink', 'rect', '10', '5', '110', '110', 'skyblue']
# ------------------------------------
# 9858.png
# ['circle', '4', '7', '90', 'pink', 'rect', '1', '5', '90', '90', 'green']
# ['circle', '4', '7', '90', 'purple', 'rect', '1', '5', '90', '90', 'green']
# ------------------------------------
# 9771.png
# ['circle', '5', '1', '50', 'purple', 'rect', '5', '5', '50', '50', 'cyan']
# ['circle', '5', '1', '50', 'purple', 'rect', '5', '5', '50', '50', 'cyan']
# ------------------------------------
# 9890.png
# ['circle', '8', '4', '80', 'blue', 'rect', '6', '4', '80', '80', 'cyan']
# ['circle', '7', '4', '80', 'blue', 'rect', '6', '3', '90', '90', 'cyan']
# ------------------------------------
# 9868.png
# ['circle', '7', '6', '30', 'pink', 'rect', '6', '9', '30', '30', 'green']
# ['circle', '7', '7', '40', 'pink', 'rect', '6', '9', '40', '40', 'lime']
# ------------------------------------
# 9999.png
# ['circle', '8', '10', '50', 'red', 'rect', '3', '7', '50', '50', 'lime']
# ['circle', '8', '10', '50', 'red', 'rect', '3', '7', '50', '50', 'green']
# ------------------------------------
# 9770.png
# ['circle', '7', '9', '70', 'yellow', 'rect', '8', '4', '70', '70', 'yellow']
# ['circle', '6', '9', '70', 'yellow', 'rect', '8', '4', '70', '70', 'yellow']
# ------------------------------------
# 9713.png
# ['circle', '1', '10', '80', 'spring_green', 'rect', '10', '1', '80', '80', 'lime']
# ['circle', '1', '10', '90', 'spring_green', 'rect', '10', '1', '90', '90', 'lime']
# ------------------------------------
# 9729.png
# ['circle', '10', '8', '90', 'skyblue', 'rect', '7', '3', '90', '90', 'cyan']
# ['circle', '10', '8', '90', 'skyblue', 'rect', '7', '3', '90', '90', 'cyan']
# ------------------------------------
# 9929.png
# ['circle', '7', '2', '40', 'yellow', 'rect', '2', '5', '40', '40', 'lime']
# ['circle', '7', '2', '40', 'yellow', 'rect', '2', '5', '40', '40', 'lime']
# ------------------------------------
# 9721.png
# ['circle', '5', '7', '80', 'deep_pink', 'rect', '8', '6', '80', '80', 'skyblue']
# ['circle', '5', '7', '80', 'red', 'rect', '6', '6', '90', '90', 'skyblue']
# ------------------------------------
# 9919.png
# ['circle', '4', '6', '30', 'green', 'rect', '9', '1', '30', '30', 'yellow']
# ['circle', '4', '6', '30', 'green', 'rect', '8', '1', '30', '30', 'yellow']
# ------------------------------------
# 9979.png
# ['circle', '10', '7', '80', 'green', 'rect', '4', '9', '80', '80', 'lime']
# ['circle', '10', '7', '80', 'green', 'rect', '4', '9', '80', '80', 'lime']
# ------------------------------------
# 9968.png
# ['circle', '1', '2', '50', 'purple', 'rect', '9', '3', '50', '50', 'spring_green']
# ['circle', '1', '3', '50', 'purple', 'rect', '9', '3', '50', '50', 'spring_green']
# ------------------------------------
# 9739.png
# ['circle', '8', '10', '90', 'cyan', 'rect', '7', '9', '90', '90', 'purple']
# ['circle', '8', '10', '90', 'cyan', 'rect', '10', '9', '90', '90', 'pink']
# ------------------------------------
# 9862.png
# ['circle', '8', '3', '110', 'skyblue', 'rect', '9', '10', '110', '110', 'green']
# ['circle', '8', '3', '110', 'skyblue', 'rect', '10', '10', '110', '110', 'green']
# ------------------------------------
# 9896.png
# ['circle', '5', '5', '50', 'yellow', 'rect', '8', '8', '50', '50', 'lime']
# ['circle', '4', '5', '50', 'yellow', 'rect', '8', '8', '50', '50', 'lime']
# ------------------------------------
# 9923.png
# ['circle', '6', '10', '70', 'deep_pink', 'rect', '10', '4', '70', '70', 'yellow']
# ['circle', '6', '10', '70', 'deep_pink', 'rect', '10', '4', '70', '70', 'yellow']
# ------------------------------------
# 9774.png
# ['circle', '7', '9', '100', 'blue', 'rect', '5', '4', '100', '100', 'green']
# ['circle', '8', '9', '100', 'blue', 'rect', '5', '5', '100', '100', 'green']
# ------------------------------------
# 9718.png
# ['circle', '7', '9', '70', 'green', 'rect', '10', '6', '70', '70', 'deep_pink']
# ['circle', '7', '10', '70', 'green', 'rect', '9', '6', '70', '70', 'deep_pink']
# ------------------------------------
# 9733.png
# ['circle', '6', '8', '80', 'spring_green', 'rect', '4', '3', '80', '80', 'deep_pink']
# ['circle', '5', '8', '80', 'spring_green', 'rect', '4', '1', '90', '90', 'deep_pink']
# ------------------------------------
# 9782.png
# ['circle', '3', '8', '70', 'pink', 'rect', '1', '7', '70', '70', 'red']
# ['circle', '3', '8', '70', 'pink', 'rect', '1', '8', '70', '70', 'red']
# ------------------------------------
# 9792.png
# ['circle', '9', '3', '80', 'cyan', 'rect', '5', '7', '80', '80', 'cyan']
# ['circle', '9', '4', '80', 'cyan', 'rect', '5', '7', '80', '80', 'cyan']
# ------------------------------------
# 9813.png
# ['circle', '4', '9', '40', 'pink', 'rect', '6', '4', '40', '40', 'pink']
# ['circle', '4', '9', '40', 'pink', 'rect', '6', '4', '40', '40', 'pink']
# ------------------------------------
# 9866.png
# ['circle', '8', '2', '110', 'yellow', 'rect', '4', '7', '110', '110', 'red']
# ['circle', '8', '3', '110', 'yellow', 'rect', '4', '7', '110', '110', 'red']
# ------------------------------------
# 9768.png
# ['circle', '2', '9', '30', 'skyblue', 'rect', '7', '10', '30', '30', 'red']
# ['circle', '2', '9', '40', 'skyblue', 'rect', '7', '10', '40', '40', 'red']
# ------------------------------------
# 9954.png
# ['circle', '10', '10', '80', 'cyan', 'rect', '5', '7', '80', '80', 'deep_pink']
# ['circle', '10', '10', '80', 'cyan', 'rect', '5', '7', '80', '80', 'deep_pink']
# ------------------------------------
# 9796.png
# ['circle', '4', '7', '50', 'purple', 'rect', '5', '8', '50', '50', 'purple']
# ['circle', '4', '7', '50', 'purple', 'rect', '5', '8', '50', '50', 'purple']
# ------------------------------------
# 9710.png
# ['circle', '1', '3', '30', 'cyan', 'rect', '9', '2', '30', '30', 'orange']
# ['circle', '1', '3', '30', 'cyan', 'rect', '8', '2', '30', '30', 'orange']
# ------------------------------------
# 9918.png
# ['circle', '5', '8', '110', 'skyblue', 'rect', '10', '1', '110', '110', 'blue']
# ['circle', '5', '8', '110', 'skyblue', 'rect', '9', '1', '110', '110', 'blue']
# ------------------------------------
# 9951.png
# ['circle', '9', '3', '60', 'spring_green', 'rect', '7', '8', '60', '60', 'spring_green']
# ['circle', '9', '3', '60', 'spring_green', 'rect', '7', '8', '70', '70', 'spring_green']
# ------------------------------------
# 9726.png
# ['circle', '10', '2', '60', 'yellow', 'rect', '2', '10', '60', '60', 'orange']
# ['circle', '10', '2', '60', 'yellow', 'rect', '2', '10', '60', '60', 'orange']
# ------------------------------------
# 9964.png
# ['circle', '6', '8', '30', 'purple', 'rect', '7', '7', '30', '30', 'spring_green']
# ['circle', '6', '8', '30', 'purple', 'rect', '6', '7', '30', '30', 'spring_green']
# ------------------------------------
# 9973.png
# ['circle', '10', '10', '20', 'pink', 'rect', '10', '3', '20', '20', 'lime']
# ['circle', '9', '10', '20', 'pink', 'rect', '10', '4', '20', '20', 'lime']
# ------------------------------------
# 9821.png
# ['circle', '2', '6', '110', 'spring_green', 'rect', '1', '3', '110', '110', 'blue']
# ['circle', '2', '6', '110', 'spring_green', 'rect', '1', '4', '110', '110', 'blue']
# ------------------------------------
# 9943.png
# ['circle', '3', '6', '30', 'purple', 'rect', '9', '4', '30', '30', 'cyan']
# ['circle', '3', '6', '30', 'purple', 'rect', '9', '4', '30', '30', 'cyan']
# ------------------------------------
# 9826.png
# ['circle', '1', '1', '60', 'orange', 'rect', '8', '2', '60', '60', 'green']
# ['circle', '1', '1', '80', 'orange', 'rect', '8', '2', '80', '80', 'green']
# ------------------------------------
# 9883.png
# ['circle', '10', '8', '90', 'lime', 'rect', '3', '9', '90', '90', 'skyblue']
# ['circle', '10', '8', '90', 'lime', 'rect', '4', '9', '90', '90', 'skyblue']
# ------------------------------------
# 9998.png
# ['circle', '9', '9', '40', 'cyan', 'rect', '10', '3', '40', '40', 'pink']
# ['circle', '8', '9', '40', 'cyan', 'rect', '10', '3', '40', '40', 'purple']
# ------------------------------------
# 9969.png
# ['circle', '8', '5', '110', 'deep_pink', 'rect', '5', '6', '110', '110', 'yellow']
# ['circle', '8', '5', '110', 'deep_pink', 'rect', '5', '6', '110', '110', 'yellow']
# ------------------------------------
# 9881.png
# ['circle', '3', '7', '30', 'green', 'rect', '8', '1', '30', '30', 'spring_green']
# ['circle', '3', '7', '30', 'green', 'rect', '8', '1', '30', '30', 'green']
# ------------------------------------
# 9938.png
# ['circle', '2', '6', '110', 'yellow', 'rect', '7', '3', '110', '110', 'skyblue']
# ['circle', '2', '6', '110', 'yellow', 'rect', '7', '3', '110', '110', 'skyblue']
# ------------------------------------
# 9962.png
# ['circle', '10', '4', '30', 'deep_pink', 'rect', '3', '7', '30', '30', 'pink']
# ['circle', '10', '4', '30', 'deep_pink', 'rect', '3', '7', '30', '30', 'purple']
# ------------------------------------
# 9930.png
# ['circle', '6', '1', '50', 'cyan', 'rect', '6', '10', '50', '50', 'yellow']
# ['circle', '5', '1', '50', 'skyblue', 'rect', '6', '10', '50', '50', 'lime']
# ------------------------------------
# 9888.png
# ['circle', '3', '6', '80', 'deep_pink', 'rect', '9', '2', '80', '80', 'spring_green']
# ['circle', '3', '6', '80', 'deep_pink', 'rect', '9', '2', '90', '90', 'spring_green']
# ------------------------------------
# 9715.png
# ['circle', '6', '3', '30', 'red', 'rect', '2', '5', '30', '30', 'yellow']
# ['circle', '6', '3', '30', 'red', 'rect', '2', '5', '30', '30', 'yellow']
# ------------------------------------
# 9833.png
# ['circle', '3', '3', '100', 'orange', 'rect', '8', '3', '100', '100', 'green']
# ['circle', '3', '3', '100', 'orange', 'rect', '8', '3', '100', '100', 'green']
# ------------------------------------
# 9763.png
# ['circle', '2', '7', '110', 'deep_pink', 'rect', '7', '7', '110', '110', 'blue']
# ['circle', '2', '7', '110', 'deep_pink', 'rect', '7', '6', '110', '110', 'blue']
# ------------------------------------
# 9781.png
# ['circle', '5', '8', '50', 'deep_pink', 'rect', '9', '5', '50', '50', 'skyblue']
# ['circle', '5', '8', '50', 'deep_pink', 'rect', '9', '4', '50', '50', 'skyblue']
# ------------------------------------
# 9806.png
# ['circle', '8', '8', '20', 'skyblue', 'rect', '5', '6', '20', '20', 'yellow']
# ['circle', '8', '8', '20', 'skyblue', 'rect', '5', '7', '20', '20', 'yellow']
# ------------------------------------
# 9956.png
# ['circle', '3', '1', '30', 'blue', 'rect', '3', '2', '30', '30', 'green']
# ['circle', '3', '1', '30', 'blue', 'rect', '3', '1', '30', '30', 'deep_pink']
# ------------------------------------
# 9748.png
# ['circle', '4', '4', '90', 'purple', 'rect', '5', '8', '90', '90', 'yellow']
# ['circle', '4', '4', '90', 'purple', 'rect', '5', '8', '90', '90', 'yellow']
# ------------------------------------
# 9932.png
# ['circle', '2', '8', '60', 'orange', 'rect', '8', '6', '60', '60', 'purple']
# ['circle', '2', '8', '60', 'yellow', 'rect', '8', '6', '60', '60', 'purple']
# ------------------------------------
# 9975.png
# ['circle', '8', '3', '100', 'green', 'rect', '2', '1', '100', '100', 'purple']
# ['circle', '8', '3', '100', 'green', 'rect', '2', '1', '110', '110', 'purple']
# ------------------------------------
# 9988.png
# ['circle', '9', '7', '20', 'blue', 'rect', '9', '2', '20', '20', 'skyblue']
# ['circle', '1', '8', '20', 'blue', 'rect', '9', '2', '20', '20', 'skyblue']
# ------------------------------------
# 9892.png
# ['circle', '2', '3', '30', 'spring_green', 'rect', '5', '7', '30', '30', 'yellow']
# ['circle', '2', '3', '30', 'spring_green', 'rect', '5', '7', '30', '30', 'yellow']
# ------------------------------------
# 9754.png
# ['circle', '6', '3', '100', 'cyan', 'rect', '10', '4', '100', '100', 'spring_green']
# ['circle', '6', '3', '100', 'cyan', 'rect', '10', '3', '100', '100', 'spring_green']
# ------------------------------------
# 9961.png
# ['circle', '10', '6', '50', 'orange', 'rect', '8', '2', '50', '50', 'green']
# ['circle', '10', '6', '50', 'orange', 'rect', '9', '2', '50', '50', 'green']
# ------------------------------------
# 9752.png
# ['circle', '7', '10', '50', 'skyblue', 'rect', '2', '5', '50', '50', 'deep_pink']
# ['circle', '7', '10', '50', 'skyblue', 'rect', '2', '5', '50', '50', 'pink']
# ------------------------------------
# 9864.png
# ['circle', '5', '6', '90', 'green', 'rect', '8', '2', '90', '90', 'pink']
# ['circle', '5', '6', '90', 'green', 'rect', '8', '2', '90', '90', 'purple']
# ------------------------------------
# 9725.png
# ['circle', '9', '5', '50', 'pink', 'rect', '2', '4', '50', '50', 'yellow']
# ['circle', '9', '5', '50', 'pink', 'rect', '2', '4', '50', '50', 'yellow']
# ------------------------------------
# 9926.png
# ['circle', '3', '4', '20', 'deep_pink', 'rect', '2', '5', '20', '20', 'spring_green']
# ['circle', '3', '4', '20', 'deep_pink', 'rect', '2', '5', '20', '20', 'spring_green']
# ------------------------------------
# 9830.png
# ['circle', '1', '5', '70', 'purple', 'rect', '9', '7', '70', '70', 'yellow']
# ['circle', '1', '5', '60', 'purple', 'rect', '9', '7', '60', '60', 'yellow']
# ------------------------------------
# 9766.png
# ['circle', '5', '6', '100', 'purple', 'rect', '1', '4', '100', '100', 'cyan']
# ['circle', '4', '6', '100', 'purple', 'rect', '1', '4', '100', '100', 'cyan']
# ------------------------------------
# 9811.png
# ['circle', '1', '3', '80', 'yellow', 'rect', '5', '4', '80', '80', 'orange']
# ['circle', '1', '3', '80', 'yellow', 'rect', '5', '4', '80', '80', 'orange']
# ------------------------------------
# 9829.png
# ['circle', '10', '7', '30', 'orange', 'rect', '7', '1', '30', '30', 'lime']
# ['circle', '10', '7', '30', 'orange', 'rect', '7', '1', '30', '30', 'lime']
# ------------------------------------
# 9722.png
# ['circle', '1', '2', '60', 'red', 'rect', '2', '9', '60', '60', 'deep_pink']
# ['circle', '1', '2', '50', 'red', 'rect', '2', '9', '50', '50', 'deep_pink']
# ------------------------------------
# 9702.png
# ['circle', '4', '10', '50', 'spring_green', 'rect', '7', '3', '50', '50', 'skyblue']
# ['circle', '3', '10', '50', 'spring_green', 'rect', '7', '3', '50', '50', 'skyblue']
# ------------------------------------
# 9921.png
# ['circle', '3', '3', '70', 'purple', 'rect', '9', '9', '70', '70', 'yellow']
# ['circle', '3', '4', '70', 'purple', 'rect', '9', '9', '70', '70', 'orange']
# ------------------------------------
# 9946.png
# ['circle', '2', '2', '70', 'red', 'rect', '2', '5', '70', '70', 'lime']
# ['circle', '2', '1', '70', 'red', 'rect', '2', '5', '70', '70', 'lime']
# ------------------------------------
# 9974.png
# ['circle', '6', '8', '90', 'pink', 'rect', '4', '7', '90', '90', 'yellow']
# ['circle', '6', '8', '90', 'pink', 'rect', '8', '7', '90', '90', 'yellow']
# ------------------------------------
# 9839.png
# ['circle', '2', '3', '60', 'purple', 'rect', '5', '9', '60', '60', 'orange']
# ['circle', '2', '3', '70', 'purple', 'rect', '5', '9', '70', '70', 'orange']
# ------------------------------------
# 9900.png
# ['circle', '3', '4', '60', 'skyblue', 'rect', '4', '9', '60', '60', 'deep_pink']
# ['circle', '3', '4', '60', 'skyblue', 'rect', '4', '9', '70', '70', 'deep_pink']
# ------------------------------------
# 9897.png
# ['circle', '2', '6', '40', 'spring_green', 'rect', '9', '3', '40', '40', 'red']
# ['circle', '2', '6', '40', 'spring_green', 'rect', '9', '3', '40', '40', 'red']
# ------------------------------------
# 9971.png
# ['circle', '5', '6', '30', 'deep_pink', 'rect', '5', '9', '30', '30', 'green']
# ['circle', '5', '6', '30', 'deep_pink', 'rect', '4', '9', '30', '30', 'green']
# ------------------------------------
# 9749.png
# ['circle', '5', '6', '80', 'spring_green', 'rect', '9', '2', '80', '80', 'skyblue']
# ['circle', '5', '6', '80', 'spring_green', 'rect', '9', '2', '80', '80', 'skyblue']
# ------------------------------------
# 9730.png
# ['circle', '5', '1', '80', 'lime', 'rect', '5', '5', '80', '80', 'spring_green']
# ['circle', '5', '1', '80', 'lime', 'rect', '5', '5', '80', '80', 'spring_green']
# ------------------------------------
# 9849.png
# ['circle', '10', '7', '70', 'skyblue', 'rect', '9', '2', '70', '70', 'pink']
# ['circle', '10', '7', '70', 'skyblue', 'rect', '9', '1', '70', '70', 'pink']
# ------------------------------------
# 9953.png
# ['circle', '6', '7', '60', 'red', 'rect', '2', '4', '60', '60', 'skyblue']
# ['circle', '6', '7', '60', 'red', 'rect', '2', '4', '70', '70', 'skyblue']
# ------------------------------------
# 9734.png
# ['circle', '3', '1', '60', 'deep_pink', 'rect', '10', '3', '60', '60', 'deep_pink']
# ['circle', '3', '1', '60', 'pink', 'rect', '10', '3', '60', '60', 'deep_pink']
# ------------------------------------
# 9756.png
# ['circle', '7', '10', '60', 'green', 'rect', '9', '2', '60', '60', 'cyan']
# ['circle', '6', '10', '60', 'green', 'rect', '9', '3', '60', '60', 'cyan']
# ------------------------------------
# 9808.png
# ['circle', '5', '5', '100', 'cyan', 'rect', '5', '8', '100', '100', 'spring_green']
# ['circle', '5', '6', '100', 'cyan', 'rect', '5', '8', '100', '100', 'green']
# ------------------------------------
# 9707.png
# ['circle', '9', '4', '70', 'yellow', 'rect', '3', '9', '70', '70', 'green']
# ['circle', '9', '4', '70', 'yellow', 'rect', '3', '9', '70', '70', 'green']
# ------------------------------------
# 9957.png
# ['circle', '10', '1', '60', 'blue', 'rect', '2', '8', '60', '60', 'deep_pink']
# ['circle', '10', '1', '60', 'blue', 'rect', '2', '8', '70', '70', 'deep_pink']
# ------------------------------------
# 9939.png
# ['circle', '8', '5', '50', 'cyan', 'rect', '3', '1', '50', '50', 'lime']
# ['circle', '8', '5', '50', 'cyan', 'rect', '3', '1', '50', '50', 'lime']
# ------------------------------------
# 9786.png
# ['circle', '2', '7', '120', 'spring_green', 'rect', '4', '3', '120', '120', 'yellow']
# ['circle', '2', '6', '120', 'spring_green', 'rect', '4', '3', '120', '120', 'yellow']
# ------------------------------------
# 9736.png
# ['circle', '8', '7', '110', 'pink', 'rect', '2', '4', '110', '110', 'lime']
# ['circle', '8', '7', '110', 'pink', 'rect', '2', '4', '110', '110', 'green']
# ------------------------------------
# 9743.png
# ['circle', '5', '9', '80', 'pink', 'rect', '5', '2', '80', '80', 'purple']
# ['circle', '5', '9', '80', 'pink', 'rect', '5', '2', '80', '80', 'purple']
# ------------------------------------
# 9790.png
# ['circle', '4', '7', '70', 'blue', 'rect', '1', '5', '70', '70', 'skyblue']
# ['circle', '4', '7', '70', 'blue', 'rect', '1', '6', '70', '70', 'skyblue']
# ------------------------------------
# 9714.png
# ['circle', '6', '1', '60', 'purple', 'rect', '3', '5', '60', '60', 'blue']
# ['circle', '6', '1', '70', 'purple', 'rect', '3', '5', '70', '70', 'blue']
# ------------------------------------
# 9879.png
# ['circle', '9', '8', '110', 'red', 'rect', '7', '10', '110', '110', 'green']
# ['circle', '10', '8', '120', 'red', 'rect', '7', '10', '120', '120', 'green']
# ------------------------------------
# 9948.png
# ['circle', '3', '5', '60', 'skyblue', 'rect', '4', '7', '60', '60', 'orange']
# ['circle', '3', '5', '60', 'skyblue', 'rect', '4', '7', '60', '60', 'orange']
# ------------------------------------
# 9814.png
# ['circle', '6', '9', '30', 'skyblue', 'rect', '6', '7', '30', '30', 'red']
# ['circle', '5', '9', '30', 'skyblue', 'rect', '6', '7', '30', '30', 'red']
# ------------------------------------
# 9952.png
# ['circle', '9', '1', '50', 'red', 'rect', '6', '8', '50', '50', 'red']
# ['circle', '9', '1', '50', 'red', 'rect', '6', '8', '50', '50', 'red']
# ------------------------------------
# 9922.png
# ['circle', '3', '2', '90', 'blue', 'rect', '10', '9', '90', '90', 'purple']
# ['circle', '3', '2', '100', 'blue', 'rect', '10', '9', '100', '100', 'purple']
# ------------------------------------
# 9878.png
# ['circle', '7', '5', '60', 'green', 'rect', '9', '8', '60', '60', 'spring_green']
# ['circle', '7', '5', '60', 'green', 'rect', '9', '8', '60', '60', 'spring_green']
# ------------------------------------
# 9755.png
# ['circle', '4', '6', '90', 'pink', 'rect', '2', '7', '90', '90', 'deep_pink']
# ['circle', '4', '6', '90', 'purple', 'rect', '2', '7', '90', '90', 'deep_pink']
# ------------------------------------
# 9777.png
# ['circle', '1', '9', '100', 'orange', 'rect', '10', '5', '100', '100', 'cyan']
# ['circle', '1', '9', '100', 'orange', 'rect', '10', '4', '100', '100', 'spring_green']
# ------------------------------------
# 9742.png
# ['circle', '9', '4', '30', 'purple', 'rect', '9', '7', '30', '30', 'green']
# ['circle', '9', '4', '30', 'purple', 'rect', '9', '7', '30', '30', 'green']
# ------------------------------------
# 9706.png
# ['circle', '5', '2', '50', 'blue', 'rect', '8', '2', '50', '50', 'spring_green']
# ['circle', '5', '2', '50', 'blue', 'rect', '9', '2', '50', '50', 'cyan']
# ------------------------------------
# 9791.png
# ['circle', '2', '1', '40', 'cyan', 'rect', '4', '1', '40', '40', 'spring_green']
# ['circle', '2', '1', '40', 'cyan', 'rect', '4', '1', '40', '40', 'spring_green']
# ------------------------------------
# 9819.png
# ['circle', '1', '3', '100', 'orange', 'rect', '7', '4', '100', '100', 'spring_green']
# ['circle', '1', '3', '100', 'orange', 'rect', '7', '4', '100', '100', 'spring_green']
# ------------------------------------
# 9711.png
# ['circle', '9', '7', '50', 'deep_pink', 'rect', '8', '10', '50', '50', 'deep_pink']
# ['circle', '9', '7', '50', 'deep_pink', 'rect', '8', '10', '50', '50', 'deep_pink']
# ------------------------------------
# 9802.png
# ['circle', '6', '6', '40', 'yellow', 'rect', '8', '4', '40', '40', 'orange']
# ['circle', '6', '6', '40', 'yellow', 'rect', '8', '4', '40', '40', 'orange']
# ------------------------------------
# 9945.png
# ['circle', '4', '9', '30', 'lime', 'rect', '9', '6', '30', '30', 'cyan']
# ['circle', '4', '9', '40', 'lime', 'rect', '9', '6', '40', '40', 'cyan']
# ------------------------------------
# 9795.png
# ['circle', '3', '1', '80', 'green', 'rect', '7', '10', '80', '80', 'deep_pink']
# ['circle', '3', '2', '80', 'green', 'rect', '7', '10', '80', '80', 'deep_pink']
# ------------------------------------
# 9917.png
# ['circle', '7', '10', '80', 'orange', 'rect', '3', '6', '80', '80', 'red']
# ['circle', '7', '10', '90', 'orange', 'rect', '3', '6', '90', '90', 'red']
# ------------------------------------
# 9993.png
# ['circle', '3', '9', '70', 'lime', 'rect', '3', '6', '70', '70', 'purple']
# ['circle', '3', '9', '70', 'yellow', 'rect', '3', '6', '70', '70', 'purple']
# ------------------------------------
# 9915.png
# ['circle', '10', '9', '110', 'yellow', 'rect', '4', '8', '110', '110', 'green']
# ['circle', '9', '10', '120', 'yellow', 'rect', '4', '8', '120', '120', 'green']
# ------------------------------------
# 9836.png
# ['circle', '7', '8', '30', 'deep_pink', 'rect', '7', '6', '30', '30', 'green']
# ['circle', '7', '8', '40', 'deep_pink', 'rect', '6', '6', '40', '40', 'green']
# ------------------------------------
# 9788.png
# ['circle', '3', '5', '40', 'red', 'rect', '4', '2', '40', '40', 'deep_pink']
# ['circle', '3', '6', '40', 'red', 'rect', '4', '3', '40', '40', 'pink']
# ------------------------------------
# 9983.png
# ['circle', '10', '4', '30', 'cyan', 'rect', '8', '2', '30', '30', 'red']
# ['circle', '10', '4', '40', 'cyan', 'rect', '8', '1', '40', '40', 'red']
# ------------------------------------
# 9914.png
# ['circle', '1', '6', '70', 'orange', 'rect', '8', '5', '70', '70', 'cyan']
# ['circle', '1', '6', '80', 'orange', 'rect', '8', '5', '80', '80', 'cyan']
# ------------------------------------
# 9901.png
# ['circle', '8', '7', '100', 'blue', 'rect', '7', '4', '100', '100', 'deep_pink']
# ['circle', '7', '7', '100', 'skyblue', 'rect', '7', '5', '100', '100', 'deep_pink']
# ------------------------------------
# 9815.png
# ['circle', '8', '4', '30', 'orange', 'rect', '4', '5', '30', '30', 'pink']
# ['circle', '8', '4', '30', 'orange', 'rect', '4', '5', '30', '30', 'pink']
# ------------------------------------
# 9870.png
# ['circle', '5', '6', '80', 'yellow', 'rect', '5', '4', '80', '80', 'skyblue']
# ['circle', '5', '6', '80', 'yellow', 'rect', '5', '5', '80', '80', 'skyblue']
# ------------------------------------
# 9874.png
# ['circle', '3', '5', '110', 'spring_green', 'rect', '2', '2', '110', '110', 'green']
# ['circle', '3', '5', '110', 'cyan', 'rect', '1', '2', '110', '110', 'spring_green']
# ------------------------------------
# 9731.png
# ['circle', '10', '3', '100', 'orange', 'rect', '10', '7', '100', '100', 'deep_pink']
# ['circle', '10', '3', '100', 'orange', 'rect', '10', '7', '100', '100', 'deep_pink']
# ------------------------------------
# 9851.png
# ['circle', '9', '9', '60', 'purple', 'rect', '8', '3', '60', '60', 'skyblue']
# ['circle', '9', '9', '60', 'purple', 'rect', '8', '3', '70', '70', 'skyblue']
# ------------------------------------
# 9834.png
# ['circle', '10', '5', '40', 'deep_pink', 'rect', '10', '8', '40', '40', 'spring_green']
# ['circle', '9', '5', '40', 'deep_pink', 'rect', '10', '7', '40', '40', 'spring_green']
# ------------------------------------
# 9747.png
# ['circle', '4', '1', '50', 'skyblue', 'rect', '8', '4', '50', '50', 'cyan']
# ['circle', '4', '1', '50', 'skyblue', 'rect', '8', '4', '50', '50', 'cyan']
# ------------------------------------
# 9985.png
# ['circle', '9', '8', '30', 'lime', 'rect', '9', '10', '30', '30', 'green']
# ['circle', '9', '8', '30', 'lime', 'rect', '9', '10', '30', '30', 'green']
# ------------------------------------
# 9746.png
# ['circle', '1', '10', '40', 'orange', 'rect', '3', '7', '40', '40', 'lime']
# ['circle', '1', '10', '40', 'orange', 'rect', '3', '7', '40', '40', 'lime']
# ------------------------------------
# 9758.png
# ['circle', '6', '3', '30', 'blue', 'rect', '7', '4', '30', '30', 'cyan']
# ['circle', '6', '3', '40', 'purple', 'rect', '7', '3', '40', '40', 'cyan']
# ------------------------------------
# 9847.png
# ['circle', '2', '3', '110', 'lime', 'rect', '1', '8', '110', '110', 'lime']
# ['circle', '2', '3', '120', 'lime', 'rect', '1', '7', '120', '120', 'lime']
# ------------------------------------
# 9863.png
# ['circle', '9', '9', '90', 'blue', 'rect', '3', '8', '90', '90', 'orange']
# ['circle', '10', '9', '100', 'blue', 'rect', '3', '7', '100', '100', 'orange']
# ------------------------------------
# 9865.png
# ['circle', '5', '10', '60', 'purple', 'rect', '4', '7', '60', '60', 'blue']
# ['circle', '5', '10', '70', 'purple', 'rect', '4', '7', '70', '70', 'blue']
# ------------------------------------
# 9761.png
# ['circle', '10', '1', '90', 'spring_green', 'rect', '1', '10', '90', '90', 'yellow']
# ['circle', '9', '1', '90', 'spring_green', 'rect', '1', '10', '90', '90', 'yellow']
# ------------------------------------
# 9762.png
# ['circle', '3', '4', '100', 'red', 'rect', '3', '2', '100', '100', 'lime']
# ['circle', '3', '4', '100', 'red', 'rect', '2', '3', '100', '100', 'yellow']
# ------------------------------------
# 9845.png
# ['circle', '3', '2', '50', 'green', 'rect', '9', '6', '50', '50', 'blue']
# ['circle', '3', '2', '50', 'green', 'rect', '9', '6', '50', '50', 'blue']
# ------------------------------------
# 9783.png
# ['circle', '8', '7', '30', 'spring_green', 'rect', '5', '1', '30', '30', 'green']
# ['circle', '8', '7', '30', 'cyan', 'rect', '5', '2', '30', '30', 'green']
# ------------------------------------
# 9876.png
# ['circle', '6', '6', '40', 'spring_green', 'rect', '7', '10', '40', '40', 'red']
# ['circle', '6', '6', '40', 'spring_green', 'rect', '7', '10', '40', '40', 'red']
# ------------------------------------
# 9898.png
# ['circle', '6', '8', '40', 'spring_green', 'rect', '7', '1', '40', '40', 'cyan']
# ['circle', '6', '8', '40', 'spring_green', 'rect', '7', '1', '40', '40', 'cyan']
# ------------------------------------
# 9958.png
# ['circle', '5', '3', '20', 'skyblue', 'rect', '3', '5', '20', '20', 'purple']
# ['circle', '5', '10', '20', 'skyblue', 'rect', '3', '5', '20', '20', 'purple']
# ------------------------------------
# 9805.png
# ['circle', '3', '6', '100', 'cyan', 'rect', '8', '2', '100', '100', 'spring_green']
# ['circle', '3', '6', '100', 'cyan', 'rect', '8', '2', '100', '100', 'spring_green']
# ------------------------------------
# 9981.png
# ['circle', '6', '4', '60', 'cyan', 'rect', '8', '10', '60', '60', 'green']
# ['circle', '6', '4', '60', 'cyan', 'rect', '7', '10', '60', '60', 'green']
# ------------------------------------
# 9717.png
# ['circle', '8', '7', '30', 'purple', 'rect', '1', '1', '30', '30', 'purple']
# ['circle', '8', '7', '30', 'purple', 'rect', '1', '2', '30', '30', 'purple']
# ------------------------------------
# 9997.png
# ['circle', '10', '1', '70', 'orange', 'rect', '7', '10', '70', '70', 'deep_pink']
# ['circle', '10', '1', '70', 'yellow', 'rect', '7', '10', '70', '70', 'deep_pink']
# ------------------------------------
# 9727.png
# ['circle', '2', '2', '70', 'green', 'rect', '3', '6', '70', '70', 'skyblue']
# ['circle', '2', '2', '70', 'green', 'rect', '3', '6', '70', '70', 'skyblue']
# ------------------------------------
# 9823.png
# ['circle', '2', '2', '20', 'spring_green', 'rect', '6', '6', '30', '30', 'orange']
# ['circle', '2', '2', '30', 'spring_green', 'rect', '6', '6', '30', '30', 'orange']
# ------------------------------------
# 9745.png
# ['circle', '6', '2', '90', 'pink', 'rect', '6', '9', '90', '90', 'skyblue']
# ['circle', '6', '2', '100', 'pink', 'rect', '6', '9', '100', '100', 'skyblue']
# ------------------------------------
# 9942.png
# ['circle', '3', '6', '110', 'deep_pink', 'rect', '5', '6', '110', '110', 'deep_pink']
# ['circle', '3', '5', '110', 'deep_pink', 'rect', '6', '6', '110', '110', 'red']
# ------------------------------------
# 9933.png
# ['circle', '3', '1', '80', 'purple', 'rect', '4', '2', '80', '80', 'pink']
# ['circle', '3', '1', '80', 'purple', 'rect', '4', '2', '80', '80', 'blue']
# ------------------------------------
# 9779.png
# ['circle', '8', '3', '20', 'skyblue', 'rect', '3', '7', '20', '20', 'orange']
# ['circle', '8', '10', '20', 'skyblue', 'rect', '4', '7', '20', '20', 'yellow']
# ------------------------------------
# 9789.png
# ['circle', '2', '5', '40', 'red', 'rect', '5', '7', '40', '40', 'red']
# ['circle', '2', '5', '40', 'red', 'rect', '6', '7', '40', '40', 'red']
# ------------------------------------
# 9840.png
# ['circle', '10', '5', '30', 'yellow', 'rect', '5', '6', '30', '30', 'lime']
# ['circle', '10', '5', '30', 'yellow', 'rect', '5', '6', '30', '30', 'lime']
# ------------------------------------
# 9844.png
# ['circle', '4', '10', '60', 'green', 'rect', '3', '6', '60', '60', 'green']
# ['circle', '4', '10', '60', 'green', 'rect', '3', '8', '60', '60', 'green']
# ------------------------------------
# 9708.png
# ['circle', '8', '2', '90', 'lime', 'rect', '2', '6', '90', '90', 'deep_pink']
# ['circle', '7', '2', '100', 'lime', 'rect', '2', '6', '100', '100', 'deep_pink']
# ------------------------------------
# 9753.png
# ['circle', '1', '2', '60', 'green', 'rect', '4', '5', '60', '60', 'red']
# ['circle', '1', '2', '60', 'green', 'rect', '4', '5', '60', '60', 'red']
# ------------------------------------
# 9992.png
# ['circle', '10', '9', '60', 'spring_green', 'rect', '5', '1', '60', '60', 'spring_green']
# ['circle', '9', '9', '60', 'spring_green', 'rect', '5', '1', '60', '60', 'cyan']
# ------------------------------------
# 9882.png
# ['circle', '8', '8', '100', 'cyan', 'rect', '1', '5', '100', '100', 'cyan']
# ['circle', '7', '8', '100', 'cyan', 'rect', '1', '5', '100', '100', 'cyan']
# ------------------------------------
# 9705.png
# ['circle', '8', '4', '110', 'red', 'rect', '4', '1', '110', '110', 'cyan']
# ['circle', '8', '4', '110', 'red', 'rect', '4', '1', '110', '110', 'cyan']
# ------------------------------------
# 9855.png
# ['circle', '4', '1', '90', 'pink', 'rect', '7', '9', '90', '90', 'deep_pink']
# ['circle', '4', '1', '90', 'pink', 'rect', '7', '9', '90', '90', 'deep_pink']
# ------------------------------------
# 9804.png
# ['circle', '1', '1', '110', 'cyan', 'rect', '8', '3', '110', '110', 'pink']
# ['circle', '1', '2', '100', 'cyan', 'rect', '8', '3', '100', '100', 'pink']
# ------------------------------------
# 9800.png
# ['circle', '4', '1', '50', 'blue', 'rect', '8', '7', '50', '50', 'blue']
# ['circle', '4', '1', '50', 'blue', 'rect', '8', '7', '50', '50', 'blue']
# ------------------------------------
# 9895.png
# ['circle', '3', '6', '110', 'cyan', 'rect', '8', '3', '110', '110', 'deep_pink']
# ['circle', '3', '6', '110', 'cyan', 'rect', '8', '3', '110', '110', 'deep_pink']
# ------------------------------------
# 9987.png
# ['circle', '1', '5', '40', 'red', 'rect', '6', '9', '40', '40', 'purple']
# ['circle', '1', '6', '40', 'red', 'rect', '6', '9', '40', '40', 'purple']
# ------------------------------------
# 9880.png
# ['circle', '1', '5', '60', 'spring_green', 'rect', '3', '5', '60', '60', 'skyblue']
# ['circle', '1', '5', '60', 'spring_green', 'rect', '3', '5', '70', '70', 'blue']
# ------------------------------------
# 9909.png
# ['circle', '1', '5', '70', 'green', 'rect', '8', '4', '70', '70', 'deep_pink']
# ['circle', '1', '5', '80', 'green', 'rect', '8', '4', '80', '80', 'deep_pink']
# ------------------------------------
# 9785.png
# ['circle', '9', '7', '70', 'deep_pink', 'rect', '3', '7', '70', '70', 'red']
# ['circle', '9', '7', '70', 'deep_pink', 'rect', '3', '7', '70', '70', 'red']
# ------------------------------------
# 9832.png
# ['circle', '1', '3', '100', 'blue', 'rect', '9', '8', '100', '100', 'blue']
# ['circle', '1', '3', '110', 'blue', 'rect', '9', '8', '110', '110', 'blue']
# ------------------------------------
# 9916.png
# ['circle', '5', '6', '30', 'spring_green', 'rect', '9', '5', '30', '30', 'spring_green']
# ['circle', '5', '6', '40', 'cyan', 'rect', '9', '4', '40', '40', 'spring_green']
# ------------------------------------
# 9994.png
# ['circle', '9', '2', '80', 'blue', 'rect', '8', '9', '80', '80', 'orange']
# ['circle', '9', '2', '80', 'blue', 'rect', '8', '9', '80', '80', 'orange']
# ------------------------------------
# 9854.png
# ['circle', '4', '7', '40', 'yellow', 'rect', '2', '3', '40', '40', 'cyan']
# ['circle', '4', '7', '40', 'yellow', 'rect', '2', '3', '40', '40', 'cyan']
# ------------------------------------
# 9970.png
# ['circle', '8', '7', '40', 'yellow', 'rect', '3', '3', '40', '40', 'spring_green']
# ['circle', '8', '7', '40', 'yellow', 'rect', '3', '3', '50', '50', 'spring_green']
# ------------------------------------
# 9848.png
# ['circle', '10', '4', '50', 'yellow', 'rect', '8', '4', '50', '50', 'green']
# ['circle', '10', '5', '50', 'yellow', 'rect', '8', '4', '50', '50', 'green']
# ------------------------------------
# 9853.png
# ['circle', '9', '8', '40', 'yellow', 'rect', '10', '8', '40', '40', 'cyan']
# ['circle', '9', '8', '40', 'yellow', 'rect', '10', '8', '40', '40', 'cyan']
# ------------------------------------
# 9720.png
# ['circle', '5', '6', '80', 'deep_pink', 'rect', '4', '10', '80', '80', 'orange']
# ['circle', '5', '7', '80', 'deep_pink', 'rect', '4', '10', '80', '80', 'orange']
# ------------------------------------
# 9740.png
# ['circle', '10', '10', '50', 'pink', 'rect', '8', '8', '50', '50', 'cyan']
# ['circle', '10', '10', '50', 'pink', 'rect', '8', '8', '50', '50', 'cyan']
# ------------------------------------
# 9760.png
# ['circle', '10', '1', '30', 'spring_green', 'rect', '4', '7', '30', '30', 'orange']
# ['circle', '10', '1', '30', 'green', 'rect', '4', '7', '30', '30', 'orange']
# ------------------------------------
# 9872.png
# ['circle', '10', '3', '60', 'green', 'rect', '8', '6', '60', '60', 'spring_green']
# ['circle', '10', '1', '60', 'green', 'rect', '9', '6', '60', '60', 'spring_green']
# ------------------------------------
# 9835.png
# ['circle', '9', '1', '30', 'skyblue', 'rect', '5', '7', '30', '30', 'orange']
# ['circle', '8', '1', '30', 'skyblue', 'rect', '4', '7', '30', '30', 'orange']
# ------------------------------------
# 9704.png
# ['circle', '7', '1', '80', 'pink', 'rect', '9', '7', '80', '80', 'spring_green']
# ['circle', '7', '1', '80', 'pink', 'rect', '9', '7', '80', '80', 'spring_green']
# ------------------------------------
# 9978.png
# ['circle', '6', '6', '60', 'red', 'rect', '4', '5', '60', '60', 'skyblue']
# ['circle', '6', '6', '60', 'red', 'rect', '9', '5', '60', '60', 'skyblue']
# ------------------------------------
# 9967.png
# ['circle', '8', '4', '60', 'deep_pink', 'rect', '5', '1', '60', '60', 'yellow']
# ['circle', '8', '4', '60', 'deep_pink', 'rect', '5', '1', '60', '60', 'yellow']
# ------------------------------------
# 9912.png
# ['circle', '3', '5', '90', 'orange', 'rect', '4', '1', '90', '90', 'red']
# ['circle', '3', '5', '90', 'orange', 'rect', '4', '1', '90', '90', 'red']
# ------------------------------------
# 9794.png
# ['circle', '10', '9', '80', 'yellow', 'rect', '6', '5', '80', '80', 'yellow']
# ['circle', '10', '10', '90', 'yellow', 'rect', '6', '4', '90', '90', 'yellow']
# ------------------------------------
# 9893.png
# ['circle', '4', '6', '100', 'deep_pink', 'rect', '5', '4', '100', '100', 'red']
# ['circle', '4', '6', '100', 'red', 'rect', '6', '4', '100', '100', 'red']
# ------------------------------------
# 9799.png
# ['circle', '9', '1', '60', 'lime', 'rect', '5', '10', '60', '60', 'yellow']
# ['circle', '9', '1', '60', 'lime', 'rect', '5', '10', '60', '60', 'yellow']
# ------------------------------------
# 9793.png
# ['circle', '3', '1', '50', 'purple', 'rect', '8', '3', '50', '50', 'deep_pink']
# ['circle', '3', '1', '50', 'purple', 'rect', '8', '3', '50', '50', 'pink']
# ------------------------------------
# 9875.png
# ['circle', '2', '9', '110', 'green', 'rect', '9', '2', '110', '110', 'lime']
# ['circle', '2', '9', '110', 'green', 'rect', '9', '2', '110', '110', 'green']
# ------------------------------------
# 9850.png
# ['circle', '3', '7', '110', 'purple', 'rect', '6', '7', '110', '110', 'deep_pink']
# ['circle', '3', '7', '110', 'purple', 'rect', '7', '7', '110', '110', 'pink']
# ------------------------------------
# 9972.png
# ['circle', '6', '7', '30', 'skyblue', 'rect', '7', '3', '30', '30', 'yellow']
# ['circle', '6', '7', '30', 'skyblue', 'rect', '7', '3', '30', '30', 'yellow']
# ------------------------------------
# 9861.png
# ['circle', '7', '9', '90', 'spring_green', 'rect', '10', '9', '90', '90', 'skyblue']
# ['circle', '7', '9', '90', 'spring_green', 'rect', '10', '10', '90', '90', 'skyblue']
# ------------------------------------
# 9877.png
# ['circle', '2', '2', '20', 'green', 'rect', '3', '6', '20', '20', 'blue']
# ['circle', '2', '1', '20', 'green', 'rect', '3', '6', '20', '20', 'skyblue']
# ------------------------------------
# 9787.png
# ['circle', '4', '6', '90', 'cyan', 'rect', '1', '5', '90', '90', 'cyan']
# ['circle', '4', '6', '90', 'skyblue', 'rect', '1', '5', '90', '90', 'cyan']
# ------------------------------------
# 9989.png
# ['circle', '9', '1', '50', 'pink', 'rect', '7', '7', '50', '50', 'yellow']
# ['circle', '9', '1', '50', 'purple', 'rect', '7', '7', '50', '50', 'yellow']
# ------------------------------------
# 9723.png
# ['circle', '3', '7', '70', 'pink', 'rect', '10', '5', '70', '70', 'pink']
# ['circle', '3', '7', '70', 'pink', 'rect', '10', '5', '70', '70', 'pink']
# ------------------------------------
# 9950.png
# ['circle', '3', '6', '70', 'lime', 'rect', '9', '4', '70', '70', 'deep_pink']
# ['circle', '3', '6', '70', 'green', 'rect', '8', '4', '70', '70', 'deep_pink']
# ------------------------------------
# 9765.png
# ['circle', '3', '8', '60', 'skyblue', 'rect', '5', '1', '60', '60', 'orange']
# ['circle', '3', '8', '60', 'skyblue', 'rect', '5', '2', '60', '60', 'orange']
# ------------------------------------
# 9913.png
# ['circle', '9', '6', '80', 'green', 'rect', '2', '8', '80', '80', 'lime']
# ['circle', '8', '6', '80', 'green', 'rect', '2', '8', '80', '80', 'lime']
# ------------------------------------
# 9750.png
# ['circle', '1', '5', '90', 'spring_green', 'rect', '5', '5', '90', '90', 'deep_pink']
# ['circle', '1', '5', '100', 'cyan', 'rect', '5', '5', '100', '100', 'deep_pink']
# ------------------------------------
# 9757.png
# ['circle', '1', '8', '80', 'cyan', 'rect', '6', '1', '80', '80', 'spring_green']
# ['circle', '1', '9', '90', 'cyan', 'rect', '6', '1', '90', '90', 'spring_green']
# ------------------------------------
# 9852.png
# ['circle', '6', '4', '20', 'yellow', 'rect', '4', '9', '20', '20', 'skyblue']
# ['circle', '6', '4', '20', 'yellow', 'rect', '4', '9', '20', '20', 'cyan']
# ------------------------------------
# 9902.png
# ['circle', '10', '8', '60', 'deep_pink', 'rect', '1', '10', '60', '60', 'yellow']
# ['circle', '9', '8', '60', 'deep_pink', 'rect', '1', '10', '60', '60', 'yellow']
# ------------------------------------
# 9709.png
# ['circle', '8', '2', '90', 'green', 'rect', '2', '5', '90', '90', 'skyblue']
# ['circle', '8', '2', '90', 'green', 'rect', '2', '5', '90', '90', 'skyblue']
# ------------------------------------
# 9780.png
# ['circle', '4', '6', '100', 'skyblue', 'rect', '5', '2', '100', '100', 'blue']
# ['circle', '4', '6', '100', 'skyblue', 'rect', '5', '4', '100', '100', 'blue']
# ------------------------------------
# 9965.png
# ['circle', '5', '1', '80', 'spring_green', 'rect', '2', '9', '80', '80', 'yellow']
# ['circle', '5', '1', '80', 'spring_green', 'rect', '2', '9', '80', '80', 'yellow']
# ------------------------------------
# 9764.png
# ['circle', '2', '4', '100', 'spring_green', 'rect', '8', '8', '100', '100', 'skyblue']
# ['circle', '2', '4', '100', 'spring_green', 'rect', '8', '8', '100', '100', 'skyblue']
# ------------------------------------
# 9924.png
# ['circle', '5', '3', '90', 'yellow', 'rect', '10', '9', '90', '90', 'spring_green']
# ['circle', '4', '3', '90', 'yellow', 'rect', '10', '9', '90', '90', 'spring_green']
# ------------------------------------
# 9887.png
# ['circle', '1', '8', '30', 'blue', 'rect', '9', '10', '30', '30', 'yellow']
# ['circle', '1', '8', '30', 'blue', 'rect', '9', '10', '30', '30', 'yellow']
# ------------------------------------
# 9701.png
# ['circle', '8', '5', '50', 'yellow', 'rect', '6', '8', '50', '50', 'lime']
# ['circle', '8', '5', '50', 'orange', 'rect', '6', '8', '50', '50', 'lime']
# ------------------------------------
# 9894.png
# ['circle', '1', '3', '90', 'green', 'rect', '1', '7', '90', '90', 'red']
# ['circle', '1', '1', '110', 'green', 'rect', '1', '7', '110', '110', 'red']
# ------------------------------------
# 9905.png
# ['circle', '4', '6', '110', 'lime', 'rect', '10', '1', '110', '110', 'cyan']
# ['circle', '4', '6', '120', 'lime', 'rect', '10', '1', '120', '120', 'skyblue']
# ------------------------------------
# 9906.png
# ['circle', '7', '4', '100', 'deep_pink', 'rect', '4', '4', '100', '100', 'orange']
# ['circle', '8', '4', '100', 'deep_pink', 'rect', '4', '4', '110', '110', 'orange']
# ------------------------------------
# 9884.png
# ['circle', '3', '6', '40', 'lime', 'rect', '3', '5', '40', '40', 'spring_green']
# ['circle', '3', '6', '50', 'yellow', 'rect', '3', '5', '50', '50', 'cyan']
# ------------------------------------
# 9843.png
# ['circle', '6', '8', '30', 'lime', 'rect', '7', '1', '30', '30', 'green']
# ['circle', '6', '7', '30', 'lime', 'rect', '7', '2', '30', '30', 'green']
# ------------------------------------
# 9719.png
# ['circle', '7', '8', '30', 'red', 'rect', '5', '1', '30', '30', 'skyblue']
# ['circle', '7', '8', '30', 'red', 'rect', '6', '1', '30', '30', 'skyblue']
# ------------------------------------
# 9949.png
# ['circle', '10', '7', '40', 'purple', 'rect', '7', '7', '40', '40', 'lime']
# ['circle', '10', '7', '40', 'purple', 'rect', '7', '7', '40', '40', 'lime']
# ------------------------------------
# 9982.png
# ['circle', '7', '8', '60', 'purple', 'rect', '7', '5', '60', '60', 'blue']
# ['circle', '7', '8', '60', 'purple', 'rect', '7', '5', '60', '60', 'blue']
# ------------------------------------
# 9769.png
# ['circle', '1', '5', '20', 'orange', 'rect', '5', '8', '20', '20', 'green']
# ['circle', '1', '5', '20', 'orange', 'rect', '5', '8', '20', '20', 'green']
# ------------------------------------
# 9871.png
# ['circle', '10', '7', '90', 'yellow', 'rect', '6', '7', '90', '90', 'cyan']
# ['circle', '10', '7', '90', 'yellow', 'rect', '6', '7', '90', '90', 'cyan']
# ------------------------------------
# 9910.png
# ['circle', '10', '9', '80', 'purple', 'rect', '10', '6', '80', '80', 'deep_pink']
# ['circle', '10', '10', '100', 'purple', 'rect', '10', '6', '110', '110', 'red']
# ------------------------------------
# 9825.png
# ['circle', '8', '10', '20', 'spring_green', 'rect', '7', '7', '30', '30', 'pink']
# ['circle', '7', '10', '20', 'spring_green', 'rect', '7', '7', '30', '30', 'pink']
# ------------------------------------
# 9885.png
# ['circle', '6', '3', '60', 'red', 'rect', '2', '8', '60', '60', 'skyblue']
# ['circle', '6', '3', '60', 'red', 'rect', '2', '7', '60', '60', 'skyblue']
# ------------------------------------
# 9857.png
# ['circle', '5', '9', '30', 'red', 'rect', '5', '2', '30', '30', 'red']
# ['circle', '4', '9', '30', 'red', 'rect', '4', '2', '30', '30', 'red']
# ------------------------------------
# 9837.png
# ['circle', '1', '8', '80', 'cyan', 'rect', '5', '8', '80', '80', 'lime']
# ['circle', '1', '8', '90', 'cyan', 'rect', '4', '8', '90', '90', 'lime']
# ------------------------------------
# 9812.png
# ['circle', '9', '9', '80', 'lime', 'rect', '9', '4', '80', '80', 'orange']
# ['circle', '9', '10', '90', 'lime', 'rect', '9', '5', '90', '90', 'orange']
# ------------------------------------
# 9817.png
# ['circle', '7', '7', '20', 'lime', 'rect', '1', '4', '20', '20', 'yellow']
# ['circle', '7', '7', '20', 'lime', 'rect', '1', '5', '20', '20', 'yellow']
# ------------------------------------
# 9827.png
# ['circle', '7', '4', '30', 'spring_green', 'rect', '7', '8', '30', '30', 'pink']
# ['circle', '7', '4', '30', 'spring_green', 'rect', '7', '8', '30', '30', 'pink']
# ------------------------------------
# 9738.png
# ['circle', '2', '4', '30', 'green', 'rect', '1', '4', '30', '30', 'orange']
# ['circle', '2', '4', '30', 'green', 'rect', '1', '2', '30', '30', 'orange']
# ------------------------------------
# 9816.png
# ['circle', '2', '9', '60', 'spring_green', 'rect', '8', '4', '60', '60', 'cyan']
# ['circle', '2', '9', '60', 'cyan', 'rect', '8', '4', '60', '60', 'cyan']
# ------------------------------------
# 9960.png
# ['circle', '2', '7', '90', 'blue', 'rect', '8', '1', '90', '90', 'deep_pink']
# ['circle', '2', '7', '90', 'blue', 'rect', '8', '1', '90', '90', 'red']
# ------------------------------------
# 9842.png
# ['circle', '4', '5', '70', 'skyblue', 'rect', '3', '5', '70', '70', 'red']
# ['circle', '4', '6', '70', 'skyblue', 'rect', '4', '5', '70', '70', 'red']
# ------------------------------------
# 9712.png
# ['circle', '10', '8', '70', 'pink', 'rect', '1', '6', '70', '70', 'pink']
# ['circle', '10', '8', '70', 'purple', 'rect', '1', '6', '70', '70', 'pink']
# ------------------------------------
# 9931.png
# ['circle', '1', '7', '110', 'orange', 'rect', '3', '8', '110', '110', 'orange']
# ['circle', '1', '7', '110', 'yellow', 'rect', '3', '8', '110', '110', 'orange']
# ------------------------------------
# 9867.png
# ['circle', '3', '3', '70', 'yellow', 'rect', '8', '2', '70', '70', 'purple']
# ['circle', '3', '3', '70', 'yellow', 'rect', '9', '2', '70', '70', 'purple']
# ------------------------------------
# 9732.png
# ['circle', '7', '8', '80', 'spring_green', 'rect', '2', '1', '80', '80', 'pink']
# ['circle', '6', '8', '90', 'spring_green', 'rect', '2', '1', '90', '90', 'pink']
# ------------------------------------
# 9846.png
# ['circle', '8', '3', '100', 'lime', 'rect', '2', '6', '100', '100', 'green']
# ['circle', '7', '4', '100', 'lime', 'rect', '2', '6', '100', '100', 'green']
# ------------------------------------
# 9820.png
# ['circle', '1', '4', '110', 'purple', 'rect', '4', '4', '110', '110', 'blue']
# ['circle', '1', '4', '100', 'purple', 'rect', '4', '3', '110', '110', 'blue']
# ------------------------------------
# 9798.png
# ['circle', '10', '9', '90', 'blue', 'rect', '9', '8', '90', '90', 'green']
# ['circle', '9', '9', '90', 'blue', 'rect', '9', '8', '90', '90', 'blue']
# ------------------------------------
# 9996.png
# ['circle', '9', '2', '20', 'cyan', 'rect', '9', '2', '20', '20', 'cyan']
# ['circle', '1', '2', '20', 'cyan', 'rect', '9', '3', '20', '20', 'cyan']
# ------------------------------------
# 9822.png
# ['circle', '3', '1', '30', 'orange', 'rect', '7', '10', '30', '30', 'red']
# ['circle', '3', '1', '30', 'orange', 'rect', '6', '10', '30', '30', 'red']
# ------------------------------------
# 9947.png
# ['circle', '10', '8', '20', 'orange', 'rect', '1', '7', '20', '20', 'orange']
# ['circle', '1', '9', '20', 'green', 'rect', '1', '7', '20', '20', 'orange']
# ------------------------------------
# 9741.png
# ['circle', '3', '5', '60', 'pink', 'rect', '1', '8', '60', '60', 'spring_green']
# ['circle', '3', '5', '60', 'pink', 'rect', '1', '8', '60', '60', 'spring_green']
# ------------------------------------
# 9735.png
# ['circle', '7', '1', '60', 'yellow', 'rect', '4', '5', '60', '60', 'blue']
# ['circle', '6', '1', '60', 'yellow', 'rect', '4', '5', '60', '60', 'blue']
# ------------------------------------
# 9936.png
# ['circle', '8', '6', '40', 'pink', 'rect', '4', '7', '40', '40', 'red']
# ['circle', '8', '7', '40', 'pink', 'rect', '4', '7', '40', '40', 'red']
# ------------------------------------
# 9911.png
# ['circle', '2', '1', '60', 'spring_green', 'rect', '6', '3', '60', '60', 'deep_pink']
# ['circle', '2', '1', '60', 'spring_green', 'rect', '6', '3', '60', '60', 'deep_pink']
# ------------------------------------
# 9940.png
# ['circle', '9', '6', '100', 'pink', 'rect', '9', '5', '100', '100', 'orange']
# ['circle', '9', '6', '100', 'pink', 'rect', '9', '1', '100', '100', 'orange']
# ------------------------------------
# 9966.png
# ['circle', '7', '9', '50', 'blue', 'rect', '5', '4', '50', '50', 'red']
# ['circle', '6', '9', '50', 'blue', 'rect', '5', '4', '50', '50', 'red']
# ------------------------------------
# 9941.png
# ['circle', '8', '9', '40', 'yellow', 'rect', '4', '8', '40', '40', 'yellow']
# ['circle', '9', '10', '40', 'yellow', 'rect', '4', '8', '40', '40', 'yellow']
# ------------------------------------
# 9907.png
# ['circle', '10', '10', '60', 'yellow', 'rect', '7', '9', '60', '60', 'purple']
# ['circle', '10', '10', '50', 'yellow', 'rect', '7', '9', '50', '50', 'purple']
# ------------------------------------
# 9937.png
# ['circle', '9', '6', '90', 'yellow', 'rect', '6', '8', '90', '90', 'cyan']
# ['circle', '9', '7', '100', 'yellow', 'rect', '6', '8', '100', '100', 'cyan']
# ------------------------------------
# 9810.png
# ['circle', '8', '7', '40', 'cyan', 'rect', '3', '6', '40', '40', 'pink']
# ['circle', '8', '7', '40', 'cyan', 'rect', '3', '5', '40', '40', 'pink']
# ------------------------------------
# 9959.png
# ['circle', '3', '6', '30', 'deep_pink', 'rect', '3', '1', '30', '30', 'pink']
# ['circle', '3', '6', '30', 'deep_pink', 'rect', '3', '2', '30', '30', 'pink']
# ------------------------------------
# 9899.png
# ['circle', '2', '5', '40', 'purple', 'rect', '5', '8', '40', '40', 'blue']
# ['circle', '2', '5', '40', 'purple', 'rect', '5', '8', '40', '40', 'blue']
# ------------------------------------
# 9767.png
# ['circle', '7', '1', '40', 'lime', 'rect', '9', '8', '40', '40', 'green']
# ['circle', '7', '1', '40', 'lime', 'rect', '9', '8', '40', '40', 'green']
# ------------------------------------
# 9751.png
# ['circle', '5', '7', '90', 'lime', 'rect', '5', '10', '90', '90', 'orange']
# ['circle', '4', '7', '90', 'lime', 'rect', '7', '10', '90', '90', 'orange']
# ------------------------------------
# 9818.png
# ['circle', '2', '6', '110', 'lime', 'rect', '9', '6', '110', '110', 'pink']
# ['circle', '2', '6', '110', 'lime', 'rect', '9', '6', '110', '110', 'pink']
# ------------------------------------
# 9891.png
# ['circle', '5', '9', '40', 'cyan', 'rect', '8', '1', '40', '40', 'orange']
# ['circle', '5', '9', '50', 'cyan', 'rect', '8', '1', '50', '50', 'yellow']
# ------------------------------------
# 9886.png
# ['circle', '3', '9', '90', 'lime', 'rect', '2', '8', '90', '90', 'blue']
# ['circle', '3', '9', '90', 'lime', 'rect', '2', '6', '90', '90', 'blue']
# ------------------------------------
# 9927.png
# ['circle', '1', '6', '20', 'red', 'rect', '8', '1', '20', '20', 'pink']
# ['circle', '1', '6', '20', 'red', 'rect', '8', '2', '20', '20', 'pink']
# ------------------------------------

# %%
        
print('shape match: %.4f, location match: %.4f,location match_rect: %.4f, radius_match: %.4f, rect_x_match: %.4f, rect_y_match: %.4f color_match: %.4f'
     %(shape_match/(len(test_list)*2), location_match/(len(test_list)*2), location_match_rect/(len(test_list)*2),
      radius_match/len(test_list), rect_x_match/len(test_list), rect_y_match/len(test_list), color_match/(len(test_list)*2)))
# Out:
# shape match: 1.0000, location match: 0.8467,location match_rect: 0.8450, radius_match: 0.8300, rect_x_match: 0.7900, rect_y_match: 0.7900 color_match: 0.8833

# %%
x_ = {x:rect_x_err.count(x) for x in rect_x_err}
y_ = {x:rect_y_err.count(x) for x in rect_y_err}
r_ = {x:radius_err.count(x) for x in radius_err}
loc_ ={x:location_err.count(x) for x in location_err}
loc_rect_ = {x:location_err_rect.count(x) for x in location_err_rect}

# %%
loc_

# %%
test_dir = 'data/2object_test/bitmap/'
cap_dir = 'data/2object_test/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

for fname in test_list: 
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))


    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    sentence = ' '.join(sampled_caption)
    print(sentence)
    predict = sentence.split()[1]
    
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    with open(cap_path, 'r') as f:
        target = f.readline()
        print('target: '+ target)
    if predict == target:
        print('corret')
    #    cnt+=1 
        
print(cnt)

# %%
feature.unsqueeze(1)

# %%
cap_path = img_list[0].split('.')[0]+'.svg'

# %%
cap_path
