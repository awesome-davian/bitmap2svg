# %%
import torch
import matplotlib.pyplot as plt
import numpy as np 
import argparse
import pickle 
import os
from attn_model import ResidualBlock, AttnEncoder, AttnDecoderRnn
from torch.autograd import Variable 
from torchvision import transforms 
from data_loader import build_vocab 
from PIL import Image


embed_size = 256
hidden_size = 512 
feature_size= 256
num_layers = 1 
decoder_path = './models/attn/1object/decoder-10-150.pkl'
encoder_path = './models/attn/1object/encoder-10-150.pkl'


def to_var(x, volatile=False):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x, volatile=volatile)

def load_image(image_path, transform=None):
    image = Image.open(image_path).convert('RGB')
    image = image.resize([64, 64], Image.LANCZOS)
    
    if transform is not None:
        image = transform(image).unsqueeze(0)
    
    return image

transform = transforms.Compose([ 
    transforms.ToTensor(), 
    transforms.Normalize((0.033, 0.032, 0.033), 
                         (0.027, 0.027, 0.027))])



vocab_path = './data/attn/vocab1.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
len_vocab = vocab.idx

# Build Models
encoder = AttnEncoder(ResidualBlock, [3, 3, 3])
encoder.eval()  # evaluation mode (BN uses moving mean/variance)
decoder = AttnDecoderRnn(feature_size, hidden_size, 
                     len(vocab), num_layers)


# Load the trained model parameters
encoder.load_state_dict(torch.load(encoder_path))
decoder.load_state_dict(torch.load(decoder_path))

# If use gpu
if torch.cuda.is_available():
    encoder.cuda()
    decoder.cuda()

# %%
image_dir = 'data/circle_and_rect/bitmap/1.png'
test_image = load_image(image_dir,transform)
image_tensor = to_var(test_image)

# %%
features = encoder(image_tensor)
h,c = decoder.init_lstm(features)

# %%
sums = torch.sum(features, 1)
out = torch.mul(sums, 1/features.size(1))
out = out.squeeze(1).unsqueeze(0)
out = decoder.init_layer(out.squeeze(0)).unsqueeze(0)

# %%
import torch.nn.functional as F
de_hidden = decoder.attn.attn(h.squeeze(0)).unsqueeze(2)
attn_weight = torch.bmm(features, de_hidden)
attn_weight = attn_weight.squeeze(2)
attn_weight = F.softmax(attn_weight).unsqueeze(2)
#attn_weight = F.softmax(attn_weight)

# %%
context = torch.bmm(attn_weight.transpose(2,1),features)

# %%
context

# %%
x = Variable(torch.rand(1,1,256)).cuda()
#x = decoder.embed((temp))
context = decoder.attn(h, features)
lstm_input = torch.cat((context, x) ,2)
lstm_out, (h,c) = decoder.lstm(lstm_input, (h,c))

# %%
F.softmax(attn_weight.squeeze(2)).unsq

# %%
de_hidden = decoder.attn.attn(h.squeeze(0)).unsqueeze(2)
attn_weight = torch.bmm(features, de_hidden)

# %%
out_ = torch.mul(sums,1/features.size(1))
out2= decoder.init_layer(out_)

# %%
import torch.nn.functional as F
F.tanh(out2)

# %%
de_hidden = decoder.attn.attn(h.squeeze(0)).unsqueeze(2)
attn_weight = torch.bmm(features, de_hidden)

# %%
de_hidden

# %%
features = encoder(image_tensor)
h,c = decoder.init_lstm(features)
x = Variable(torch.rand(1,1,256)).cuda()
#x = decoder.embed((temp))
context = decoder.attn(h, features)
lstm_input = torch.cat((context, x) ,2)
lstm_out, (h,c) = decoder.lstm(lstm_input, (h,c))          # (batch_size, 1, hidden_size), 
out = decoder.decode_lstm(x, context, h, lstm_out)
predicted = out.max(1)[1]

# %%
de_hidden = decoder.attn.attn(h.squeeze(0)).unsqueeze(2)
attn_weight = torch.bmm(features, de_hidden)

# %%
attn_weight

# %%
temp = Variable(torch.Tensor([1]).cuda().unsqueeze(1).long())

# %%
decoder.embed(predicted)

# %%
test_dir = 'data/circle_and_rect/bitmap/'
cap_dir = 'data/circle_and_rect/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

shape_match = 0
location_match = 0
radius_match = 0 
rect_x_match = 0 
rect_y_match = 0 
length_match = 0
for fname in test_list: 
    #cnt+=1 
    if cnt>2:
        break;
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))
    print(fname)

    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    in_caption = sampled_caption[1:-1]
    print(in_caption)
    
    #read target caption
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    trg_caption = [] 
    with open(cap_path, 'r') as f:
        target = f.readline().split()
        for word in target:
            trg_caption.append(word)
    print(trg_caption)
    print('-------------------------------------------------------------------')
    
    
    if(len(in_caption) == len(trg_caption)):        
        length_match += 1
        
print(length_match)
# Out:
# 748.png
# ['circle', '9', '5', '100', 'lime']
# ['circle', '9', '5', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1788.png
# ['rect', '10', '10', '60', '60', 'blue']
# ['rect', '10', '10', '110', '110', 'orange']
# -------------------------------------------------------------------
# 1594.png
# ['circle', '10', '3', '100', 'lime']
# ['circle', '10', '3', '110', 'pink']
# -------------------------------------------------------------------
# 1121.png
# ['circle', '1', '9', '60', 'orange']
# ['circle', '1', '9', '60', 'deep_pink']
# -------------------------------------------------------------------
# 1288.png
# ['circle', '8', '6', '110', 'lime']
# ['circle', '8', '6', '100', 'purple']
# -------------------------------------------------------------------
# 606.png
# ['rect', '5', '2', '70', '70', 'spring_green']
# ['circle', '6', '3', '40', 'pink']
# -------------------------------------------------------------------
# 468.png
# ['circle', '6', '7', '70', 'cyan']
# ['rect', '5', '5', '120', '120', 'red']
# -------------------------------------------------------------------
# 596.png
# ['rect', '3', '4', '30', '30', 'spring_green']
# ['rect', '3', '3', '40', '40', 'purple']
# -------------------------------------------------------------------
# 1155.png
# ['circle', '8', '6', '60', 'orange']
# ['circle', '8', '6', '70', 'skyblue']
# -------------------------------------------------------------------
# 1300.png
# ['rect', '10', '6', '50', '50', 'spring_green']
# ['rect', '10', '6', '60', '60', 'skyblue']
# -------------------------------------------------------------------
# 489.png
# ['circle', '4', '6', '70', 'yellow']
# ['circle', '4', '6', '70', 'orange']
# -------------------------------------------------------------------
# 1421.png
# ['rect', '10', '1', '30', '30', 'blue']
# ['rect', '10', '1', '30', '30', 'blue']
# -------------------------------------------------------------------
# 754.png
# ['circle', '7', '1', '30', 'skyblue']
# ['rect', '6', '1', '70', '70', 'spring_green']
# -------------------------------------------------------------------
# 746.png
# ['circle', '5', '4', '80', 'orange']
# ['circle', '5', '4', '80', 'spring_green']
# -------------------------------------------------------------------
# 1284.png
# ['circle', '5', '3', '40', 'orange']
# ['circle', '5', '2', '50', 'red']
# -------------------------------------------------------------------
# 714.png
# ['circle', '4', '7', '70', 'orange']
# ['circle', '4', '7', '60', 'lime']
# -------------------------------------------------------------------
# 1721.png
# ['circle', '10', '6', '100', 'lime']
# ['circle', '10', '6', '100', 'yellow']
# -------------------------------------------------------------------
# 1531.png
# ['circle', '8', '8', '50', 'blue']
# ['circle', '8', '9', '50', 'spring_green']
# -------------------------------------------------------------------
# 1405.png
# ['rect', '7', '4', '80', '80', 'blue']
# ['circle', '8', '5', '40', 'orange']
# -------------------------------------------------------------------
# 723.png
# ['circle', '3', '3', '70', 'orange']
# ['circle', '3', '3', '70', 'green']
# -------------------------------------------------------------------
# 1700.png
# ['rect', '2', '7', '40', '40', 'red']
# ['circle', '2', '8', '30', 'yellow']
# -------------------------------------------------------------------
# 1717.png
# ['rect', '5', '1', '60', '60', 'blue']
# ['rect', '5', '1', '60', '60', 'red']
# -------------------------------------------------------------------
# 1719.png
# ['circle', '5', '4', '110', 'lime']
# ['circle', '5', '4', '100', 'red']
# -------------------------------------------------------------------
# 833.png
# ['circle', '1', '3', '100', 'red']
# ['circle', '2', '3', '90', 'cyan']
# -------------------------------------------------------------------
# 987.png
# ['circle', '3', '6', '60', 'orange']
# ['rect', '2', '6', '90', '90', 'pink']
# -------------------------------------------------------------------
# 698.png
# ['circle', '7', '9', '70', 'orange']
# ['circle', '7', '9', '70', 'skyblue']
# -------------------------------------------------------------------
# 178.png
# ['circle', '8', '6', '110', 'lime']
# ['circle', '9', '6', '110', 'lime']
# -------------------------------------------------------------------
# 1174.png
# ['rect', '3', '2', '60', '60', 'pink']
# ['circle', '4', '3', '30', 'red']
# -------------------------------------------------------------------
# 203.png
# ['rect', '9', '8', '80', '80', 'orange']
# ['rect', '9', '8', '90', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1160.png
# ['rect', '2', '7', '90', '90', 'spring_green']
# ['circle', '3', '8', '60', 'purple']
# -------------------------------------------------------------------
# 1226.png
# ['rect', '8', '6', '20', '20', 'blue']
# ['rect', '8', '6', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 1014.png
# ['circle', '3', '7', '60', 'orange']
# ['rect', '2', '6', '100', '100', 'green']
# -------------------------------------------------------------------
# 1363.png
# ['circle', '8', '8', '40', 'lime']
# ['circle', '8', '8', '40', 'cyan']
# -------------------------------------------------------------------
# 1749.png
# ['circle', '10', '8', '60', 'spring_green']
# ['rect', '9', '7', '110', '110', 'purple']
# -------------------------------------------------------------------
# 1087.png
# ['circle', '3', '5', '40', 'lime']
# ['rect', '2', '4', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 400.png
# ['rect', '8', '10', '60', '60', 'lime']
# ['rect', '8', '10', '70', '70', 'pink']
# -------------------------------------------------------------------
# 192.png
# ['circle', '3', '1', '40', 'green']
# ['circle', '3', '1', '40', 'blue']
# -------------------------------------------------------------------
# 2.png
# ['circle', '3', '6', '60', 'orange']
# ['circle', '3', '6', '60', 'lime']
# -------------------------------------------------------------------
# 1435.png
# ['circle', '7', '6', '60', 'orange']
# ['circle', '7', '5', '70', 'blue']
# -------------------------------------------------------------------
# 126.png
# ['circle', '10', '4', '80', 'pink']
# ['circle', '10', '4', '80', 'red']
# -------------------------------------------------------------------
# 711.png
# ['rect', '10', '1', '30', '30', 'blue']
# ['rect', '10', '1', '50', '50', 'yellow']
# -------------------------------------------------------------------
# 1293.png
# ['circle', '4', '10', '100', 'red']
# ['circle', '4', '10', '110', 'purple']
# -------------------------------------------------------------------
# 1129.png
# ['circle', '8', '1', '20', 'blue']
# ['circle', '8', '1', '30', 'yellow']
# -------------------------------------------------------------------
# 752.png
# ['circle', '5', '8', '90', 'lime']
# ['circle', '5', '7', '100', 'orange']
# -------------------------------------------------------------------
# 1625.png
# ['rect', '1', '8', '30', '30', 'blue']
# ['circle', '2', '8', '20', 'purple']
# -------------------------------------------------------------------
# 1098.png
# ['rect', '5', '2', '80', '80', 'lime']
# ['rect', '5', '2', '90', '90', 'orange']
# -------------------------------------------------------------------
# 910.png
# ['rect', '2', '7', '80', '80', 'lime']
# ['circle', '3', '8', '50', 'purple']
# -------------------------------------------------------------------
# 1172.png
# ['circle', '8', '4', '60', 'yellow']
# ['circle', '8', '4', '60', 'blue']
# -------------------------------------------------------------------
# 67.png
# ['rect', '4', '3', '80', '80', 'orange']
# ['circle', '5', '4', '50', 'skyblue']
# -------------------------------------------------------------------
# 925.png
# ['rect', '2', '4', '40', '40', 'orange']
# ['rect', '2', '4', '50', '50', 'orange']
# -------------------------------------------------------------------
# 1832.png
# ['circle', '3', '4', '100', 'yellow']
# ['circle', '3', '4', '100', 'yellow']
# -------------------------------------------------------------------
# 1067.png
# ['rect', '6', '5', '50', '50', 'yellow']
# ['circle', '7', '5', '30', 'spring_green']
# -------------------------------------------------------------------
# 1847.png
# ['circle', '10', '9', '100', 'lime']
# ['circle', '10', '9', '100', 'deep_pink']
# -------------------------------------------------------------------
# 355.png
# ['rect', '10', '7', '30', '30', 'blue']
# ['rect', '10', '8', '30', '30', 'spring_green']
# -------------------------------------------------------------------
# 1632.png
# ['rect', '3', '1', '20', '20', 'blue']
# ['rect', '3', '1', '20', '20', 'orange']
# -------------------------------------------------------------------
# 1825.png
# ['circle', '10', '7', '80', 'spring_green']
# ['circle', '10', '7', '80', 'cyan']
# -------------------------------------------------------------------
# 687.png
# ['rect', '6', '7', '50', '50', 'spring_green']
# ['circle', '6', '8', '30', 'purple']
# -------------------------------------------------------------------
# 340.png
# ['rect', '1', '8', '40', '40', 'blue']
# ['circle', '2', '9', '20', 'deep_pink']
# -------------------------------------------------------------------
# 1972.png
# ['circle', '8', '7', '100', 'yellow']
# ['circle', '8', '6', '100', 'purple']
# -------------------------------------------------------------------
# 70.png
# ['rect', '2', '9', '20', '20', 'blue']
# ['rect', '2', '9', '20', '20', 'yellow']
# -------------------------------------------------------------------
# 738.png
# ['circle', '4', '4', '60', 'orange']
# ['rect', '2', '3', '110', '110', 'deep_pink']
# -------------------------------------------------------------------
# 1948.png
# ['circle', '4', '6', '60', 'orange']
# ['circle', '4', '6', '60', 'deep_pink']
# -------------------------------------------------------------------
# 647.png
# ['circle', '10', '4', '60', 'orange']
# ['circle', '10', '4', '50', 'green']
# -------------------------------------------------------------------
# 1252.png
# ['rect', '2', '10', '40', '40', 'blue']
# ['rect', '2', '10', '60', '60', 'pink']
# -------------------------------------------------------------------
# 630.png
# ['rect', '8', '6', '30', '30', 'blue']
# ['rect', '8', '6', '30', '30', 'red']
# -------------------------------------------------------------------
# 1751.png
# ['rect', '4', '3', '40', '40', 'orange']
# ['rect', '4', '3', '50', '50', 'blue']
# -------------------------------------------------------------------
# 524.png
# ['rect', '6', '8', '40', '40', 'blue']
# ['rect', '6', '9', '50', '50', 'green']
# -------------------------------------------------------------------
# 204.png
# ['circle', '2', '6', '30', 'blue']
# ['rect', '1', '5', '60', '60', 'spring_green']
# -------------------------------------------------------------------
# 1557.png
# ['circle', '8', '10', '60', 'spring_green']
# ['rect', '7', '9', '110', '110', 'pink']
# -------------------------------------------------------------------
# 528.png
# ['circle', '5', '7', '60', 'blue']
# ['rect', '4', '6', '100', '100', 'cyan']
# -------------------------------------------------------------------
# 1134.png
# ['rect', '4', '1', '50', '50', 'spring_green']
# ['circle', '4', '1', '30', 'deep_pink']
# -------------------------------------------------------------------
# 1305.png
# ['rect', '9', '6', '70', '70', 'orange']
# ['rect', '9', '6', '70', '70', 'blue']
# -------------------------------------------------------------------
# 834.png
# ['circle', '1', '9', '110', 'spring_green']
# ['circle', '1', '9', '100', 'skyblue']
# -------------------------------------------------------------------
# 85.png
# ['rect', '4', '2', '100', '100', 'pink']
# ['rect', '4', '1', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 776.png
# ['circle', '1', '10', '80', 'spring_green']
# ['circle', '1', '10', '50', 'cyan']
# -------------------------------------------------------------------
# 78.png
# ['rect', '2', '7', '40', '40', 'red']
# ['rect', '2', '7', '50', '50', 'spring_green']
# -------------------------------------------------------------------
# 1397.png
# ['rect', '1', '8', '80', '80', 'red']
# ['circle', '2', '9', '50', 'pink']
# -------------------------------------------------------------------
# 1279.png
# ['circle', '2', '5', '100', 'yellow']
# ['circle', '2', '5', '100', 'yellow']
# -------------------------------------------------------------------
# 1433.png
# ['rect', '5', '1', '90', '90', 'lime']
# ['rect', '5', '1', '90', '90', 'orange']
# -------------------------------------------------------------------
# 365.png
# ['rect', '10', '5', '40', '40', 'yellow']
# ['rect', '10', '5', '30', '30', 'spring_green']
# -------------------------------------------------------------------
# 737.png
# ['circle', '8', '4', '60', 'spring_green']
# ['circle', '8', '4', '60', 'cyan']
# -------------------------------------------------------------------
# 1954.png
# ['rect', '6', '4', '20', '20', 'blue']
# ['rect', '6', '4', '20', '20', 'cyan']
# -------------------------------------------------------------------
# 1486.png
# ['rect', '6', '4', '50', '50', 'yellow']
# ['rect', '6', '4', '50', '50', 'skyblue']
# -------------------------------------------------------------------
# 1785.png
# ['circle', '3', '4', '40', 'spring_green']
# ['rect', '2', '3', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 1936.png
# ['rect', '1', '1', '100', '100', 'spring_green']
# ['rect', '1', '1', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 1839.png
# ['rect', '4', '1', '70', '70', 'orange']
# ['rect', '4', '1', '80', '80', 'deep_pink']
# -------------------------------------------------------------------
# 486.png
# ['rect', '4', '3', '20', '20', 'blue']
# ['rect', '4', '3', '30', '30', 'blue']
# -------------------------------------------------------------------
# 168.png
# ['rect', '5', '1', '80', '80', 'lime']
# ['circle', '6', '2', '50', 'spring_green']
# -------------------------------------------------------------------
# 15.png
# ['rect', '9', '10', '30', '30', 'orange']
# ['circle', '10', '10', '20', 'skyblue']
# -------------------------------------------------------------------
# 177.png
# ['rect', '10', '6', '50', '50', 'spring_green']
# ['circle', '10', '6', '30', 'lime']
# -------------------------------------------------------------------
# 543.png
# ['rect', '9', '7', '40', '40', 'blue']
# ['rect', '9', '6', '50', '50', 'lime']
# -------------------------------------------------------------------
# 582.png
# ['rect', '1', '10', '30', '30', 'blue']
# ['rect', '1', '10', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 214.png
# ['rect', '1', '6', '70', '70', 'orange']
# ['circle', '2', '7', '40', 'pink']
# -------------------------------------------------------------------
# 593.png
# ['rect', '8', '2', '60', '60', 'yellow']
# ['circle', '9', '3', '30', 'purple']
# -------------------------------------------------------------------
# 1323.png
# ['rect', '10', '6', '40', '40', 'cyan']
# ['rect', '10', '6', '50', '50', 'blue']
# -------------------------------------------------------------------
# 402.png
# ['circle', '5', '4', '110', 'lime']
# ['circle', '5', '4', '110', 'lime']
# -------------------------------------------------------------------
# 646.png
# ['rect', '5', '5', '40', '40', 'blue']
# ['circle', '5', '5', '30', 'pink']
# -------------------------------------------------------------------
# 1766.png
# ['circle', '1', '3', '60', 'yellow']
# ['circle', '1', '3', '60', 'blue']
# -------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-feb060f70cc7> in <module>()
#      20     # Generate caption from image
#      21     feature = encoder(image_tensor)
# ---> 22     sampled_ids = decoder.sample(feature)
#      23     ids_arr = []
#      24     for element in sampled_ids:
#
# /home/penielrome/pytorch/bitmap2svg/attn_model.py in sample(self, features)
#     166             lstm_input = torch.cat((context, x) ,2)
#     167             lstm_out, (h,c) = self.lstm(lstm_input, (h,c))          # (batch_size, 1, hidden_size),
# --> 168             out = self.decode_lstm(x, context, h, lstm_out)
#     169             # hidden = lstm_out.squeeze(0)
#     170             # out = self.h2out(hidden)
#
# /home/penielrome/pytorch/bitmap2svg/attn_model.py in decode_lstm(self, input_word, context, hidden, lstm_out)
#     102         out += input_word
#     103         out = F.tanh(out)
# --> 104         out = self.out(out)
#     105
#     106
#
# /home/penielrome/anaconda3/lib/python3.4/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /home/penielrome/anaconda3/lib/python3.4/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      52             return self._backend.Linear.apply(input, self.weight)
#      53         else:
# ---> 54             return self._backend.Linear.apply(input, self.weight, self.bias)
#      55
#      56     def __repr__(self):
#
# /home/penielrome/anaconda3/lib/python3.4/site-packages/torch/nn/_functions/linear.py in forward(ctx, input, weight, bias)
#      10         ctx.save_for_backward(input, weight, bias)
#      11         output = input.new(input.size(0), weight.size(0))
# ---> 12         output.addmm_(0, 1, input, weight.t())
#      13         if bias is not None:
#      14             output.add_(bias.expand_as(output))
#
# KeyboardInterrupt:

# %%
test_dir = 'data/circle_and_rect/bitmap/'
cap_dir = 'data/circle_and_rect/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

shape_match = 0
location_match = 0
radius_match = 0 
rect_x_match = 0 
rect_y_match = 0 
length_match = 0
circle_cnt = 0 
rect_cnt = 0 
color_match= 0

location_err = [] 
rect_x_err = []
rect_y_err = []
radius_err = [] 

for fname in test_list: 
    #cnt+=1 
    if cnt>2:
        break;
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    print(fname)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))
    #print(fname)

    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    in_caption = sampled_caption[1:-1]
    print(in_caption)
    
    #read target caption
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    trg_caption = [] 
    with open(cap_path, 'r') as f:
        target = f.readline().split()
        for word in target:
            trg_caption.append(word)
    print(trg_caption)
    print('-------------------------------------------------------------------')
    
    if(trg_caption[0]) == 'circle':
        if in_caption[0] == trg_caption[0]:
            shape_match+=1
            circle_cnt+=1
        if (in_caption[1] == trg_caption[1]):
            location_match+=1
        if (in_caption[2] == trg_caption[2]):
            location_match+=1        
        if (in_caption[3] == trg_caption[3]):
            radius_match+=1
        else:
            error = int(trg_caption[3]) - int(in_caption[3])
            radius_err.append(abs(error))
        if (in_caption[4] == trg_caption[4]):
            color_match+=1
    elif(trg_caption[0]) == 'rect':
        if in_caption[0] == trg_caption[0]:
            shape_match+=1
            rect_cnt+=1
        if (in_caption[1] == trg_caption[1]):
            location_match+=1
        if (in_caption[2] == trg_caption[2]):
            location_match+=1        
        if (in_caption[3] == trg_caption[3]):
            rect_x_match+=1
        else: 
            error = int(trg_caption[3]) - int(in_caption[3])
            rect_x_err.append(abs(error))
        if (in_caption[4] == trg_caption[4]):
            rect_y_match+=1
        else: 
            error = int(trg_caption[4]) - int(in_caption[4])
            rect_y_err.append(abs(error))            
        if (in_caption[5] == trg_caption[5]):
            color_match+=1
            
    
    if(trg_caption[0] != in_caption[0]):
        print(fname)
    if(trg_caption[1] != in_caption[1]):
        try:
            error = int(trg_caption[1]) - int(in_caption[1])
        except:
            print(fname)
            print(in_caption)
            pass
        location_err.append(abs(error))
    if(trg_caption[2] != in_caption[2]):
        error = int(trg_caption[1]) - int(in_caption[2])
        location_err.append(abs(error))
# Out:
# 748.png
# ['circle', '9', '5', '100', 'lime']
# ['circle', '9', '5', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1788.png
# ['rect', '10', '10', '60', '60', 'blue']
# ['rect', '10', '10', '110', '110', 'orange']
# -------------------------------------------------------------------
# 1594.png
# ['circle', '10', '3', '100', 'lime']
# ['circle', '10', '3', '110', 'pink']
# -------------------------------------------------------------------
# 1121.png
# ['circle', '1', '9', '60', 'orange']
# ['circle', '1', '9', '60', 'deep_pink']
# -------------------------------------------------------------------
# 1288.png
# ['circle', '8', '6', '110', 'lime']
# ['circle', '8', '6', '100', 'purple']
# -------------------------------------------------------------------
# 606.png
# ['rect', '5', '2', '70', '70', 'spring_green']
# ['circle', '6', '3', '40', 'pink']
# -------------------------------------------------------------------
# 606.png
# 468.png
# ['circle', '6', '7', '70', 'cyan']
# ['rect', '5', '5', '120', '120', 'red']
# -------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-268c7eedbaf8> in <module>()
#      90             rect_y_match+=1
#      91         else:
# ---> 92             error = int(trg_caption[4]) - int(in_caption[4])
#      93             rect_y_err.append(abs(error))
#      94         if (in_caption[5] == trg_caption[5]):
#
# ValueError: invalid literal for int() with base 10: 'cyan'
