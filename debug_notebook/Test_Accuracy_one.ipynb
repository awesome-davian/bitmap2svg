# %%
import torch
import matplotlib.pyplot as plt
import numpy as np 
import argparse
import pickle 
import os
from torch.autograd import Variable 
from torchvision import transforms 
from data_loader import build_vocab 
from model import EncoderCNN, DecoderRNN
from model import ResNet, ResidualBlock
from PIL import Image
from attn_model import ResidualBlock, AttnEncoder, AttnDecoderRnn


embed_size = 128
hidden_size = 256 
num_layers = 1 
feature_size =128
#decoder_path = './models/1object_color/decoder-10-150.pkl'
#encoder_path = './models/1object_color/encoder-10-150.pkl'
decoder_path = './models/attn/1object/decoder-10-150.pkl'
encoder_path = './models/attn/1object/encoder-10-150.pkl'

def to_var(x, volatile=False):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x, volatile=volatile)

def load_image(image_path, transform=None):
    image = Image.open(image_path).convert('RGB')
    image = image.resize([64, 64], Image.LANCZOS)
    
    if transform is not None:
        image = transform(image).unsqueeze(0)
    
    return image

transform = transforms.Compose([ 
    transforms.ToTensor(), 
    transforms.Normalize((0.033, 0.032, 0.033), 
                         (0.027, 0.027, 0.027))])



#vocab_path = './data/vocab_1object_color.pkl'
vocab_path = './data/attn/vocab1.pkl'
with open(vocab_path, 'rb') as f:
    vocab = pickle.load(f)
len_vocab = vocab.idx

# Build Models
#encoder = ResNet(ResidualBlock, [3, 3, 3], len_vocab)
#encoder.eval()  # evaluation mode (BN uses moving mean/variance)
#decoder = DecoderRNN(len_vocab, hidden_size,len(vocab), num_layers)
encoder = AttnEncoder(ResidualBlock, [3, 3, 3])
encoder.eval()  # evaluation mode (BN uses moving mean/variance)
decoder = AttnDecoderRnn(feature_size, hidden_size, 
                     len(vocab), num_layers)


# Load the trained model parameters
encoder.load_state_dict(torch.load(encoder_path))
decoder.load_state_dict(torch.load(decoder_path))


# If use gpu
if torch.cuda.is_available():
    encoder.cuda()
    decoder.cuda()

# %%
image_dir = 'data/circle_and_rect/bitmap/1.png'
test_image = load_image(image_dir,transform)
image_tensor = to_var(test_image)
features = en

# %%
test_dir = 'data/circle_and_rect/bitmap/'
cap_dir = 'data/circle_and_rect/caption/'
test_list = os.listdir(test_dir)
cnt = 0 

shape_match = 0
location_match = 0
radius_match = 0 
rect_x_match = 0 
rect_y_match = 0 
length_match = 0
circle_cnt = 0 
rect_cnt = 0 
color_match= 0
length_match = 0

location_err = [] 
rect_x_err = []
rect_y_err = []
radius_err = [] 


for fname in test_list: 
    #cnt+=1 
    if cnt>2:
        break;
    test_path = test_dir + fname
    test_image = load_image(test_path, transform)
    image_tensor = to_var(test_image)
    
    print(fname)
    
    # Generate caption from image
    feature = encoder(image_tensor)
    sampled_ids = decoder.sample(feature)
    ids_arr = []
    for element in sampled_ids: 
        temp = element.cpu().data.numpy()
        ids_arr.append(int(temp))
    #print(fname)

    # Decode word_ids to words
    sampled_caption = []
    for word_id in ids_arr:
        word = vocab.idx2word[word_id]
        sampled_caption.append(word)
        if word == '<end>':
            break
    in_caption = sampled_caption[1:-1]
    print(in_caption)
    
    #read target caption
    cap_target = cap_dir+fname
    cap_path = cap_target.split('.')[0]+'.svg'
    trg_caption = [] 
    with open(cap_path, 'r') as f:
        target = f.readline().split()
        for word in target:
            trg_caption.append(word)
    print(trg_caption)
    print('-------------------------------------------------------------------')
    
    try: 
    
        if(trg_caption[0]) == 'circle':
            if in_caption[0] == trg_caption[0]:
                shape_match+=1
                circle_cnt+=1
            else:
                continue 
            if (in_caption[1] == trg_caption[1]):
                location_match+=1
            if (in_caption[2] == trg_caption[2]):
                location_match+=1        
            if (in_caption[3] == trg_caption[3]):
                radius_match+=1
            else:
                error = int(trg_caption[3]) - int(in_caption[3])
                radius_err.append(abs(error))
            if (in_caption[4] == trg_caption[4]):
                color_match+=1
        elif(trg_caption[0]) == 'rect':
            if in_caption[0] == trg_caption[0]:
                shape_match+=1
                rect_cnt+=1
            else:
                continue 
            if (in_caption[1] == trg_caption[1]):
                location_match+=1
            if (in_caption[2] == trg_caption[2]):
                location_match+=1        
            if (in_caption[3] == trg_caption[3]):
                rect_x_match+=1
            else: 
                error = int(trg_caption[3]) - int(in_caption[3])
                rect_x_err.append(abs(error))
            if (in_caption[4] == trg_caption[4]):
                rect_y_match+=1
            else: 
                error = int(trg_caption[4]) - int(in_caption[4])
                rect_y_err.append(abs(error))            
            if (in_caption[5] == trg_caption[5]):
                color_match+=1


        if(trg_caption[0] != in_caption[0]):
            print(fname)
        if(trg_caption[1] != in_caption[1]):
            try:
                error = int(trg_caption[1]) - int(in_caption[1])
            except:
                print(fname)
                print(in_caption)
                pass
            location_err.append(abs(error))
        if(trg_caption[2] != in_caption[2]):
            error = int(trg_caption[1]) - int(in_caption[2])
            location_err.append(abs(error))
       
        if len(trg_caption) == len(in_caption):
            length_match+=1
        else:
            print('error')
            print(fname)
    except:
        continue
# Out:
# 748.png
# ['circle', '9', '5', '110', 'deep_pink']
# ['circle', '9', '5', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1788.png
# ['rect', '10', '9', '50', '50', 'orange']
# ['rect', '10', '10', '110', '110', 'orange']
# -------------------------------------------------------------------
# 1594.png
# ['circle', '10', '3', '110', 'pink']
# ['circle', '10', '3', '110', 'pink']
# -------------------------------------------------------------------
# 1121.png
# ['circle', '1', '9', '50', 'red']
# ['circle', '1', '9', '60', 'deep_pink']
# -------------------------------------------------------------------
# 1288.png
# ['circle', '8', '6', '100', 'purple']
# ['circle', '8', '6', '100', 'purple']
# -------------------------------------------------------------------
# 606.png
# ['circle', '6', '3', '40', 'pink']
# ['circle', '6', '3', '40', 'pink']
# -------------------------------------------------------------------
# 468.png
# ['rect', '5', '5', '120', '120', 'red']
# ['rect', '5', '5', '120', '120', 'red']
# -------------------------------------------------------------------
# 596.png
# ['rect', '3', '3', '30', '30', 'blue']
# ['rect', '3', '3', '40', '40', 'purple']
# -------------------------------------------------------------------
# 1155.png
# ['circle', '8', '6', '70', 'skyblue']
# ['circle', '8', '6', '70', 'skyblue']
# -------------------------------------------------------------------
# 1300.png
# ['rect', '10', '6', '60', '60', 'skyblue']
# ['rect', '10', '6', '60', '60', 'skyblue']
# -------------------------------------------------------------------
# 489.png
# ['circle', '4', '6', '70', 'orange']
# ['circle', '4', '6', '70', 'orange']
# -------------------------------------------------------------------
# 1421.png
# ['rect', '10', '1', '30', '30', 'skyblue']
# ['rect', '10', '1', '30', '30', 'blue']
# -------------------------------------------------------------------
# 754.png
# ['rect', '6', '1', '70', '70', 'spring_green']
# ['rect', '6', '1', '70', '70', 'spring_green']
# -------------------------------------------------------------------
# 746.png
# ['circle', '5', '4', '80', 'spring_green']
# ['circle', '5', '4', '80', 'spring_green']
# -------------------------------------------------------------------
# 1284.png
# ['circle', '5', '2', '50', 'orange']
# ['circle', '5', '2', '50', 'red']
# -------------------------------------------------------------------
# 714.png
# ['circle', '4', '7', '60', 'lime']
# ['circle', '4', '7', '60', 'lime']
# -------------------------------------------------------------------
# 1721.png
# ['circle', '10', '6', '100', 'yellow']
# ['circle', '10', '6', '100', 'yellow']
# -------------------------------------------------------------------
# 1531.png
# ['circle', '8', '8', '50', 'spring_green']
# ['circle', '8', '9', '50', 'spring_green']
# -------------------------------------------------------------------
# 1405.png
# ['circle', '8', '4', '40', 'yellow']
# ['circle', '8', '5', '40', 'orange']
# -------------------------------------------------------------------
# 723.png
# ['circle', '3', '3', '70', 'green']
# ['circle', '3', '3', '70', 'green']
# -------------------------------------------------------------------
# 1700.png
# ['circle', '2', '8', '20', 'yellow']
# ['circle', '2', '8', '30', 'yellow']
# -------------------------------------------------------------------
# 1717.png
# ['rect', '4', '1', '60', '60', 'red']
# ['rect', '5', '1', '60', '60', 'red']
# -------------------------------------------------------------------
# 1719.png
# ['circle', '5', '3', '110', 'red']
# ['circle', '5', '4', '100', 'red']
# -------------------------------------------------------------------
# 833.png
# ['circle', '1', '3', '100', 'cyan']
# ['circle', '2', '3', '90', 'cyan']
# -------------------------------------------------------------------
# 987.png
# ['rect', '2', '6', '90', '90', 'pink']
# ['rect', '2', '6', '90', '90', 'pink']
# -------------------------------------------------------------------
# 698.png
# ['circle', '6', '9', '70', 'skyblue']
# ['circle', '7', '9', '70', 'skyblue']
# -------------------------------------------------------------------
# 178.png
# ['circle', '9', '6', '120', 'lime']
# ['circle', '9', '6', '110', 'lime']
# -------------------------------------------------------------------
# 1174.png
# ['circle', '3', '3', '30', 'red']
# ['circle', '4', '3', '30', 'red']
# -------------------------------------------------------------------
# 203.png
# ['rect', '10', '8', '90', '90', 'deep_pink']
# ['rect', '9', '8', '90', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1160.png
# ['circle', '3', '9', '50', 'purple']
# ['circle', '3', '8', '60', 'purple']
# -------------------------------------------------------------------
# 1226.png
# ['rect', '8', '6', '30', '30', 'skyblue']
# ['rect', '8', '6', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 1014.png
# ['rect', '2', '6', '100', '100', 'green']
# ['rect', '2', '6', '100', '100', 'green']
# -------------------------------------------------------------------
# 1363.png
# ['circle', '8', '8', '40', 'cyan']
# ['circle', '8', '8', '40', 'cyan']
# -------------------------------------------------------------------
# 1749.png
# ['rect', '9', '8', '100', '100', 'purple']
# ['rect', '9', '7', '110', '110', 'purple']
# -------------------------------------------------------------------
# 1087.png
# ['rect', '2', '5', '80', '80', 'yellow']
# ['rect', '2', '4', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 400.png
# ['rect', '8', '10', '110', '110', 'pink']
# ['rect', '8', '10', '70', '70', 'pink']
# -------------------------------------------------------------------
# 192.png
# ['circle', '3', '1', '30', 'blue']
# ['circle', '3', '1', '40', 'blue']
# -------------------------------------------------------------------
# 2.png
# ['circle', '3', '6', '60', 'lime']
# ['circle', '3', '6', '60', 'lime']
# -------------------------------------------------------------------
# 1435.png
# ['circle', '6', '5', '70', 'skyblue']
# ['circle', '7', '5', '70', 'blue']
# -------------------------------------------------------------------
# 126.png
# ['circle', '10', '4', '80', 'red']
# ['circle', '10', '4', '80', 'red']
# -------------------------------------------------------------------
# 711.png
# ['rect', '10', '7', '40', '40', 'orange']
# ['rect', '10', '1', '50', '50', 'yellow']
# -------------------------------------------------------------------
# 1293.png
# ['circle', '4', '10', '120', 'purple']
# ['circle', '4', '10', '110', 'purple']
# -------------------------------------------------------------------
# 1129.png
# ['circle', '8', '1', '30', 'yellow']
# ['circle', '8', '1', '30', 'yellow']
# -------------------------------------------------------------------
# 752.png
# ['circle', '4', '7', '100', 'orange']
# ['circle', '5', '7', '100', 'orange']
# -------------------------------------------------------------------
# 1625.png
# ['rect', '1', '8', '30', '30', 'purple']
# ['circle', '2', '8', '20', 'purple']
# -------------------------------------------------------------------
# 1098.png
# ['rect', '5', '2', '90', '90', 'orange']
# ['rect', '5', '2', '90', '90', 'orange']
# -------------------------------------------------------------------
# 910.png
# ['circle', '3', '8', '50', 'purple']
# ['circle', '3', '8', '50', 'purple']
# -------------------------------------------------------------------
# 1172.png
# ['circle', '7', '3', '60', 'blue']
# ['circle', '8', '4', '60', 'blue']
# -------------------------------------------------------------------
# 67.png
# ['circle', '5', '4', '50', 'skyblue']
# ['circle', '5', '4', '50', 'skyblue']
# -------------------------------------------------------------------
# 925.png
# ['rect', '2', '4', '50', '50', 'orange']
# ['rect', '2', '4', '50', '50', 'orange']
# -------------------------------------------------------------------
# 1832.png
# ['circle', '3', '4', '100', 'yellow']
# ['circle', '3', '4', '100', 'yellow']
# -------------------------------------------------------------------
# 1067.png
# ['circle', '6', '5', '30', 'spring_green']
# ['circle', '7', '5', '30', 'spring_green']
# -------------------------------------------------------------------
# 1847.png
# ['circle', '10', '9', '100', 'deep_pink']
# ['circle', '10', '9', '100', 'deep_pink']
# -------------------------------------------------------------------
# 355.png
# ['rect', '10', '7', '30', '30', 'cyan']
# ['rect', '10', '8', '30', '30', 'spring_green']
# -------------------------------------------------------------------
# 1632.png
# ['rect', '3', '1', '20', '20', 'orange']
# ['rect', '3', '1', '20', '20', 'orange']
# -------------------------------------------------------------------
# 1825.png
# ['circle', '10', '7', '80', 'cyan']
# ['circle', '10', '7', '80', 'cyan']
# -------------------------------------------------------------------
# 687.png
# ['circle', '6', '8', '30', 'purple']
# ['circle', '6', '8', '30', 'purple']
# -------------------------------------------------------------------
# 340.png
# ['circle', '1', '8', '20', 'deep_pink']
# ['circle', '2', '9', '20', 'deep_pink']
# -------------------------------------------------------------------
# 1972.png
# ['circle', '8', '6', '110', 'purple']
# ['circle', '8', '6', '100', 'purple']
# -------------------------------------------------------------------
# 70.png
# ['rect', '2', '9', '20', '20', 'yellow']
# ['rect', '2', '9', '20', '20', 'yellow']
# -------------------------------------------------------------------
# 738.png
# ['rect', '3', '3', '120', '120', 'deep_pink']
# ['rect', '2', '3', '110', '110', 'deep_pink']
# -------------------------------------------------------------------
# 1948.png
# ['circle', '4', '6', '60', 'deep_pink']
# ['circle', '4', '6', '60', 'deep_pink']
# -------------------------------------------------------------------
# 647.png
# ['circle', '10', '4', '60', 'green']
# ['circle', '10', '4', '50', 'green']
# -------------------------------------------------------------------
# 1252.png
# ['rect', '2', '10', '50', '50', 'pink']
# ['rect', '2', '10', '60', '60', 'pink']
# -------------------------------------------------------------------
# 630.png
# ['rect', '8', '6', '40', '40', 'red']
# ['rect', '8', '6', '30', '30', 'red']
# -------------------------------------------------------------------
# 1751.png
# ['rect', '4', '3', '50', '50', 'skyblue']
# ['rect', '4', '3', '50', '50', 'blue']
# -------------------------------------------------------------------
# 524.png
# ['rect', '6', '8', '50', '50', 'green']
# ['rect', '6', '9', '50', '50', 'green']
# -------------------------------------------------------------------
# 204.png
# ['rect', '1', '5', '60', '60', 'cyan']
# ['rect', '1', '5', '60', '60', 'spring_green']
# -------------------------------------------------------------------
# 1557.png
# ['circle', '8', '10', '80', 'pink']
# ['rect', '7', '9', '110', '110', 'pink']
# -------------------------------------------------------------------
# 528.png
# ['rect', '3', '6', '100', '100', 'cyan']
# ['rect', '4', '6', '100', '100', 'cyan']
# -------------------------------------------------------------------
# 1134.png
# ['circle', '4', '2', '30', 'deep_pink']
# ['circle', '4', '1', '30', 'deep_pink']
# -------------------------------------------------------------------
# 1305.png
# ['rect', '9', '6', '70', '70', 'blue']
# ['rect', '9', '6', '70', '70', 'blue']
# -------------------------------------------------------------------
# 834.png
# ['circle', '1', '9', '110', 'skyblue']
# ['circle', '1', '9', '100', 'skyblue']
# -------------------------------------------------------------------
# 85.png
# ['rect', '4', '2', '110', '110', 'spring_green']
# ['rect', '4', '1', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 776.png
# ['circle', '1', '10', '70', 'cyan']
# ['circle', '1', '10', '50', 'cyan']
# -------------------------------------------------------------------
# 78.png
# ['rect', '2', '7', '50', '50', 'spring_green']
# ['rect', '2', '7', '50', '50', 'spring_green']
# -------------------------------------------------------------------
# 1397.png
# ['circle', '2', '9', '50', 'pink']
# ['circle', '2', '9', '50', 'pink']
# -------------------------------------------------------------------
# 1279.png
# ['circle', '2', '5', '100', 'yellow']
# ['circle', '2', '5', '100', 'yellow']
# -------------------------------------------------------------------
# 1433.png
# ['rect', '5', '1', '90', '90', 'orange']
# ['rect', '5', '1', '90', '90', 'orange']
# -------------------------------------------------------------------
# 365.png
# ['rect', '10', '5', '40', '40', 'spring_green']
# ['rect', '10', '5', '30', '30', 'spring_green']
# -------------------------------------------------------------------
# 737.png
# ['circle', '8', '4', '60', 'cyan']
# ['circle', '8', '4', '60', 'cyan']
# -------------------------------------------------------------------
# 1954.png
# ['rect', '6', '4', '20', '20', 'cyan']
# ['rect', '6', '4', '20', '20', 'cyan']
# -------------------------------------------------------------------
# 1486.png
# ['rect', '6', '4', '60', '60', 'skyblue']
# ['rect', '6', '4', '50', '50', 'skyblue']
# -------------------------------------------------------------------
# 1785.png
# ['rect', '2', '3', '80', '80', 'yellow']
# ['rect', '2', '3', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 1936.png
# ['rect', '1', '1', '110', '110', 'spring_green']
# ['rect', '1', '1', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 1839.png
# ['rect', '4', '1', '80', '80', 'deep_pink']
# ['rect', '4', '1', '80', '80', 'deep_pink']
# -------------------------------------------------------------------
# 486.png
# ['rect', '3', '3', '30', '30', 'blue']
# ['rect', '4', '3', '30', '30', 'blue']
# -------------------------------------------------------------------
# 168.png
# ['circle', '6', '2', '50', 'spring_green']
# ['circle', '6', '2', '50', 'spring_green']
# -------------------------------------------------------------------
# 15.png
# ['rect', '9', '10', '40', '40', 'skyblue']
# ['circle', '10', '10', '20', 'skyblue']
# -------------------------------------------------------------------
# 177.png
# ['rect', '10', '6', '50', '50', 'lime']
# ['circle', '10', '6', '30', 'lime']
# -------------------------------------------------------------------
# 543.png
# ['rect', '9', '6', '50', '50', 'lime']
# ['rect', '9', '6', '50', '50', 'lime']
# -------------------------------------------------------------------
# 582.png
# ['rect', '2', '10', '30', '30', 'skyblue']
# ['rect', '1', '10', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 214.png
# ['circle', '2', '7', '40', 'pink']
# ['circle', '2', '7', '40', 'pink']
# -------------------------------------------------------------------
# 593.png
# ['circle', '8', '3', '30', 'purple']
# ['circle', '9', '3', '30', 'purple']
# -------------------------------------------------------------------
# 1323.png
# ['rect', '9', '6', '50', '50', 'blue']
# ['rect', '10', '6', '50', '50', 'blue']
# -------------------------------------------------------------------
# 402.png
# ['circle', '5', '4', '110', 'lime']
# ['circle', '5', '4', '110', 'lime']
# -------------------------------------------------------------------
# 646.png
# ['circle', '5', '5', '30', 'deep_pink']
# ['circle', '5', '5', '30', 'pink']
# -------------------------------------------------------------------
# 1766.png
# ['circle', '1', '3', '60', 'blue']
# ['circle', '1', '3', '60', 'blue']
# -------------------------------------------------------------------
# 1222.png
# ['rect', '7', '6', '100', '100', 'blue']
# ['rect', '7', '7', '100', '100', 'blue']
# -------------------------------------------------------------------
# 503.png
# ['rect', '8', '2', '60', '60', 'skyblue']
# ['rect', '9', '2', '50', '50', 'skyblue']
# -------------------------------------------------------------------
# 1691.png
# ['rect', '8', '7', '60', '60', 'cyan']
# ['rect', '9', '7', '60', '60', 'cyan']
# -------------------------------------------------------------------
# 939.png
# ['circle', '7', '2', '60', 'orange']
# ['circle', '7', '2', '70', 'orange']
# -------------------------------------------------------------------
# 1449.png
# ['rect', '2', '7', '40', '40', 'lime']
# ['rect', '2', '7', '40', '40', 'lime']
# -------------------------------------------------------------------
# 274.png
# ['rect', '9', '1', '70', '70', 'green']
# ['rect', '9', '1', '70', '70', 'green']
# -------------------------------------------------------------------
# 466.png
# ['circle', '3', '3', '60', 'lime']
# ['circle', '3', '3', '60', 'lime']
# -------------------------------------------------------------------
# 1811.png
# ['circle', '5', '5', '100', 'spring_green']
# ['circle', '5', '5', '90', 'spring_green']
# -------------------------------------------------------------------
# 347.png
# ['circle', '4', '10', '120', 'skyblue']
# ['circle', '5', '10', '120', 'skyblue']
# -------------------------------------------------------------------
# 1738.png
# ['circle', '3', '10', '100', 'pink']
# ['circle', '3', '10', '100', 'pink']
# -------------------------------------------------------------------
# 1732.png
# ['rect', '9', '10', '30', '30', 'blue']
# ['rect', '9', '10', '20', '20', 'blue']
# -------------------------------------------------------------------
# 34.png
# ['circle', '10', '8', '40', 'deep_pink']
# ['circle', '10', '9', '40', 'deep_pink']
# -------------------------------------------------------------------
# 1666.png
# ['rect', '10', '10', '110', '110', 'orange']
# ['rect', '10', '10', '100', '100', 'orange']
# -------------------------------------------------------------------
# 1113.png
# ['rect', '4', '7', '120', '120', 'cyan']
# ['rect', '4', '7', '110', '110', 'cyan']
# -------------------------------------------------------------------
# 604.png
# ['circle', '3', '3', '100', 'lime']
# ['circle', '3', '2', '100', 'lime']
# -------------------------------------------------------------------
# 1474.png
# ['rect', '10', '6', '90', '90', 'lime']
# ['rect', '10', '6', '90', '90', 'lime']
# -------------------------------------------------------------------
# 491.png
# ['circle', '8', '5', '110', 'blue']
# ['circle', '9', '5', '100', 'blue']
# -------------------------------------------------------------------
# 1762.png
# ['circle', '6', '6', '70', 'purple']
# ['circle', '6', '6', '70', 'purple']
# -------------------------------------------------------------------
# 1758.png
# ['circle', '7', '10', '120', 'purple']
# ['circle', '8', '9', '110', 'purple']
# -------------------------------------------------------------------
# 145.png
# ['rect', '3', '7', '80', '80', 'orange']
# ['rect', '3', '8', '80', '80', 'orange']
# -------------------------------------------------------------------
# 1190.png
# ['rect', '2', '5', '30', '30', 'green']
# ['rect', '3', '5', '20', '20', 'green']
# -------------------------------------------------------------------
# 1481.png
# ['rect', '7', '7', '30', '30', 'skyblue']
# ['rect', '7', '7', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 84.png
# ['rect', '9', '6', '30', '30', 'blue']
# ['rect', '10', '5', '30', '30', 'blue']
# -------------------------------------------------------------------
# 712.png
# ['circle', '5', '1', '60', 'lime']
# ['circle', '5', '1', '50', 'green']
# -------------------------------------------------------------------
# 719.png
# ['rect', '9', '6', '100', '100', 'lime']
# ['rect', '9', '7', '100', '100', 'lime']
# -------------------------------------------------------------------
# 432.png
# ['rect', '5', '8', '30', '30', 'pink']
# ['rect', '5', '8', '30', '30', 'pink']
# -------------------------------------------------------------------
# 252.png
# ['circle', '6', '5', '50', 'skyblue']
# ['circle', '7', '5', '50', 'skyblue']
# -------------------------------------------------------------------
# 1065.png
# ['rect', '1', '8', '110', '110', 'yellow']
# ['rect', '1', '9', '90', '90', 'yellow']
# -------------------------------------------------------------------
# 1711.png
# ['circle', '5', '6', '110', 'orange']
# ['circle', '6', '6', '100', 'red']
# -------------------------------------------------------------------
# 1586.png
# ['rect', '7', '9', '80', '80', 'spring_green']
# ['rect', '8', '9', '80', '80', 'spring_green']
# -------------------------------------------------------------------
# 1320.png
# ['rect', '10', '7', '80', '80', 'lime']
# ['rect', '10', '7', '80', '80', 'lime']
# -------------------------------------------------------------------
# 1739.png
# ['circle', '5', '2', '100', 'lime']
# ['circle', '5', '2', '110', 'lime']
# -------------------------------------------------------------------
# 1670.png
# ['circle', '10', '9', '110', 'blue']
# ['circle', '10', '10', '120', 'blue']
# -------------------------------------------------------------------
# 1312.png
# ['rect', '2', '5', '40', '40', 'spring_green']
# ['rect', '2', '5', '40', '40', 'spring_green']
# -------------------------------------------------------------------
# 166.png
# ['rect', '7', '7', '50', '50', 'orange']
# ['rect', '7', '7', '50', '50', 'red']
# -------------------------------------------------------------------
# 552.png
# ['circle', '6', '2', '60', 'blue']
# ['circle', '7', '2', '60', 'blue']
# -------------------------------------------------------------------
# 1084.png
# ['circle', '3', '3', '50', 'red']
# ['circle', '4', '3', '50', 'red']
# -------------------------------------------------------------------
# 253.png
# ['rect', '4', '7', '80', '80', 'green']
# ['rect', '4', '8', '80', '80', 'green']
# -------------------------------------------------------------------
# 1380.png
# ['rect', '5', '2', '40', '40', 'skyblue']
# ['rect', '5', '2', '40', '40', 'blue']
# -------------------------------------------------------------------
# 1034.png
# ['rect', '2', '7', '60', '60', 'orange']
# ['rect', '2', '8', '60', '60', 'orange']
# -------------------------------------------------------------------
# 1969.png
# ['rect', '7', '1', '30', '30', 'purple']
# ['rect', '7', '1', '30', '30', 'purple']
# -------------------------------------------------------------------
# 1796.png
# ['circle', '10', '7', '70', 'orange']
# ['circle', '10', '7', '70', 'orange']
# -------------------------------------------------------------------
# 1146.png
# ['rect', '7', '6', '100', '100', 'purple']
# ['rect', '7', '6', '100', '100', 'purple']
# -------------------------------------------------------------------
# 1753.png
# ['circle', '7', '4', '30', 'purple']
# ['circle', '7', '4', '40', 'purple']
# -------------------------------------------------------------------
# 1526.png
# ['rect', '10', '9', '50', '50', 'green']
# ['rect', '10', '10', '80', '80', 'green']
# -------------------------------------------------------------------
# 768.png
# ['rect', '9', '6', '100', '100', 'orange']
# ['rect', '9', '6', '100', '100', 'orange']
# -------------------------------------------------------------------
# 272.png
# ['rect', '8', '2', '40', '40', 'purple']
# ['rect', '8', '2', '40', '40', 'pink']
# -------------------------------------------------------------------
# 963.png
# ['rect', '2', '10', '30', '30', 'pink']
# ['rect', '2', '10', '30', '30', 'pink']
# -------------------------------------------------------------------
# 1403.png
# ['rect', '9', '8', '80', '80', 'lime']
# ['rect', '9', '8', '70', '70', 'lime']
# -------------------------------------------------------------------
# 200.png
# ['circle', '8', '1', '20', 'blue']
# ['circle', '8', '1', '20', 'purple']
# -------------------------------------------------------------------
# 1464.png
# ['rect', '5', '8', '120', '120', 'spring_green']
# ['rect', '5', '8', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 1763.png
# ['rect', '8', '1', '50', '50', 'cyan']
# ['rect', '8', '1', '50', '50', 'cyan']
# -------------------------------------------------------------------
# 284.png
# ['rect', '4', '9', '50', '50', 'deep_pink']
# ['rect', '4', '9', '50', '50', 'deep_pink']
# -------------------------------------------------------------------
# 32.png
# ['rect', '3', '6', '50', '50', 'yellow']
# ['rect', '3', '6', '50', '50', 'yellow']
# -------------------------------------------------------------------
# 227.png
# ['circle', '1', '2', '110', 'blue']
# ['circle', '1', '3', '100', 'purple']
# -------------------------------------------------------------------
# 224.png
# ['rect', '1', '2', '60', '60', 'green']
# ['rect', '1', '2', '60', '60', 'green']
# -------------------------------------------------------------------
# 1457.png
# ['circle', '10', '7', '100', 'green']
# ['circle', '10', '8', '100', 'green']
# -------------------------------------------------------------------
# 1331.png
# ['rect', '10', '6', '80', '80', 'blue']
# ['rect', '10', '5', '80', '80', 'blue']
# -------------------------------------------------------------------
# 388.png
# ['circle', '4', '7', '70', 'deep_pink']
# ['circle', '4', '7', '60', 'deep_pink']
# -------------------------------------------------------------------
# 1630.png
# ['rect', '10', '8', '40', '40', 'yellow']
# ['rect', '10', '9', '30', '30', 'yellow']
# -------------------------------------------------------------------
# 1716.png
# ['rect', '5', '2', '30', '30', 'pink']
# ['rect', '5', '2', '30', '30', 'pink']
# -------------------------------------------------------------------
# 310.png
# ['circle', '3', '5', '100', 'purple']
# ['circle', '4', '5', '100', 'purple']
# -------------------------------------------------------------------
# 363.png
# ['rect', '10', '3', '90', '90', 'pink']
# ['rect', '10', '3', '90', '90', 'pink']
# -------------------------------------------------------------------
# 1605.png
# ['rect', '10', '4', '50', '50', 'spring_green']
# ['rect', '10', '4', '50', '50', 'spring_green']
# -------------------------------------------------------------------
# 13.png
# ['rect', '8', '6', '20', '20', 'purple']
# ['rect', '8', '6', '30', '30', 'purple']
# -------------------------------------------------------------------
# 551.png
# ['rect', '3', '3', '70', '70', 'orange']
# ['rect', '3', '3', '70', '70', 'orange']
# -------------------------------------------------------------------
# 1462.png
# ['circle', '8', '1', '30', 'cyan']
# ['circle', '8', '1', '30', 'cyan']
# -------------------------------------------------------------------
# 615.png
# ['rect', '3', '10', '60', '60', 'pink']
# ['rect', '3', '10', '70', '70', 'pink']
# -------------------------------------------------------------------
# 1921.png
# ['circle', '5', '2', '80', 'purple']
# ['circle', '5', '2', '80', 'purple']
# -------------------------------------------------------------------
# 629.png
# ['rect', '10', '7', '70', '70', 'deep_pink']
# ['circle', '10', '7', '50', 'pink']
# -------------------------------------------------------------------
# 1415.png
# ['circle', '6', '1', '110', 'pink']
# ['circle', '6', '1', '120', 'pink']
# -------------------------------------------------------------------
# 1582.png
# ['circle', '7', '4', '60', 'blue']
# ['circle', '7', '4', '60', 'blue']
# -------------------------------------------------------------------
# 539.png
# ['rect', '8', '10', '30', '30', 'red']
# ['rect', '8', '10', '30', '30', 'red']
# -------------------------------------------------------------------
# 555.png
# ['circle', '5', '7', '60', 'lime']
# ['circle', '5', '7', '60', 'lime']
# -------------------------------------------------------------------
# 1539.png
# ['circle', '2', '3', '60', 'pink']
# ['circle', '2', '3', '60', 'pink']
# -------------------------------------------------------------------
# 1799.png
# ['circle', '6', '8', '110', 'skyblue']
# ['circle', '6', '8', '110', 'blue']
# -------------------------------------------------------------------
# 1156.png
# ['circle', '8', '8', '80', 'spring_green']
# ['circle', '8', '9', '80', 'spring_green']
# -------------------------------------------------------------------
# 434.png
# ['rect', '2', '10', '90', '90', 'lime']
# ['rect', '2', '10', '80', '80', 'lime']
# -------------------------------------------------------------------
# 1822.png
# ['rect', '5', '6', '40', '40', 'green']
# ['rect', '5', '6', '40', '40', 'green']
# -------------------------------------------------------------------
# 763.png
# ['rect', '10', '10', '110', '110', 'lime']
# ['rect', '10', '10', '60', '60', 'yellow']
# -------------------------------------------------------------------
# 152.png
# ['rect', '6', '4', '40', '40', 'cyan']
# ['rect', '6', '4', '40', '40', 'cyan']
# -------------------------------------------------------------------
# 511.png
# ['circle', '7', '8', '40', 'orange']
# ['circle', '7', '8', '40', 'orange']
# -------------------------------------------------------------------
# 1742.png
# ['circle', '8', '6', '120', 'deep_pink']
# ['circle', '8', '6', '120', 'deep_pink']
# -------------------------------------------------------------------
# 1259.png
# ['rect', '4', '6', '120', '120', 'lime']
# ['rect', '4', '6', '120', '120', 'lime']
# -------------------------------------------------------------------
# 1878.png
# ['rect', '4', '4', '30', '30', 'skyblue']
# ['rect', '4', '4', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 1497.png
# ['rect', '2', '10', '40', '40', 'purple']
# ['rect', '3', '10', '60', '60', 'purple']
# -------------------------------------------------------------------
# 387.png
# ['circle', '5', '10', '80', 'yellow']
# ['circle', '6', '10', '70', 'yellow']
# -------------------------------------------------------------------
# 600.png
# ['circle', '1', '2', '100', 'red']
# ['circle', '1', '2', '100', 'deep_pink']
# -------------------------------------------------------------------
# 751.png
# ['rect', '8', '3', '120', '120', 'purple']
# ['rect', '9', '3', '120', '120', 'purple']
# -------------------------------------------------------------------
# 1264.png
# ['circle', '2', '3', '30', 'purple']
# ['circle', '1', '3', '30', 'purple']
# -------------------------------------------------------------------
# 1733.png
# ['circle', '4', '9', '20', 'red']
# ['circle', '4', '9', '20', 'red']
# -------------------------------------------------------------------
# 1882.png
# ['circle', '7', '3', '20', 'lime']
# ['circle', '7', '3', '20', 'lime']
# -------------------------------------------------------------------
# 241.png
# ['rect', '8', '4', '90', '90', 'orange']
# ['rect', '8', '4', '90', '90', 'orange']
# -------------------------------------------------------------------
# 1392.png
# ['circle', '3', '2', '70', 'pink']
# ['circle', '4', '2', '70', 'pink']
# -------------------------------------------------------------------
# 1271.png
# ['circle', '8', '4', '90', 'lime']
# ['circle', '8', '4', '90', 'lime']
# -------------------------------------------------------------------
# 1985.png
# ['circle', '8', '5', '110', 'blue']
# ['circle', '8', '5', '110', 'blue']
# -------------------------------------------------------------------
# 1008.png
# ['rect', '6', '6', '100', '100', 'cyan']
# ['rect', '6', '6', '100', '100', 'cyan']
# -------------------------------------------------------------------
# 673.png
# ['circle', '5', '8', '30', 'red']
# ['circle', '5', '8', '30', 'deep_pink']
# -------------------------------------------------------------------
# 306.png
# ['circle', '8', '7', '80', 'orange']
# ['circle', '8', '7', '80', 'orange']
# -------------------------------------------------------------------
# 1769.png
# ['rect', '2', '8', '70', '70', 'deep_pink']
# ['rect', '2', '8', '70', '70', 'deep_pink']
# -------------------------------------------------------------------
# 993.png
# ['circle', '9', '5', '80', 'yellow']
# ['circle', '9', '5', '80', 'yellow']
# -------------------------------------------------------------------
# 1926.png
# ['rect', '1', '3', '70', '70', 'purple']
# ['rect', '1', '3', '70', '70', 'purple']
# -------------------------------------------------------------------
# 1386.png
# ['rect', '6', '5', '90', '90', 'blue']
# ['rect', '6', '5', '90', '90', 'blue']
# -------------------------------------------------------------------
# 404.png
# ['circle', '8', '10', '40', 'pink']
# ['circle', '8', '10', '40', 'pink']
# -------------------------------------------------------------------
# 1469.png
# ['rect', '3', '4', '50', '50', 'cyan']
# ['rect', '3', '4', '50', '50', 'cyan']
# -------------------------------------------------------------------
# 1671.png
# ['rect', '8', '1', '90', '90', 'deep_pink']
# ['rect', '8', '1', '90', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1649.png
# ['circle', '6', '10', '80', 'orange']
# ['circle', '6', '10', '70', 'orange']
# -------------------------------------------------------------------
# 1918.png
# ['circle', '7', '8', '70', 'pink']
# ['circle', '7', '8', '70', 'pink']
# -------------------------------------------------------------------
# 247.png
# ['rect', '10', '2', '50', '50', 'orange']
# ['rect', '10', '2', '50', '50', 'orange']
# -------------------------------------------------------------------
# 119.png
# ['circle', '3', '3', '90', 'deep_pink']
# ['circle', '4', '3', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1504.png
# ['circle', '3', '9', '110', 'yellow']
# ['circle', '3', '9', '110', 'yellow']
# -------------------------------------------------------------------
# 211.png
# ['rect', '3', '8', '100', '100', 'spring_green']
# ['rect', '3', '8', '90', '90', 'spring_green']
# -------------------------------------------------------------------
# 418.png
# ['rect', '6', '8', '120', '120', 'skyblue']
# ['rect', '6', '8', '120', '120', 'skyblue']
# -------------------------------------------------------------------
# 1888.png
# ['circle', '10', '1', '80', 'spring_green']
# ['circle', '10', '1', '100', 'spring_green']
# -------------------------------------------------------------------
# 1579.png
# ['circle', '7', '10', '120', 'orange']
# ['circle', '7', '9', '110', 'orange']
# -------------------------------------------------------------------
# 103.png
# ['rect', '4', '10', '110', '110', 'deep_pink']
# ['rect', '5', '10', '100', '100', 'deep_pink']
# -------------------------------------------------------------------
# 727.png
# ['circle', '4', '9', '40', 'lime']
# ['circle', '4', '9', '40', 'lime']
# -------------------------------------------------------------------
# 208.png
# ['circle', '1', '1', '90', 'blue']
# ['circle', '2', '1', '90', 'blue']
# -------------------------------------------------------------------
# 1243.png
# ['rect', '5', '9', '100', '100', 'deep_pink']
# ['rect', '5', '9', '90', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1538.png
# ['circle', '2', '3', '110', 'purple']
# ['circle', '2', '3', '110', 'purple']
# -------------------------------------------------------------------
# 597.png
# ['rect', '3', '5', '100', '100', 'deep_pink']
# ['rect', '3', '5', '100', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1118.png
# ['rect', '8', '4', '50', '50', 'cyan']
# ['rect', '8', '4', '50', '50', 'cyan']
# -------------------------------------------------------------------
# 445.png
# ['rect', '3', '6', '40', '40', 'green']
# ['rect', '2', '6', '40', '40', 'green']
# -------------------------------------------------------------------
# 218.png
# ['circle', '7', '5', '120', 'yellow']
# ['circle', '8', '5', '120', 'yellow']
# -------------------------------------------------------------------
# 1638.png
# ['rect', '5', '10', '120', '120', 'pink']
# ['rect', '5', '10', '110', '110', 'pink']
# -------------------------------------------------------------------
# 1211.png
# ['rect', '3', '6', '50', '50', 'blue']
# ['rect', '3', '6', '50', '50', 'blue']
# -------------------------------------------------------------------
# 148.png
# ['circle', '6', '5', '30', 'purple']
# ['circle', '7', '5', '30', 'purple']
# -------------------------------------------------------------------
# 1673.png
# ['rect', '7', '4', '110', '110', 'lime']
# ['rect', '7', '4', '110', '110', 'lime']
# -------------------------------------------------------------------
# 101.png
# ['rect', '5', '3', '50', '50', 'deep_pink']
# ['rect', '5', '3', '50', '50', 'deep_pink']
# -------------------------------------------------------------------
# 741.png
# ['rect', '1', '9', '100', '100', 'spring_green']
# ['circle', '2', '10', '60', 'spring_green']
# -------------------------------------------------------------------
# 1511.png
# ['rect', '9', '10', '40', '40', 'purple']
# ['rect', '10', '9', '40', '40', 'purple']
# -------------------------------------------------------------------
# 421.png
# ['circle', '1', '2', '50', 'cyan']
# ['circle', '2', '2', '40', 'cyan']
# -------------------------------------------------------------------
# 1615.png
# ['rect', '10', '2', '60', '60', 'red']
# ['rect', '10', '2', '60', '60', 'red']
# -------------------------------------------------------------------
# 1123.png
# ['circle', '2', '5', '100', 'green']
# ['circle', '1', '6', '100', 'green']
# -------------------------------------------------------------------
# 1561.png
# ['rect', '5', '2', '50', '50', 'yellow']
# ['rect', '5', '1', '50', '50', 'yellow']
# -------------------------------------------------------------------
# 872.png
# ['rect', '6', '4', '100', '100', 'skyblue']
# ['rect', '6', '4', '100', '100', 'blue']
# -------------------------------------------------------------------
# 871.png
# ['circle', '3', '9', '20', 'red']
# ['circle', '4', '9', '20', 'red']
# -------------------------------------------------------------------
# 1107.png
# ['circle', '7', '3', '30', 'orange']
# ['circle', '7', '3', '30', 'orange']
# -------------------------------------------------------------------
# 576.png
# ['circle', '8', '6', '90', 'green']
# ['circle', '8', '6', '90', 'green']
# -------------------------------------------------------------------
# 744.png
# ['circle', '1', '2', '70', 'spring_green']
# ['circle', '1', '2', '60', 'spring_green']
# -------------------------------------------------------------------
# 537.png
# ['circle', '8', '4', '100', 'yellow']
# ['circle', '8', '3', '100', 'yellow']
# -------------------------------------------------------------------
# 911.png
# ['circle', '6', '6', '40', 'green']
# ['circle', '6', '6', '40', 'spring_green']
# -------------------------------------------------------------------
# 1390.png
# ['rect', '7', '2', '70', '70', 'lime']
# ['rect', '7', '2', '70', '70', 'lime']
# -------------------------------------------------------------------
# 1559.png
# ['rect', '8', '7', '40', '40', 'orange']
# ['rect', '8', '7', '40', '40', 'orange']
# -------------------------------------------------------------------
# 841.png
# ['circle', '4', '5', '30', 'green']
# ['circle', '4', '5', '30', 'green']
# -------------------------------------------------------------------
# 1601.png
# ['circle', '1', '10', '40', 'skyblue']
# ['circle', '2', '10', '40', 'blue']
# -------------------------------------------------------------------
# 1551.png
# ['circle', '5', '2', '60', 'orange']
# ['circle', '5', '2', '60', 'orange']
# -------------------------------------------------------------------
# 1819.png
# ['rect', '3', '6', '40', '40', 'cyan']
# ['rect', '4', '6', '40', '40', 'cyan']
# -------------------------------------------------------------------
# 17.png
# ['rect', '8', '1', '60', '60', 'deep_pink']
# ['rect', '8', '1', '60', '60', 'deep_pink']
# -------------------------------------------------------------------
# 44.png
# ['rect', '6', '2', '80', '80', 'red']
# ['rect', '6', '2', '80', '80', 'deep_pink']
# -------------------------------------------------------------------
# 1979.png
# ['circle', '9', '1', '110', 'pink']
# ['circle', '9', '1', '110', 'pink']
# -------------------------------------------------------------------
# 1031.png
# ['rect', '5', '7', '60', '60', 'cyan']
# ['rect', '5', '7', '60', '60', 'cyan']
# -------------------------------------------------------------------
# 374.png
# ['circle', '3', '3', '100', 'purple']
# ['circle', '4', '3', '100', 'pink']
# -------------------------------------------------------------------
# 1097.png
# ['rect', '10', '2', '30', '30', 'spring_green']
# ['rect', '10', '2', '30', '30', 'spring_green']
# -------------------------------------------------------------------
# 581.png
# ['rect', '6', '1', '90', '90', 'orange']
# ['rect', '6', '1', '90', '90', 'orange']
# -------------------------------------------------------------------
# 171.png
# ['rect', '1', '1', '70', '70', 'pink']
# ['rect', '1', '1', '70', '70', 'pink']
# -------------------------------------------------------------------
# 1837.png
# ['rect', '10', '9', '50', '50', 'green']
# ['rect', '10', '10', '70', '70', 'green']
# -------------------------------------------------------------------
# 1070.png
# ['circle', '6', '3', '60', 'spring_green']
# ['circle', '7', '3', '60', 'spring_green']
# -------------------------------------------------------------------
# 1052.png
# ['circle', '1', '10', '110', 'lime']
# ['circle', '1', '9', '80', 'lime']
# -------------------------------------------------------------------
# 1001.png
# ['rect', '2', '9', '50', '50', 'red']
# ['rect', '2', '9', '50', '50', 'red']
# -------------------------------------------------------------------
# 277.png
# ['circle', '9', '5', '50', 'pink']
# ['circle', '9', '5', '60', 'pink']
# -------------------------------------------------------------------
# 116.png
# ['rect', '1', '10', '110', '110', 'orange']
# ['rect', '1', '9', '100', '100', 'red']
# -------------------------------------------------------------------
# 538.png
# ['circle', '3', '5', '50', 'lime']
# ['circle', '3', '5', '50', 'lime']
# -------------------------------------------------------------------
# 1617.png
# ['rect', '3', '10', '30', '30', 'yellow']
# ['rect', '4', '10', '30', '30', 'yellow']
# -------------------------------------------------------------------
# 810.png
# ['rect', '9', '2', '110', '110', 'pink']
# ['rect', '9', '2', '110', '110', 'pink']
# -------------------------------------------------------------------
# 1220.png
# ['circle', '4', '10', '70', 'cyan']
# ['circle', '4', '10', '60', 'cyan']
# -------------------------------------------------------------------
# 956.png
# ['circle', '1', '6', '80', 'lime']
# ['circle', '1', '6', '80', 'lime']
# -------------------------------------------------------------------
# 1935.png
# ['rect', '1', '5', '80', '80', 'yellow']
# ['rect', '1', '4', '80', '80', 'orange']
# -------------------------------------------------------------------
# 163.png
# ['rect', '10', '6', '100', '100', 'spring_green']
# ['rect', '10', '6', '90', '90', 'spring_green']
# -------------------------------------------------------------------
# 1101.png
# ['rect', '3', '10', '120', '120', 'blue']
# ['rect', '2', '10', '110', '110', 'blue']
# -------------------------------------------------------------------
# 981.png
# ['circle', '8', '6', '50', 'deep_pink']
# ['circle', '8', '6', '50', 'deep_pink']
# -------------------------------------------------------------------
# 39.png
# ['circle', '9', '3', '80', 'deep_pink']
# ['circle', '9', '4', '80', 'deep_pink']
# -------------------------------------------------------------------
# 257.png
# ['rect', '7', '6', '60', '60', 'lime']
# ['rect', '8', '7', '60', '60', 'lime']
# -------------------------------------------------------------------
# 691.png
# ['rect', '10', '4', '40', '40', 'purple']
# ['rect', '10', '4', '50', '50', 'purple']
# -------------------------------------------------------------------
# 433.png
# ['circle', '3', '3', '110', 'red']
# ['circle', '3', '4', '100', 'red']
# -------------------------------------------------------------------
# 1343.png
# ['rect', '8', '10', '110', '110', 'lime']
# ['rect', '8', '10', '100', '100', 'lime']
# -------------------------------------------------------------------
# 774.png
# ['rect', '7', '5', '120', '120', 'lime']
# ['rect', '7', '5', '120', '120', 'lime']
# -------------------------------------------------------------------
# 1108.png
# ['rect', '2', '9', '20', '20', 'yellow']
# ['rect', '3', '8', '30', '30', 'yellow']
# -------------------------------------------------------------------
# 1608.png
# ['circle', '3', '2', '70', 'skyblue']
# ['circle', '3', '2', '70', 'skyblue']
# -------------------------------------------------------------------
# 1534.png
# ['rect', '9', '9', '110', '110', 'pink']
# ['circle', '10', '10', '70', 'pink']
# -------------------------------------------------------------------
# 876.png
# ['rect', '1', '7', '90', '90', 'skyblue']
# ['rect', '1', '7', '80', '80', 'skyblue']
# -------------------------------------------------------------------
# 194.png
# ['rect', '6', '1', '100', '100', 'lime']
# ['rect', '6', '1', '100', '100', 'lime']
# -------------------------------------------------------------------
# 1241.png
# ['circle', '3', '8', '50', 'spring_green']
# ['circle', '3', '8', '50', 'spring_green']
# -------------------------------------------------------------------
# 197.png
# ['rect', '5', '1', '30', '30', 'skyblue']
# ['rect', '5', '1', '30', '30', 'skyblue']
# -------------------------------------------------------------------
# 1957.png
# ['circle', '7', '8', '80', 'deep_pink']
# ['circle', '7', '8', '80', 'deep_pink']
# -------------------------------------------------------------------
# 1893.png
# ['rect', '9', '1', '60', '60', 'yellow']
# ['rect', '9', '1', '60', '60', 'yellow']
# -------------------------------------------------------------------
# 1602.png
# ['rect', '4', '7', '40', '40', 'cyan']
# ['rect', '4', '8', '40', '40', 'cyan']
# -------------------------------------------------------------------
# 718.png
# ['circle', '8', '5', '120', 'cyan']
# ['circle', '8', '5', '120', 'cyan']
# -------------------------------------------------------------------
# 845.png
# ['circle', '6', '8', '20', 'cyan']
# ['circle', '6', '7', '20', 'cyan']
# -------------------------------------------------------------------
# 1164.png
# ['rect', '4', '7', '60', '60', 'purple']
# ['rect', '4', '7', '50', '50', 'purple']
# -------------------------------------------------------------------
# 265.png
# ['rect', '3', '6', '80', '80', 'red']
# ['rect', '3', '6', '80', '80', 'red']
# -------------------------------------------------------------------
# 1635.png
# ['rect', '10', '4', '110', '110', 'green']
# ['rect', '10', '4', '110', '110', 'green']
# -------------------------------------------------------------------
# 285.png
# ['circle', '8', '2', '30', 'deep_pink']
# ['circle', '9', '1', '30', 'deep_pink']
# -------------------------------------------------------------------
# 330.png
# ['circle', '4', '2', '120', 'purple']
# ['circle', '4', '3', '120', 'purple']
# -------------------------------------------------------------------
# 1911.png
# ['circle', '8', '8', '100', 'green']
# ['circle', '8', '8', '100', 'green']
# -------------------------------------------------------------------
# 155.png
# ['rect', '4', '3', '80', '80', 'yellow']
# ['rect', '4', '3', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 417.png
# ['rect', '10', '6', '70', '70', 'yellow']
# ['rect', '10', '6', '70', '70', 'yellow']
# -------------------------------------------------------------------
# 414.png
# ['circle', '7', '3', '80', 'lime']
# ['circle', '7', '2', '80', 'green']
# -------------------------------------------------------------------
# 900.png
# ['rect', '1', '8', '40', '40', 'deep_pink']
# ['rect', '1', '8', '40', '40', 'deep_pink']
# -------------------------------------------------------------------
# 1778.png
# ['rect', '1', '4', '100', '100', 'yellow']
# ['rect', '1', '4', '100', '100', 'yellow']
# -------------------------------------------------------------------
# 1856.png
# ['rect', '4', '9', '50', '50', 'lime']
# ['circle', '5', '10', '30', 'lime']
# -------------------------------------------------------------------
# 1406.png
# ['circle', '6', '7', '100', 'yellow']
# ['circle', '7', '7', '100', 'yellow']
# -------------------------------------------------------------------
# 1473.png
# ['rect', '5', '9', '60', '60', 'green']
# ['rect', '5', '9', '60', '60', 'green']
# -------------------------------------------------------------------
# 870.png
# ['circle', '10', '1', '80', 'cyan']
# ['circle', '10', '1', '100', 'cyan']
# -------------------------------------------------------------------
# 364.png
# ['rect', '3', '8', '30', '30', 'cyan']
# ['rect', '3', '8', '30', '30', 'cyan']
# -------------------------------------------------------------------
# 1240.png
# ['circle', '5', '1', '30', 'skyblue']
# ['circle', '5', '1', '20', 'skyblue']
# -------------------------------------------------------------------
# 885.png
# ['rect', '1', '3', '60', '60', 'orange']
# ['rect', '1', '3', '60', '60', 'orange']
# -------------------------------------------------------------------
# 1631.png
# ['circle', '10', '5', '40', 'orange']
# ['circle', '10', '5', '50', 'orange']
# -------------------------------------------------------------------
# 1610.png
# ['rect', '7', '10', '90', '90', 'purple']
# ['rect', '7', '10', '90', '90', 'pink']
# -------------------------------------------------------------------
# 159.png
# ['rect', '2', '6', '110', '110', 'spring_green']
# ['rect', '1', '6', '110', '110', 'spring_green']
# -------------------------------------------------------------------
# 1782.png
# ['rect', '8', '3', '50', '50', 'skyblue']
# ...
# 8.png
# ['rect', '9', '9', '100', '100', 'orange']
# ['rect', '9', '9', '80', '80', 'orange']
# -------------------------------------------------------------------
# 1301.png
# ['rect', '10', '8', '70', '70', 'blue']
# ['rect', '10', '9', '70', '70', 'blue']
# -------------------------------------------------------------------
# 497.png
# ['circle', '1', '8', '80', 'lime']
# ['circle', '1', '7', '80', 'lime']
# -------------------------------------------------------------------
# 1488.png
# ['rect', '4', '1', '70', '70', 'blue']
# ['rect', '4', '1', '70', '70', 'blue']
# -------------------------------------------------------------------
# 1792.png
# ['circle', '8', '7', '100', 'spring_green']
# ['circle', '8', '7', '100', 'spring_green']
# -------------------------------------------------------------------
# 1636.png
# ['circle', '7', '5', '110', 'skyblue']
# ['circle', '7', '5', '110', 'skyblue']
# -------------------------------------------------------------------
# 1523.png
# ['circle', '7', '8', '80', 'red']
# ['circle', '7', '8', '80', 'red']
# -------------------------------------------------------------------
# 650.png
# ['rect', '7', '6', '50', '50', 'blue']
# ['rect', '8', '6', '50', '50', 'purple']
# -------------------------------------------------------------------
# 170.png
# ['circle', '5', '7', '90', 'orange']
# ['circle', '5', '7', '90', 'red']
# -------------------------------------------------------------------
# 1115.png
# ['rect', '1', '5', '110', '110', 'skyblue']
# ['rect', '1', '5', '110', '110', 'blue']
# -------------------------------------------------------------------
# 1006.png
# ['rect', '10', '3', '80', '80', 'orange']
# ['rect', '10', '3', '80', '80', 'orange']
# -------------------------------------------------------------------
# 797.png
# ['circle', '2', '1', '30', 'spring_green']
# ['circle', '1', '1', '30', 'spring_green']
# -------------------------------------------------------------------
# 71.png
# ['circle', '5', '3', '70', 'orange']
# ['circle', '5', '3', '70', 'orange']
# -------------------------------------------------------------------
# 1604.png
# ['circle', '5', '3', '70', 'lime']
# ['circle', '5', '3', '70', 'lime']
# -------------------------------------------------------------------
# 0.png
# ['circle', '4', '3', '100', 'yellow']
# ['circle', '4', '3', '100', 'yellow']
# -------------------------------------------------------------------
# 1686.png
# ['rect', '10', '2', '50', '50', 'lime']
# ['circle', '10', '2', '30', 'lime']
# -------------------------------------------------------------------
# 1127.png
# ['rect', '1', '10', '60', '60', 'yellow']
# ['rect', '1', '10', '40', '40', 'yellow']
# -------------------------------------------------------------------
# 1187.png
# ['rect', '10', '5', '30', '30', 'cyan']
# ['rect', '10', '5', '30', '30', 'cyan']
# -------------------------------------------------------------------
# 739.png
# ['rect', '2', '5', '70', '70', 'orange']
# ['rect', '2', '5', '70', '70', 'red']
# -------------------------------------------------------------------
# 968.png
# ['rect', '2', '8', '120', '120', 'blue']
# ['rect', '1', '8', '110', '110', 'blue']
# -------------------------------------------------------------------
# 381.png
# ['circle', '10', '2', '60', 'skyblue']
# ['circle', '10', '2', '60', 'skyblue']
# -------------------------------------------------------------------
# 435.png
# ['circle', '1', '1', '70', 'green']
# ['circle', '1', '1', '70', 'green']
# -------------------------------------------------------------------
# 1103.png
# ['circle', '6', '3', '80', 'lime']
# ['circle', '6', '3', '80', 'lime']
# -------------------------------------------------------------------
# 1619.png
# ['rect', '10', '8', '90', '90', 'orange']
# ['rect', '10', '8', '90', '90', 'orange']
# -------------------------------------------------------------------
# 20.png
# ['circle', '5', '3', '40', 'red']
# ['circle', '5', '3', '40', 'red']
# -------------------------------------------------------------------
# 961.png
# ['rect', '7', '9', '20', '20', 'skyblue']
# ['rect', '7', '9', '20', '20', 'blue']
# -------------------------------------------------------------------
# 767.png
# ['rect', '2', '8', '70', '70', 'yellow']
# ['rect', '2', '8', '70', '70', 'yellow']
# -------------------------------------------------------------------
# 820.png
# ['circle', '8', '6', '100', 'deep_pink']
# ['circle', '7', '6', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1153.png
# ['circle', '8', '3', '50', 'cyan']
# ['circle', '9', '3', '50', 'cyan']
# -------------------------------------------------------------------
# 1235.png
# ['circle', '8', '2', '30', 'skyblue']
# ['circle', '8', '2', '30', 'skyblue']
# -------------------------------------------------------------------
# 545.png
# ['circle', '2', '4', '100', 'skyblue']
# ['circle', '2', '4', '100', 'skyblue']
# -------------------------------------------------------------------
# 1640.png
# ['circle', '6', '10', '120', 'red']
# ['circle', '7', '10', '120', 'red']
# -------------------------------------------------------------------
# 1182.png
# ['rect', '9', '7', '110', '110', 'lime']
# ['rect', '9', '7', '120', '120', 'green']
# -------------------------------------------------------------------
# 943.png
# ['rect', '3', '4', '80', '80', 'orange']
# ['rect', '4', '4', '80', '80', 'orange']
# -------------------------------------------------------------------
# 1131.png
# ['rect', '7', '7', '30', '30', 'deep_pink']
# ['rect', '7', '7', '30', '30', 'pink']
# -------------------------------------------------------------------
# 1360.png
# ['circle', '3', '8', '100', 'purple']
# ['circle', '3', '8', '100', 'purple']
# -------------------------------------------------------------------
# 1800.png
# ['rect', '10', '8', '60', '60', 'skyblue']
# ['rect', '10', '9', '60', '60', 'skyblue']
# -------------------------------------------------------------------
# 583.png
# ['rect', '5', '10', '50', '50', 'spring_green']
# ['rect', '5', '10', '50', '50', 'spring_green']
# -------------------------------------------------------------------
# 153.png
# ['rect', '6', '1', '30', '30', 'green']
# ['rect', '6', '1', '30', '30', 'green']
# -------------------------------------------------------------------
# 631.png
# ['circle', '9', '8', '70', 'green']
# ['circle', '9', '9', '60', 'green']
# -------------------------------------------------------------------
# 1573.png
# ['rect', '5', '2', '60', '60', 'pink']
# ['rect', '5', '2', '60', '60', 'pink']
# -------------------------------------------------------------------
# 1339.png
# ['circle', '9', '9', '110', 'red']
# ['circle', '9', '9', '110', 'deep_pink']
# -------------------------------------------------------------------
# 894.png
# ['rect', '5', '9', '110', '110', 'red']
# ['rect', '6', '9', '100', '100', 'red']
# -------------------------------------------------------------------
# 344.png
# ['rect', '4', '5', '20', '20', 'blue']
# ['rect', '5', '5', '20', '20', 'blue']
# -------------------------------------------------------------------
# 303.png
# ['rect', '9', '6', '20', '20', 'blue']
# ['rect', '9', '6', '30', '30', 'blue']
# -------------------------------------------------------------------
# 1552.png
# ['circle', '6', '10', '110', 'spring_green']
# ['circle', '6', '10', '110', 'spring_green']
# -------------------------------------------------------------------
# 461.png
# ['rect', '8', '3', '40', '40', 'yellow']
# ['rect', '8', '3', '40', '40', 'yellow']
# -------------------------------------------------------------------
# 1062.png
# ['rect', '9', '7', '40', '40', 'deep_pink']
# ['rect', '9', '8', '40', '40', 'deep_pink']
# -------------------------------------------------------------------
# 1147.png
# ['circle', '7', '3', '110', 'green']
# ['circle', '7', '3', '100', 'green']
# -------------------------------------------------------------------
# 844.png
# ['rect', '4', '5', '90', '90', 'deep_pink']
# ['rect', '4', '5', '90', '90', 'deep_pink']
# -------------------------------------------------------------------
# 1359.png
# ['circle', '1', '6', '80', 'blue']
# ['circle', '1', '6', '80', 'blue']
# -------------------------------------------------------------------
# 929.png
# ['circle', '7', '5', '50', 'skyblue']
# ['circle', '7', '5', '50', 'skyblue']
# -------------------------------------------------------------------
# 1366.png
# ['circle', '5', '2', '80', 'yellow']
# ['circle', '6', '2', '80', 'orange']
# -------------------------------------------------------------------
# 825.png
# ['rect', '5', '8', '70', '70', 'spring_green']
# ['rect', '5', '8', '70', '70', 'spring_green']
# -------------------------------------------------------------------
# 117.png
# ['rect', '5', '2', '90', '90', 'lime']
# ['rect', '5', '1', '90', '90', 'lime']
# -------------------------------------------------------------------
# 716.png
# ['circle', '7', '8', '100', 'red']
# ['circle', '7', '8', '90', 'red']
# -------------------------------------------------------------------
# 1013.png
# ['rect', '9', '3', '80', '80', 'orange']
# ['rect', '9', '3', '80', '80', 'orange']
# -------------------------------------------------------------------
# 758.png
# ['circle', '5', '5', '100', 'red']
# ['circle', '5', '5', '100', 'red']
# -------------------------------------------------------------------
# 1441.png
# ['circle', '3', '2', '110', 'lime']
# ['circle', '3', '2', '110', 'lime']
# -------------------------------------------------------------------
# 98.png
# ['rect', '10', '5', '100', '100', 'blue']
# ['rect', '10', '5', '100', '100', 'purple']
# -------------------------------------------------------------------
# 107.png
# ['circle', '10', '2', '50', 'green']
# ['circle', '10', '2', '50', 'green']
# -------------------------------------------------------------------
# 975.png
# ['rect', '9', '3', '90', '90', 'lime']
# ['rect', '9', '3', '90', '90', 'green']
# -------------------------------------------------------------------
# 889.png
# ['circle', '4', '9', '50', 'purple']
# ['circle', '4', '9', '50', 'purple']
# -------------------------------------------------------------------
# 1372.png
# ['circle', '4', '3', '40', 'deep_pink']
# ['circle', '4', '3', '40', 'deep_pink']
# -------------------------------------------------------------------
# 480.png
# ['rect', '8', '10', '110', '110', 'red']
# ['rect', '8', '10', '100', '100', 'red']
# -------------------------------------------------------------------
# 264.png
# ['circle', '3', '9', '70', 'pink']
# ['circle', '3', '8', '70', 'pink']
# -------------------------------------------------------------------
# 1973.png
# ['circle', '10', '5', '110', 'blue']
# ['circle', '10', '6', '110', 'blue']
# -------------------------------------------------------------------
# 1318.png
# ['circle', '8', '2', '40', 'spring_green']
# ['circle', '9', '2', '40', 'spring_green']
# -------------------------------------------------------------------
# 1546.png
# ['rect', '10', '4', '100', '100', 'lime']
# ['rect', '10', '4', '100', '100', 'lime']
# -------------------------------------------------------------------
# 601.png
# ['rect', '2', '1', '100', '100', 'lime']
# ['rect', '2', '1', '100', '100', 'lime']
# -------------------------------------------------------------------
# 1554.png
# ['rect', '7', '10', '50', '50', 'lime']
# ['circle', '7', '10', '30', 'lime']
# -------------------------------------------------------------------
# 493.png
# ['circle', '3', '6', '20', 'green']
# ['circle', '4', '6', '30', 'green']
# -------------------------------------------------------------------
# 850.png
# ['rect', '3', '1', '50', '50', 'red']
# ['rect', '3', '1', '50', '50', 'red']
# -------------------------------------------------------------------
# 632.png
# ['rect', '4', '7', '40', '40', 'lime']
# ['rect', '4', '7', '40', '40', 'lime']
# -------------------------------------------------------------------
# 1869.png
# ['rect', '7', '3', '100', '100', 'blue']
# ['rect', '7', '3', '90', '90', 'purple']
# -------------------------------------------------------------------
# 542.png
# ['rect', '4', '9', '100', '100', 'cyan']
# ['rect', '5', '9', '90', '90', 'cyan']
# -------------------------------------------------------------------
# 238.png
# ['rect', '6', '7', '20', '20', 'orange']
# ['rect', '7', '6', '20', '20', 'red']
# -------------------------------------------------------------------
# 598.png
# ['rect', '5', '5', '110', '110', 'cyan']
# ['rect', '6', '5', '110', '110', 'cyan']
# -------------------------------------------------------------------
# 766.png
# ['rect', '10', '3', '100', '100', 'spring_green']
# ['rect', '10', '3', '90', '90', 'green']
# -------------------------------------------------------------------
# 350.png
# ['rect', '1', '2', '70', '70', 'green']
# ['rect', '1', '1', '70', '70', 'green']
# -------------------------------------------------------------------
# 358.png
# ['rect', '7', '1', '80', '80', 'yellow']
# ['rect', '7', '1', '80', '80', 'yellow']
# -------------------------------------------------------------------
# 1000.png
# ['circle', '3', '1', '90', 'lime']
# ['circle', '2', '1', '100', 'lime']
# -------------------------------------------------------------------
# 1652.png
# ['circle', '10', '2', '100', 'purple']
# ['circle', '10', '2', '100', 'purple']
# -------------------------------------------------------------------
# 1272.png
# ['rect', '3', '1', '110', '110', 'lime']
# ['rect', '3', '1', '110', '110', 'lime']
# -------------------------------------------------------------------
# 585.png
# ['circle', '7', '1', '30', 'red']
# ['circle', '7', '1', '20', 'red']
# -------------------------------------------------------------------
# 923.png
# ['circle', '5', '6', '100', 'cyan']
# ['circle', '5', '6', '100', 'cyan']
# -------------------------------------------------------------------
# 424.png
# ['rect', '2', '8', '20', '20', 'cyan']
# ['rect', '2', '8', '20', '20', 'cyan']
# -------------------------------------------------------------------
# 1015.png
# ['circle', '6', '2', '80', 'green']
# ['circle', '6', '2', '80', 'green']
# -------------------------------------------------------------------
# 441.png
# ['circle', '9', '8', '30', 'pink']
# ['circle', '9', '8', '30', 'pink']
# -------------------------------------------------------------------
# 1567.png
# ['circle', '10', '9', '60', 'red']
# ['circle', '10', '9', '60', 'red']
# -------------------------------------------------------------------
# 1698.png
# ['circle', '1', '5', '50', 'orange']
# ['circle', '2', '5', '50', 'orange']
# -------------------------------------------------------------------
# 787.png
# ['rect', '5', '4', '60', '60', 'orange']
# ['rect', '5', '4', '60', '60', 'orange']
# -------------------------------------------------------------------
# 1697.png
# ['rect', '7', '5', '70', '70', 'skyblue']
# ['rect', '7', '5', '70', '70', 'skyblue']
# -------------------------------------------------------------------
# 1900.png
# ['circle', '10', '2', '110', 'yellow']
# ['circle', '10', '2', '110', 'yellow']
# -------------------------------------------------------------------
# 1265.png
# ['circle', '9', '5', '90', 'skyblue']
# ['circle', '9', '5', '90', 'skyblue']
# -------------------------------------------------------------------
# 416.png
# ['rect', '4', '5', '70', '70', 'pink']
# ['rect', '4', '5', '70', '70', 'pink']
# -------------------------------------------------------------------
# 966.png
# ['circle', '10', '9', '70', 'skyblue']
# ['circle', '10', '10', '80', 'skyblue']
# -------------------------------------------------------------------
# 1682.png
# ['rect', '5', '5', '70', '70', 'cyan']
# ['rect', '5', '5', '70', '70', 'cyan']
# -------------------------------------------------------------------
# 102.png
# ['rect', '9', '1', '40', '40', 'skyblue']
# ['rect', '10', '1', '40', '40', 'blue']
# -------------------------------------------------------------------
# 384.png
# ['circle', '6', '3', '100', 'deep_pink']
# ['circle', '6', '3', '100', 'deep_pink']
# -------------------------------------------------------------------
# 1982.png
# ['circle', '10', '8', '70', 'pink']
# ['circle', '10', '8', '70', 'pink']
# -------------------------------------------------------------------
# 1247.png
# ['rect', '4', '9', '110', '110', 'orange']
# ['rect', '4', '9', '90', '90', 'orange']
# -------------------------------------------------------------------
# 1242.png
# ['rect', '2', '10', '100', '100', 'yellow']
# ['circle', '3', '10', '40', 'yellow']
# -------------------------------------------------------------------

# %%
trg_caption[0]
in_caption[0]

# %%
length_match/len(test_list)
# Out:
# 0.961

# %%
temp = [] 
temp.append('1')

# %%
print('shape match: %.4f, location match: %.4f, radius_match: %.4f, rect_x_match: %.4f, rect_y_match: %.4f color_match: %.4f'
     %(shape_match/(len(test_list)), location_match/(len(test_list)*2),
       radius_match/(circle_cnt), rect_x_match/rect_cnt, rect_y_match/rect_cnt, color_match/(len(test_list))))
# Out:
# shape match: 0.9615, location match: 0.8060, radius_match: 0.7505, rect_x_match: 0.7419, rect_y_match: 0.7419 color_match: 0.8490

# %%
x_ = {x:rect_x_err.count(x) for x in rect_x_err}
y_ = {x:rect_y_err.count(x) for x in rect_y_err}
r_ = {x:radius_err.count(x) for x in radius_err}
loc_ ={x:location_err.count(x) for x in location_err}

# %%
y_
# Out:
# {10: 198, 20: 25, 30: 12, 40: 2, 50: 1, 60: 7, 70: 2}

# %%
x_[10]/len(rect_x_err)
